# %%
import urllib.request
import random
from bs4 import BeautifulSoup
import json

def get_page(url, parameters = None):
    
    if parameters:
        encode_parameters = urllib.parse.urlencode(parameters).encode('utf-8')
    else:
        encode_parameters = None
        
    request = urllib.request.Request(url)

        ####隨機header挑選####
    foo = [
            'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2227.1 Safari/537.36',
            'Mozilla/5.0 (compatible, MSIE 11, Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko',
            'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:40.0) Gecko/20100101 Firefox/40.1'
            'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_6_7; da-dk) AppleWebKit/533.21.1 (KHTML, like Gecko) Version/5.0.5 Safari/533.21.1'
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246'
            'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2722.0 Safari/537.36'
            'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.116 Safari/537.36'
        ]
    headers = str(random.choice(foo))
        ####隨機header挑選####

    request.add_header('User-Agent', headers)
    response = urllib.request.urlopen(request, data=encode_parameters, timeout=180)
    html = BeautifulSoup(response.read().decode('big5'), 'lxml')
    response.close()

    return html

# %%
def etmall(search):
    
    parameters = {'SearchKeyword': search,
                  'SearchKey': search,
                  'ProductPage': '0',
                  'RecordsPerPage': '40',
                  'OrderBy': '_weight_,DESC'}

    result = str(get_page('http://www.etmall.com.tw/Pages/AllSearchFormResult.aspx', parameters=parameters))
    
    pat_product = 'aPL_GOODNM\[.*?\)'
    # pat2='aPL_PRC\[.*?\;'
    pat_price = 'aPL_DISCOUNT_VALUE\[.*?\;'
    product = re.findall(pat_product, result)
    price = re.findall(pat_price, result)
    
    etmall_list = list()
    for i in range(len(product)):
        product_remove = re.sub(r"^aPL.*\car\('", '', product[i]).replace("')", '')
        price_remove = re.sub(r"^aPL.*\= \'", '', price[i]).replace("';", '')
        etmall_list.extend([product_remove, price_remove])
        
    ####將結果變成list裡面包tuple(產品, 價格)####
    etmall_display = list()
    a, b = 0, 2
    x = int(len(etmall_list) / 2)
    while x != 0:
        etmall_display.append(tuple(etmall_list[a:b]))
        x -= 1
        a, b = b, b + 2
    ####將結果變成list裡面包tuple(產品, 價格)####
    return etmall_display

# %%
etmall('KIEN 3 G-TX 男慢跑鞋- 路跑 美津濃 黑綠')
# Out:
# [('【MIZUNO】KIEN 3 G-TX 男慢跑鞋- 路跑 美津濃 黑綠', '2420')]

# %%
import re

pat='aPL_GOODNM\[.*?\)'
pat2='aPL_PRC\[.*?\;'
match = re.findall(pat, test)
match2 = re.findall(pat2 , test)

# %%
# inputStr = "hello crifan, nihao crifan"
inputStr = "aPL_GOODNM[0]=changecar('PS4主機CUH-2017專用直立架-黑(lV-P4S006)"
replacedStr = re.sub(r"^aPL.*\car\('", '', inputStr)
replacedStr
# Out:
# D:\anaconda\lib\site-packages\ipykernel\__main__.py:3: DeprecationWarning: bad escape \c
#   app.launch_new_instance()
# 'PS4主機CUH-2017專用直立架-黑(lV-P4S006)'

# %%
pat='aPL_GOODNM\[.*?\;'
# pat='sm_seq_list:\[.*'
match = re.findall(pat, aa)
match

# %%
import re
def umall(search):
    
    parameters = {'SearchKeyword': search,
                  'SearchKey': search,
                  'ProductPage': '0',
                  'RecordsPerPage': '40',
                  'OrderBy': '_weight_,DESC'}

    result = str(get_page('http://www.u-mall.com.tw/Search.aspx', parameters=parameters))
    pat_product = 'Tmp = changecar\(\'.*?\)'
    pat_price = 'Sys_showPRCValue\(.*?\)'
    product = re.findall(pat_product, result)
    price_error_string = re.findall(pat_price, result)

    price_correct = list()
    for i in price_error_string:
        price_correct.append([(re.sub(r"^Sys_.*('', |'Y', )", '', i).replace(")", '').replace("'", '').replace(' ',''))])
    price_final = [min(x) for x in [i[0].split(',') for i in price_correct]]
    
    umall_list = list()
    for i in range(len(product)):
        product_remove = re.sub(r"^Tmp.*\('", '', product[i]).replace("')", '')
        price_remove = price_final[i]
        umall_list.extend([product_remove, price_remove])
        
    ####將結果變成list裡面包tuple(產品, 價格)####
    umall_display = list()
    a, b = 0, 2
    x = int(len(umall_list) / 2)
    while x != 0:
        umall_display.append(tuple(umall_list[a:b]))
        x -= 1
        a, b = b, b + 2
    ####將結果變成list裡面包tuple(產品, 價格)####
    
    return umall_display

# %%
umall('【MIZUNO】SYNCHRO MX 女慢跑鞋- 美津濃 訓練 健身 路跑 桃紅黑')
# Out:
# [('【MIZUNO】SYNCHRO MX 女慢跑鞋- 美津濃 訓練 健身 路跑 桃紅黑', '1690')]

# %%
pat='changecar\(.*?\)'
# pat2='aPL_PRC\[.*?\;'
pat2 = 'Sys_showPRCValue\(.*?\)'
match = re.findall(pat, haha_html)
match2 = re.findall(pat2, haha_html)
match
# umall_list = list()
# test = list()
# for i in match2:
#     test.append([(re.sub(r"^Sys_.*('', |'Y', )", '', i).replace(")", '').replace("'", '').replace(' ',''))])
# last = [min(x) for x in [i[0].split(',') for i in test]]
# for i in range(len(match)):
#     product_remove = re.sub(r"^Tmp.*\car\('", '', match[i]).replace("')", '')
#     price_remove = re.sub(r"^Sys_.*\(", '', match2[i]).replace(")", '').replace('Y', '')
#     umall_list.extend([product_remove, price_remove])
# Out:
# ["changecar('【MIZUNO】WAVE RIDER 19 男慢跑鞋-慢跑 路跑 美津濃 灰水藍')",
#  "changecar('*透氣網布提升穩定和包覆<br/>*橡膠大底增加耐磨度<br/>*貨號:J1GC1603')",
#  "changecar('【MIZUNO】男針織運動長褲 - 路跑 慢跑 美津濃 藍綠白')",
#  "changecar('*100%聚酯纖維<br/>*彈性鬆緊腰帶附拉繩<br/>*貨號:32TD5534')",
#  "changecar('【MIZUNO】男保暖風褲-防風 防撥水 刷毛 長褲 美津濃 黑黃灰')",
#  "changecar('*褲頭綁繩<br/>*內裡刷毛<br/>*貨號:32TF6587')",
#  "changecar('【Mizuno 美津濃】 Mizuno Slim Fit 合身版針織運動長褲 (法國藍X麻灰)",
#  "changecar('吸汗快乾材質 <br/>抗紫外線UPF50 <br/>Slim Fit合身版型')",
#  "changecar('【MIZUNO】WAVE INSPIRE 12 男慢跑鞋- 路跑 美津濃 螢光黃銀')",
#  "changecar('*橡膠大底提升抓地力br*貨號:J1GC1644')",
#  "changecar('【MIZUNO】男針織運動長褲- 慢跑 路跑 美津濃 丈青藍黃')",
#  "changecar('*腰部鬆緊附抽繩<br/>*雙側口袋<br/>*貨號:32TD6534')",
#  "changecar('【MIZUNO】WAVE RIDER 20 女慢跑鞋- 路跑 美津濃 紫粉紅')",
#  "changecar('*平行波浪片<br/>*避震<br/>*型號:J1GD170309')",
#  "changecar('【Mizuno 美津濃】Mizuno SPARK Jnr 大童鞋 K1GC162611')",
#  "changecar('A.重量約170g(22.0cm單腳)",
#  "changecar('【Mizuno 美津濃】 MAXIMIZER 18 男女慢跑鞋(寬楦)",
#  "changecar('適合輕運動，快走使用，搭配mizuno X10耐磨大底，輕鬆運動無負擔!')",
# ...

# %%
def gohappy(search):

    import json
    import requests
    
    def gohappy_pro_pages(search): #### 取得商品頁數

        gohappy_pro_url = 'http://www.gohappy.com.tw/ec2/search?sid=&hotNum=1&search=' + str(requests.utils.quote(search))
        gohappy_url_html = get_page(gohappy_pro_url)
        
        parse_time = None
        for pages in gohappy_url_html.find_all('ul', {'class': 'pagenum'}):
            gohappy_page = pages.text.replace('\n', '')
            page_index = gohappy_page.find('共')
            parse_time = int(gohappy_page[page_index + 1 :].replace('頁', ''))
            
        return parse_time
    
    gohappy_url = 'http://www.gohappy.com.tw/ec2/searchCate'
    
    pages = gohappy_pro_pages(search)
    gohappy_list = list()
    
    for page in range(0, pages):
        parameters = {'searchs': search, 'pageno': str(page), 'pagesize': '20', 'orderby': 'close', 'cateLvs': '-1', 'watchtype': '1'}
        r = requests.post(gohappy_url, params = parameters)
        r_json = json.loads(r.text)
        r_bs = BeautifulSoup(r_json.get('data').get('form'), 'lxml')

        for elements in r_bs.find_all('ol', {'class': 'proddata-list'}):
            for product in elements.find_all('li', {'class': 'prodname'}):
                gohappy_list.append(product.text.replace('\n', ''))
            for price_tag in elements.find_all('li', {'class': 'price-txt'}):
                for price in price_tag.find_all('strong'):
                    gohappy_list.append(price.text)
                    
    ####將結果變成list裡面包tuple(產品, 價格)####
    gohappy_display = list()
    a, b = 0, 2
    x = int(len(gohappy_list) / 2)
    while x != 0:
        gohappy_display.append(tuple(gohappy_list[a:b]))
        x -= 1
        a, b = b, b + 2
    ####將結果變成list裡面包tuple(產品, 價格)####
            
    return gohappy_display

# %%
gohappy('Mizuno手套')
# Out:
# [('Mizuno PROFESSIONAL 野手硬式手套 1ATGH50207', '4220'),
#  ('MIZUNO 少年右打者打擊手套-棒球 壘球 黑紅', '434'),
#  ('MIZUNO 右打者用打擊手套-棒球 壘球 左手用 一只入 美津濃 黑灰藍', '455'),
#  ('MIZUNO 右打者用打擊手套-棒球 壘球 左手用 一只入 美津濃 黑紅白', '455'),
#  ('MIZUNO 打擊手套-棒球 壘球 一雙入 美津濃 藍黑白', '871'),
#  ('MIZUNO 打擊手套-棒球 壘球 一雙入 美津濃 橘白黑', '871'),
#  ('MIZUNO 打擊手套-棒球 壘球 一雙入 美津濃 黑白', '871'),
#  ('MIZUNO 打擊手套-棒球 壘球 一雙入 美津濃 灰黑白', '871'),
#  ('MIZUNO 打擊手套-棒球 壘球 一雙入 美津濃 丈青白', '871'),
#  ('MIZUNO 打擊手套-棒球 壘球 一雙入 美津濃 白黑', '871'),
#  ('MIZUNO 打擊手套-棒球 壘球 一雙入 美津濃 紅黑白', '871'),
#  ('MIZUNO 硬式手套-棒球 壘球 美津濃 丈青橘 F', '3307'),
#  ('MIZUNO 硬式手套-棒球 壘球 美津濃 橘紅 F', '3307'),
#  ('MIZUNO 日製高級保革霜-棒壘球 配件 美津濃 依賣場 F', '680')]

# %%
import requests
a = 'http://www.gohappy.com.tw/ec2/search?sid=&hotNum=1&search=' + str(requests.utils.quote('Mizuno手套'))
get_page(a)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="zh-tw" http-equiv="Content-Language"/>
# <title>GoHappy快樂購物網-全台最大百貨零售購物網站</title>
# <meta content="GoHappy快樂購物網" name="author"/>
# <link href="http://www.gohappy.com.tw/ec2/search?sid=&amp;hotNum=0&amp;search=Mizuno手套" rel="canonical"/>
# <meta content="GoHappy給你購好的選擇!提供太平洋SOGO、遠東百貨國內外專櫃品牌，包含美容保養、服飾、精品、3C家電、美食餐券等超過八十萬件商品。100%正品及HAPPYGO點數折抵，讓你買得划算、安心又有保障!" name="description"/>
# <meta content="購物網站,線上購物,sogo,遠東百貨,citysuper,outlet,愛買線上購物,品牌特賣匯,百貨年終慶,周年慶,團購,餐券,快樂購卡點數折抵" name="keywords"/>
# <meta content="GoHappy快樂購物網-全台最大百貨零售購物網站" property="og:title"/>
# <meta content="product.group" property="og:type"/>
# <meta content="http://www.gohappy.com.tw/event/social_image/logo" property="og:image"/>
# <meta content=" GoHappy快樂購物網" property="og:site_name"/>
# ...

# %%
a
# Out:
# 'http://www.gohappy.com.tw/ec2/search?sid=&hotNum=1&search=Mizuno手套'

# %%
def yahoo(search):
    
    result = get_page('https://tw.search.buy.yahoo.com/search/shopping/product?p=dhc+%E8%AD%B7%E5%94%87%E8%86%8F&qt=product&cid=&clv=')
    yahoo = list()
    
    if result.find_all('div', {'class': 'wrap yui3-g'}):
        for elements in result.find_all('div', {'class': 'wrap yui3-g'}):
            for product in elements.find_all('div', {'class': 'yui3-u srp-pdcontent'}):
                yahoo.append(product.text.replace('\n',''))
            for prices in elements.find_all('div', {'class': 'srp-pdprice'}):
                for price in prices.find_all('span', {'class': 'srp-listprice-class'}):
                    yahoo.append(price.text.replace('$',''))
    elif result.find_all('div', {'class': 'srp-pdcontent'}):
        for elements in result.find_all('div', {'class': 'srp-pdcontent'}):
            for product in elements.find_all('div', {'class': 'srp-pdtitle'}):
                yahoo.append(product.text.replace('\n',''))
            for prices in elements.find_all('div', {'class': 'srp-pdprice'}):
                if prices.find_all('div', {'class': 'srp-actprice'}):
                    for price in prices.find_all('div', {'class': 'srp-actprice'}):
                        yahoo.append(price.text.replace('活動價 $','').replace('起', ''))
                else:
                    for price in prices.find_all('div', {'class': 'srp-listprice'}):
                        yahoo.append(price.text.replace('網路價 $', ''))
#             yahoo.append(price.text.replace('$',''))

    ###將結果變成list裡面包tuple(產品, 價格)####
    yahoo_display = list()
    a, b = 0, 2
    x = int(len(yahoo) / 2)
    while x != 0:
        yahoo_display.append(tuple(yahoo[a:b]))
        x -= 1
        a, b = b, b + 2
    ###將結果變成list裡面包tuple(產品, 價格)####
    return yahoo_display

# %%
yahoo('dhc 護唇膏')
# Out:
# [('DHC 純橄欖護唇膏-迪士尼公主系列 限定版(1.5gX3)-粉紅A款網路優惠價日本限定', '1,099'),
#  ('DHC 唇彩潤唇膏-小美人魚(1.4g)#RD02網路優惠價日本限定', '599'),
#  ('DHC 純橄欖護唇膏-迪士尼公主系列 限定版(1.5gX3)-綠色B款網路優惠價日本限定', '1,099'),
#  ('DHC 唇彩潤唇膏-白雪公主(1.4g)#PK01網路優惠價日本限定', '599')]

# %%
a = 'https://tw.search.buy.yahoo.com/search/shopping/product?p='+str(requests.utils.quote('Mizuno PRO 限定版 運動外套 保暖外套 夾克 12JE6W8314'))+'&qt=product&cid=&clv='
result = get_page('https://tw.search.buy.yahoo.com/search/shopping/product?p=dhc+%E8%AD%B7%E5%94%87%E8%86%8F&qt=product&cid=&clv=')

# %%
for i in result.find_all('div', {'class': 'srp-pdprice'}):
    for price in i.find_all('span', {'class': 'srp-listprice-class'}):
        print(price.text)
# Out:
# $1,099
# $599
# $1,099
# $599

# %%
result
# Out:
# <!DOCTYPE html>
# <html id="Stencil" lang="zh-Hant-tw">
# <head>
# <link href="https://buy.yahoo.com.tw" rel="canonical"/>
# <meta charset="utf-8" content="text/html" http-equiv="content-type"/>
# <meta content="-1" http-equiv="expires"/>
# <meta content="Yahoo!奇摩購物中心,提供40萬項以上商品讓您隨時享受購物服務,免運費,享有七天鑑賞期,是網路購物第一選擇,我們有300位以上專業團隊為您提供服務" name="description"/>
# <meta content="Yahoo!奇摩購物中心,購物,週年慶,百貨週年慶,會招,每日好康,福利品,特價,下殺,分期,0利率,無息,紅利折抵,超商取貨,快速到貨,限量" name="keywords"/>
# <meta content="Yahoo!奇摩購物中心" name="application-name"/>
# <meta content="#7B0099" name="msapplication-TileColor"/>
# <meta content="https://s.yimg.com/f/i/tw/monday/ymp/icon_pin_shopping_130103.png" name="msapplication-TileImage"/>
# <title>搜尋 dhc 護唇膏 結果- Yahoo!奇摩購物中心</title>
# <!-- facebook applinks -->
# ...

# %%
import re

aa = str()
p = re.compile('^sm_seq_list')
for i in haha3.find_all('script'):
    aa = i.text

# %%
import re


pat='sm_seq_list:.*?\]'
# pat='sm_seq_list:\[.*'
match = re.search(pat, aa)
match.group(0)
# Out:
# 'sm_seq_list:["201611AM300002770","201610AM120001222","201610AM120001284","201609AM170000224","201604AM280000562","201604AM280000561"]'

# %%
def asap(search):
    
    import requests
    
    def get_asap_pro_id():
        
        import re
    
        asap_scripts = str()
        asap_pages = int()
        
        pattern = 'sm_seq_list:.*?\]'
        
        result = get_page('http://www.asap.com.tw/search?q=' + search + '&s_c=1')
        for scripts in result.find_all('script'):
            asap_scripts = scripts.text 
#         for pages in result.find_all('ul', {'class': 'pagination'}):
#             asap_pages = pages
#             print(pages.text)
    
        match = re.search(pattern, asap_scripts)
        pro_id = match.group(0).replace('sm_seq_list:[', '').replace(']', '').replace('"', '').split(',')
        
        return pro_id
#         return pro_id, asap_pages
#     return get_asap_pro_id()
    
    pro_id = get_asap_pro_id()

    parameters = {'sm_seq_list[]': pro_id,
                  'is_cross': 'false',
                  'cross_country': ''}

    result = requests.post('http://www.asap.com.tw/category/get_real_time_data', data= parameters)
    result_dict = json.loads(result.text)
    
    asap_list = list()
    for i in pro_id:
        name = result_dict.get('data').get(i).get('market_info').get('name')
        price = result_dict.get('data').get(i).get('market_info').get('price').get('final_price').get('price')
        asap_list.extend((name, price))
    
    ####將結果變成list裡面包tuple(產品, 價格)####
    asap_display = list()
    a, b = 0, 2
    x = int(len(asap_list) / 2)
    while x != 0:
        asap_display.append(tuple(asap_list[a:b]))
        x -= 1
        a, b = b, b + 2
    ####將結果變成list裡面包tuple(產品, 價格)####
        
    return asap_display

# %%
asap('dhc 護唇膏')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-121-3bbc648ae069> in <module>()
# ----> 1 asap('dhc 護唇膏')
#
# <ipython-input-119-0873fc18e0cb> in asap(search)
#      26 #     return get_asap_pro_id()
#      27
# ---> 28     pro_id = get_asap_pro_id()
#      29
#      30     parameters = {'sm_seq_list[]': pro_id,
#
# <ipython-input-119-0873fc18e0cb> in get_asap_pro_id()
#      12         pattern = 'sm_seq_list:.*?\]'
#      13
# ---> 14         result = get_page('http://www.asap.com.tw/search?q=' + search + '&s_c=1')
#      15         for scripts in result.find_all('script'):
#      16             asap_scripts = scripts.text
#
# <ipython-input-97-570fce8191b1> in get_page(url, parameters)
#      27
#      28     request.add_header('User-Agent', headers)
# ---> 29     response = urllib.request.urlopen(request, data=encode_parameters, timeout=180)
# ...

# %%
haha = {'min_price':'0', 'max_price':'0', 'page':'1', 'sort':'score',
        'asc':'0', 's_c':'1', 'q':'mizuno'}
result = requests.post('http://www.asap.com.tw/search/get_list', data=haha)
result.text
# Out:
# '{"total":709,"range":"0 to 709","next_index":1,"category_list":{"AC202636":{"CP_SEQ":"AC202636","CP_NAME":"\\u5c08\\u696d\\u904b\\u52d5\\u978b","total":238},"200712":{"CP_SEQ":"200712","CP_NAME":"\\u5176\\u4ed6\\u9ad4\\u80b2","total":157},"200716":{"CP_SEQ":"200716","CP_NAME":"\\u904b\\u52d5\\u670d\\u98fe","total":121},"200718":{"CP_SEQ":"200718","CP_NAME":"\\u904b\\u52d5\\u914d\\u4ef6","total":77},"AC202354":{"CP_SEQ":"AC202354","CP_NAME":"\\u7537\\u904b\\u52d5\\u978b","total":59},"AC202349":{"CP_SEQ":"AC202349","CP_NAME":"\\u904b\\u52d5\\u978b","total":34},"AC202262":{"CP_SEQ":"AC202262","CP_NAME":"\\u7537\\u7ae5\\u978b","total":6},"200713":{"CP_SEQ":"200713","CP_NAME":"\\u745c\\u73c8\\u6bdb\\u5dfe","total":5},"AC202220":{"CP_SEQ":"AC202220","CP_NAME":"\\u904b\\u52d5\\u9632\\u8b77\\/\\u8212\\u58d3","total":3},"201920":{"CP_SEQ":"201920","CP_NAME":"\\u5176\\u4ed6\\u4eba\\u8eab\\u90e8\\u54c1","total":2},"200719":{"CP_SEQ":"200719","CP_NAME":"\\u904b\\u52d5\\u4f11\\u9592\\u5305\\/\\u
# ...

# %%
result = get_page('http://www.asap.com.tw/search?q=mizuno&s_c=1')
# print(result)
for i in result.find_all('div', {'class': 'nav-pagination'}):
    print(i.text)

# %%
asap()

# %%
parameters2 = {'sm_seq_list[]':["201611AM300002770","201610AM120001222","201610AM120001284","201609AM170000224","201604AM280000562","201604AM280000561"],
                'is_cross':'false',
               'cross_country':''}
ya = urllib.parse.urlencode(parameters2).encode('utf-8')
# haha = get_page('http://www.asap.com.tw/category/get_real_time_data', )
# haha = get_page('http://www.asap.com.tw/search?q=PS4%20CUH&s_c=1')
haha = requests.post('http://www.asap.com.tw/category/get_real_time_data', data=parameters2)
# haha = get_page('http://www.asap.com.tw/category/get_real_time_data', parameters=parameters2)

# %%
haha2 = json.loads(haha.text)

# %%
name = haha2.get('data').get('201611AM300002770').get('market_info').get('name')
price = haha2.get('data').get('201611AM300002770').get('market_info').get('price').get('final_price').get('price')

# %%
price, name
# Out:
# ('649', 'PS4 CUH-2000 / PS4 Pro CUH-7000系列 主機及手把兩用直立架 固定架')

# %%
parameters2 = {'sm_seq_list[]':['201611AM300002770','201610AM120001222','201610AM120001284'],
                'is_cross':'false',
               'cross_country':''}
# Out:
# {'cross_country': '',
#  'is_cross': 'false',
#  'sm_seq_list[]': ['201611AM300002770',
#   '201610AM120001222',
#   '201610AM120001284']}

# %%
udn_par = {'sort':'weight',
           'key':'32303137303230f7f25da3a5ad05cd6cca',
           'keyword':'ps4 CUH'}
udn = get_page('https://shopping.udn.com/mall/cus/search/Search.do', parameters = udn_par)

# %%
def udn(search):
    
    def udn_pro_pages(search):
        
        result = get_page("http://shopping.udn.com/mall/cus/search/SearchAction.do?start=1&keyword=" 
                          + search + 
                          "&cid=&sort=weight&pickup=&minP=&maxP=&pageSize=20&key=32303137303230f7f25da1a0ab06cd67c0")
        udn_pages = list()
        for pages in result.find_all('li', {'class': 'pager_item'}):
            page = pages.text.replace('\n', '').replace('\r', '').replace('\t', '')
            udn_pages.append(page)
            if '下一頁' in udn_pages:
                udn_pages.remove('下一頁')
                
        return udn_pages
    
    udn_list = list()
    pages = udn_pro_pages(search)
    for page in pages:
        result = get_page("http://shopping.udn.com/mall/cus/search/SearchAction.do?start=" + str(page) + "&keyword=" 
                          + search + "&cid=&sort=weight&pickup=&minP=&maxP=&pageSize=20&key=32303137303230f7f25da1a0ab06cd67c0")
        for elements in result.find_all('li', {'class': 'lv3_item'}):
            for product in elements.find_all('p', {'class': 'pd_name'}):
                udn_list.append(product.text)
            for price in elements.find_all('p', {'class': 'pd_price'}):
                udn_list.append(price.text.replace('\n', '').replace('\t', '').replace('\r', '').replace('限時', ''))
                
    ####將結果變成list裡面包tuple(產品, 價格)####
    udn_display = list()
    a, b = 0, 2
    x = int(len(udn_list) / 2)
    while x != 0:
        udn_display.append(tuple(udn_list[a:b]))
        x -= 1
        a, b = b, b + 2
    ####將結果變成list裡面包tuple(產品, 價格)####
    
    return udn_display

# %%
udn('mizuno')
# Out:
# [('MIZUNO MAXIMIZER 18 男女慢跑鞋- 路跑 美津濃 白', '1037'),
#  ('MIZUNO WAVE RIDER 19 男慢跑鞋-2E- 寬楦 美津濃 藍紅白', '2600'),
#  ('(男)MIZUNO PRIMA VIVO 2慢跑鞋黑綠J1GG152703-', '990'),
#  ('Mizuno RUSH UP 2 AW 2016 秋冬新款 男慢路跑鞋 J1GA168403 (黑紅)', '1580'),
#  ('Mizuno 美津濃 男女款慢跑鞋 軍警鞋 工作鞋 學生鞋 (寬楦) K1GA170209', '1399'),
#  ('MIZUNO WAVE EMPEROR 皇速-男路跑鞋- 慢跑 美津濃 藍綠銀', '2613'),
#  ('MIZUNO WAVE EMPEROR 皇速-男路跑鞋- 慢跑 美津濃 黑芥末綠', '2613'),
#  ('MIZUNO 美津濃 MAXIMIZER 男款寬楦慢跑鞋 路跑鞋 輕量避震 運動鞋 @(K1GA170209)', '1580'),
#  ('Mizuno 美津濃 男女款慢跑鞋 軍警鞋 工作鞋 學生鞋 (寬楦) K1GA170010', '1499'),
#  ('(男)MIZUNO WAVE RIDER 19 2E慢跑鞋灰黑黃J1GC160409-', '2190'),
#  ('(男)MIZUNO WAVE RIDER 19慢跑鞋藍綠漸層J1GC160404-', '2190'),
#  ('MIZUNO 男排球短袖上衣-慢跑 路跑 T恤  眼鏡王 美津濃 丈青白', '626'),
#  ('MIZUNO WAVE RIDER 20 OSAKA -限量男慢跑鞋-美津濃 丈青黃', '3343'),
#  ('Mizuno 女休閒無袖背心 N2TA670309 (黑)', '620'),
#  ('MIZUNO 中性版 三分款路跑褲 慢跑褲 運動褲 羽球褲 桌球褲 排汗透氣 口袋設計 2件組(J2TB4A54)', '1300'),
#  ('MIZUNO 男短袖T恤 - 路跑 慢跑 健身 美津濃 藍橘', '446'),
# ...

# %%
a = get_page('http://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=4492052&Area=search&mdiv=403')

# %%
for i in a.find_all('ul', {'class':'prdPrice'}):
    print(i.text)
# Out:
# 市價12,090元
#
#
#               促銷價10,290元
#
#               賣貴通報

# %%
b = "http://www.momoshop.com.tw/mosearch/" + str(requests.utils.quote('ASUS ZenFone 3  ZE552KL 5.5吋4G LTE雙卡機 4G 64G版')) + ".html"
b
# Out:
# 'http://www.momoshop.com.tw/mosearch/ASUS%20ZenFone%203%20%20ZE552KL%205.5%E5%90%8B4G%20LTE%E9%9B%99%E5%8D%A1%E6%A9%9F%204G%2064G%E7%89%88.html'

# %%
# haha = get_page("http://www.momoshop.com.tw/mosearch/"+requests.utils.quote("【ASUS】ZenFone 3 ZE552KL 4G/64G 5.5吋 智慧型手機")+".html")
haha = get_page("http://www.momoshop.com.tw/mosearch/"+ requests.utils.quote("【MI】《小米手環 2》 運動必備組【含：保護貼+美國酷涼水壺】")+".html")

# %%
"http://www.momoshop.com.tw/mosearch/"+ requests.utils.quote("MI《小米手環 2》 運動必備組【含：保護貼+美國酷涼水壺】") +".html"
# Out:
# 'http://www.momoshop.com.tw/mosearch/MI%E5%B0%8F%E7%B1%B3%E6%89%8B%E7%92%B0%202%20%E9%81%8B%E5%8B%95%E5%BF%85%E5%82%99%E7%B5%84%E5%90%AB%EF%BC%9A%E4%BF%9D%E8%AD%B7%E8%B2%BC%2B%E7%BE%8E%E5%9C%8B%E9%85%B7%E6%B6%BC%E6%B0%B4%E5%A3%BA.html'

# %%
haha
# Out:
# <!DOCTYPE HTML>
# <html lang="zh">
# <head>
# <link href="/main/favicon.ico" rel="shortcut icon"/>
# <link href="/main/favicon.ico" rel="Bookmark"/>
# <link href="/main/favicon.ico" rel="icon" type="image/ico"/>
# <title>momo購物網</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="【MI】《小米手環 2》 運動必備組【含：保護貼+美國酷涼水壺】,momo購物網" name="Title"/>
# <meta content="momo購物網" name="Author"/>
# <meta content="momoshop,momo購物網" name="Subject"/>
# <meta content="momo購物網【MI】《小米手環 2》 運動必備組【含：保護貼+美國酷涼水壺】商品價格優惠便宜,種類規格齊全,值得推薦!" name="Description"/>
# <meta content="【MI】《小米手環 2》 運動必備組【含：保護貼+美國酷涼水壺】" name="Keywords"/>
# <meta content="Tradition Chinese" name="Language"/>
# <meta content="momoshop,momo購物網" name="Abstract"/>
# <meta content="momoshop,momo購物網" name="Copyright"/>
# <meta content="momoshop,momo購物網" name="Designer"/>
# <meta content="momoshop,momo購物網" name="Publisher"/>
# ...

# %%
# for i in haha.find_all('a', {'class': 'slog_4'}):
#     print(i['href'])
for i in haha.find_all('ul', {'class':'prdPrice'}):
    print(i.text)

# %%
requests.utils.unquote('%E5%B0%8F%E7%B1%B3%E6%89%8B%E7%92%B0-2-+-%E4%BF%9D%E8%AD%B7%E8%B2%BC-(-%E8%B4%88%EF%BC%9A%E7%BE%8E%E5%9C%8B%E9%85%B7%E6%B6%BC%E6%B0%B4%E5%A3%BA-)')
# Out:
# '小米手環-2-+-保護貼-(-贈：美國酷涼水壺-)'

# %%
# 'http://www.momoshop.com.tw/mosearch/' + requests.utils.quote('小米手環2保護貼贈：美國酷涼水壺') + '.html'
a = get_page('http://www.momoshop.com.tw/mosearch/' + requests.utils.quote('MI 小米手環 2  運動必備組 含：保護貼 美國酷涼水壺') + '.html')

# %%
a = get_page('http://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=4545437&Area=search&mdiv=403')
# a = get_page('http://www.momoshop.com.tw/goods/GoodsDetail.jsp?i_code=4492052&Area=search&mdiv=403')

# %%
# momo = list()
# for i in a.find_all('div', {'class': 'prdnoteArea'}):
#     momo.append(i.find('h1').text)
# if i.find_all('li', {'class': 'special'}):
#     for prices in i.find_all('li', {'class': 'special'}):
#         for price in prices.find_all('span'):
#             momo.append(price.text.replace(',', ''))
# else:
#     for price in i.find_all('span'):
#         momo.append(price.replace(',', ''))

# %%
b = '<!DOCTYPE HTML>\n<html prefix="og: http://ogp.me/ns#"><head><meta content="TEXT/HTML; CHARSET=UTF-8" http-equiv="Content-Type"/>\n<title>搜尋結果｜ETMall東森購物網</title>\n<meta content="no-cache" http-equiv="Pragma"/>\n<meta content="Yes" http-equiv="MSThemeCompatible"/>\n<meta content="1 days" name="revisit-after"/>\n<meta content="no-cache" http-equiv="Pragma"/>\n<meta content="no-store" http-equiv="Cache-Control"/>\n<meta content="0" http-equiv="expires"/>\n<meta content="IE=9; IE=8; IE=7" http-equiv="X-UA-Compatible"/>\n<script>\n\tvar ETU_opener = \'Y\';\n</script>\n<script>var FBrecord_opener = \'Y\';</script>\n<meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>\n<script>\r\nvar isUseNewImgPath = \'Y\';\r\nvar IsUseNewImageIP = \'media.etmall.com.tw/NXimg\';\r\n</script>\n<script type="text/javascript">\r\n(function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\r\n\r\n</script>\n<!-- Facebook Pixel Code --><script>!function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version=\'2.0\';n.queue=[];t=b.createElement(e);t.async=!0;t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,document,\'script\',\'//connect.facebook.net/en_US/fbevents.js\');fbq(\'init\', \'701110716660336\');fbq(\'track\', \'PageView\');</script><noscript><img height="1" src="https://www.facebook.com/tr?id=701110716660336&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript><!-- End Facebook Pixel Code -->\n<script>    (function() {    var _fbq = window._fbq || (window._fbq = []);    if (!_fbq.loaded) {    var fbds = document.createElement(\'script\');    fbds.async = true;    fbds.src = \'//connect.facebook.net/en_US/fbds.js\';    var s = document.getElementsByTagName(\'script\')[0];    s.parentNode.insertBefore(fbds, s);    _fbq.loaded = true;}    _fbq.push([\'addPixelId\', \'246268902232013\']);})();    window._fbq = window._fbq || [];    window._fbq.push([\'track\', \'PixelInitialized\', {}]);</script><noscript><img alt="" height="1" src="https://www.facebook.com/tr?id=246268902232013&amp;ev=NoScript" style="display:none" width="1"/></noscript>\n</head>\n<body class="BrandHomeBgSetting" id="store-0" style="margin:0;padding:0;">\n<xml id="DS_SessionContext" style="display:none;"><data><listcontrol><currentpage>0</currentpage><recordsperpage>0</recordsperpage><totalpages>0</totalpages></listcontrol></data></xml>\n<form id="XForm" method="post" name="XForm">\n<script>var analytics = true;</script>\n<script charset="UTF-8" language="Javascript" src="../Includes/jquery-1.4.4.js"></script>\n<script charset="UTF-8" language="Javascript" src="../Includes/PageClientEngine.js?ver=20170207160412"></script>\n<script language="Javascript">\n<!--\nSys_FixProtocol(true,false,80);\n//-->\n</script>\n<input id="XForm_Action" name="XForm_Action" type="hidden" value=""/>\n<input id="XForm_Sender" name="XForm_Sender" type="hidden" value=""/>\n<input id="XForm_Url" name="XForm_Url" type="hidden" value=""/>\n<input id="XForm_Params" name="XForm_Params" type="hidden" value=""/>\n</form>\n<script src="GetPersonalLogin.aspx"></script>\n<script>\r\n            var isCustomerLogined = "False";\r\n            var isUserLogined = \'False\';\r\n            var LoginPonta_Web_Switch = \'N\';\r\n\t\t\tvar E68_HttpLocationHref = location.href.split(\'://\')[1];\r\n\t\t\tvar E68_HttpLoginLink;\r\n\t\t\t\r\n\t\t\tif(location.host.toLowerCase() == \'localhost\')\r\n\t\t\t{\r\n\t\t\t\tE68_HttpLoginLink = \'http://\' + E68_HttpLocationHref.substring(0, E68_HttpLocationHref.split(\'?\')[0].lastIndexOf("/")) + \'/\';\r\n\t\t\t}\r\n\t\t\telse\r\n\t\t\t{\r\n\t\t\t\tE68_HttpLoginLink = \'https://\' + E68_HttpLocationHref.substring(0, E68_HttpLocationHref.split(\'?\')[0].lastIndexOf("/")) + \'/\';\r\n\t\t\t}\r\n\r\n            var getMsize = function(imgURL)\r\n            {\r\n                var MSize = \'\'\r\n            \r\n                if(imgURL.indexOf(\'NXimg\') == -1)\r\n                {\r\n                    var getGOOD_ID = imgURL.split(\'ProductImage/\')[1].split(\'/\')[0];\r\n                    //var MSize = checkHTTPSSL() +\'media.etmall.com.tw/ProductImage/\'+ getGOOD_ID +\'/\'+ getGOOD_ID +\'_ML.jpg\';\r\n                    MSize = getPdImg(getGOOD_ID, \'ML\');\r\n                }\r\n                else\r\n                {\r\n                    MSize = imgURL;\r\n                }\r\n                return MSize;\r\n            }\r\n            \r\n            var SetNotLogined =function(){}\r\n            var SetLogined =function(){}\r\n        </script>\n<script>\n\tvar E68_HeaderBagEncryptKey = \'\';\n        var EncryptKey = E68_HeaderBagEncryptKey;\n</script>\n<link href="../R6CSS/fancybox.message.css?version=20170207160412" media="screen" rel="stylesheet" type="text/css"/>\n<link href="../R6CSS/common.css?version=20170207160412" media="screen" rel="stylesheet" type="text/css"/>\n<link href="../E68CSS/E68Basic.css?version=20170207160412" media="screen" rel="stylesheet" type="text/css"/>\n<script src="../E68Includes/E68Common.js?version=20170207160412" type="text/javascript"></script>\n<!-- CONTENT_HTML_ CT_E68_singleItemTemplate-BEGIN -->\n<!-- CONTENT_HTML_ CT_E68_singleItemTemplate-END -->\n<script>try{document.getElementById("CT_E68_singleItemTemplate").innerHTML=TransDataSource(DS_SessionContext, document.getElementById("CT_E68_singleItemTemplate").innerHTML);}catch(e){}\n</script><script id="jt_TopNaviCartListBagEmpty" type="text/x-jquery-tmpl">\n    <li class="WishListBagEmpty">您的購物車內目前沒有商品。</li>\n</script>\n<script id="jt_TopNaviWishListBagEmpty" type="text/x-jquery-tmpl">\n    <li class="WishListBagEmpty">您的追蹤清單內目前沒有商品。</li>\n</script>\n<script id="jt_TopNaviCampareListBagEmpty" type="text/x-jquery-tmpl">\n    <li class="WishListBagEmpty">您的比較清單內目前沒有商品。</li>\n</script>\n<script id="jt_TopNaviProductReviewEmpty" type="text/x-jquery-tmpl">\n    <li class="WishListBagEmpty">您目前沒有瀏覽紀錄。</li>\n</script>\n<script id="jt_TopNaviCartListBag" type="text/x-jquery-tmpl">\n\t<li>\t\n\t\t<div class="single-item cart-item-list clearfix" id="CartProduct_${ProductVariantSKU}" productvariantsku="${ProductVariantSKU}" productsku="${ProductSKU}" storeid="${StoreID}" categoryid="${CategoryID}">\n            <i class="inline-block member-navi-bg ico-remove"></i>\n\t\t\t<div class="GOOD-Img"><a href="ProductDetail.aspx?StoreID=${StoreID}&CategoryID=${CategoryID}&ProductSKU=${ProductSKU}"><img src="${GOODIDtoMediaSrc(ProductSKU)}" class="setImgSrc" width="120" height="120"></a></div>\n\t\t\t<ul>\n\t\t\t\t<li class="GOOD-NM">${DoubleToSingle(ProductName)}</li>\n\t\t\t\t{{if Bundle_CD == \'555\'}}\n\t\t\t\t\t<li class="GOOD-PRC"><em>得易Ponta卡兌換點數：</em><br><b>${Sys_FormatNumber(UsePoint)}</b>點</li>\n\t\t\t\t{{else}}\n\t\t\t\t\t<li class="GOOD-PRC">$<b>${Sys_FormatNumber(Price)}</b></li>\n\t\t\t\t{{/if}}\n\t\t\t\t\n\t\t\t</ul>\n        </div>\n\t</li>\n</script>\n<script id="jt_TopNaviProductReviewBag" type="text/x-jquery-tmpl">\n    <li>{{tmpl($item.data) "#jt_TopNaviSingleItem"}}</li>\n</script>\n<script id="jt_TopNaviSingleItem" type="text/x-jquery-tmpl">\n        <div class="single-item cart-item-list clearfix" id="CartProduct_${ProductVariantSKU}" productvariantsku="${ProductVariantSKU}" productsku="${ProductSKU}" storeid="${StoreID}" categoryid="${CategoryID}">\n            <i class="inline-block member-navi-bg ico-remove"></i>\n            {{if ProductOnline == \'Y\'}}\n                {{tmpl($item.data) "#jt_TopNaviSingleItemOnLine"}}\n            {{else}}\n                {{tmpl($item.data) "#jt_TopNaviSingleItemOffLine"}}\n            {{/if}}\n        </div>\n</script>\n<script id="jt_TopNaviSingleItemOnLine" type="text/x-jquery-tmpl">\n        <div class="GOOD-Img"><a href="ProductDetail.aspx?StoreID=${StoreID}&CategoryID=${CategoryID}&ProductSKU=${ProductSKU}"><img src="${GOODIDtoMediaSrc(ProductSKU)}" class="setImgSrc" width="120" height="120"></a></div>\n        <ul>\n            <li class="GOOD-NM">${DoubleToSingle(ProductName)}</li>\n\t\t\t{{if Bundle_CD == \'555\'}}\n\t\t\t\t<li class="GOOD-PRC"><em>得易Ponta卡兌換點數：</em><br><b>${Sys_FormatNumber(UsePoint)}</b>點</li>\n\t\t\t\t<li class="GOOD-Cart">\n\t\t\t\t\t<input id="ProductChecked_${ProductVariantSKU}" name="ProductChecked_${ProductVariantSKU}" type="checkbox" name="a"> <label for="ProductChecked_${ProductVariantSKU}">立即兌換</label>\n\t\t\t\t</li>\n\t\t\t{{else}}\n\t\t\t\t<li class="GOOD-PRC">$<b>${Sys_FormatNumber(Price)}</b></li>\n\t\t\t\t<li class="GOOD-Cart">\n\t\t\t\t\t<input id="ProductChecked_${ProductVariantSKU}" name="ProductChecked_${ProductVariantSKU}" type="checkbox" name="a"> <label for="ProductChecked_${ProductVariantSKU}">立即結帳</label>\n\t\t\t\t</li>\n\t\t\t{{/if}}\n        </ul>\n</script>\n<script id="jt_TopNaviSingleItemOffLine" type="text/x-jquery-tmpl">\n        <div class="GOOD-Img"><a href="ProductDetail.aspx?StoreID=${StoreID}&CategoryID=${CategoryID}&ProductSKU=${ProductSKU}"><img src="../R6Images/shoppingBag/ProductNotOnLine.gif" width="120" height="120"></a></div>\n        <ul>\n            <li class="GOOD-NM">${DoubleToSingle(ProductName)}</li>\n\t\t\t{{if Bundle_CD == \'555\'}}\n\t\t\t\t<li class="GOOD-PRC"><em>得易Ponta卡兌換點數：</em><br><b>${Sys_FormatNumber(UsePoint)}</b>點</li>\n\t\t\t\t<li class="GOOD-Cart">\n\t\t\t\t\t<input type="checkbox" class="inputM" disabled="disabled"> 立即兌換</label>\n\t\t\t\t</li>\n\t\t\t{{else}}\n\t\t\t\t<li class="GOOD-PRC">$<b>${Sys_FormatNumber(Price)}</b></li>\n\t\t\t\t<li class="GOOD-Cart">\n\t\t\t\t\t<input type="checkbox" class="inputM" disabled="disabled"> 立即結帳\n\t\t\t\t</li>\n\t\t\t{{/if}}\n        </ul>\n</script>\n<script id="jt_TopNaviWishListBag" type="text/x-jquery-tmpl">\n    <li>{{tmpl($item.data) "#jt_TopNaviWishSingleItem"}}</li>\n</script>\n<script id="jt_TopNaviWishSingleItem" type="text/x-jquery-tmpl">\n        <div class="single-item cart-item-list clearfix" id="CartProduct_${ProductVariantSKU}" productvariantsku="${ProductVariantSKU}" productsku="${ProductSKU}" storeid="${StoreID}" categoryid="${CategoryID}">\n            <i class="inline-block member-navi-bg ico-remove"></i>\n            {{if ProductOnline == \'Y\'}}\n                {{tmpl($item.data) "#jt_TopNaviWishSingleItemOnLine"}}\n            {{else}}\n                {{tmpl($item.data) "#jt_TopNaviWishSingleItemOffLine"}}\n            {{/if}}\n        </div>\n</script>\n<script id="jt_TopNaviWishSingleItemOnLine" type="text/x-jquery-tmpl">\n        <div class="GOOD-Img"><a href="ProductDetail.aspx?StoreID=${StoreID}&CategoryID=${CategoryID}&ProductSKU=${ProductSKU}"><img src="${GOODIDtoMediaSrc(ProductSKU)}" class="setImgSrc" width="120" height="120"></a></div>\n        <ul>\n            <li class="GOOD-NM">${DoubleToSingle(ProductName)}</li>\n            <li class="GOOD-PRC">$<b>${Sys_FormatNumber(Price)}</b></li>\n            <li class="GOOD-Cart">\n                <input id="ProductChecked_${ProductVariantSKU}" name="ProductChecked_${ProductVariantSKU}" type="checkbox" name="a"> <label for="ProductChecked_${ProductVariantSKU}">立即結帳</label>\n            </li>\n        </ul>\n</script>\n<script id="jt_TopNaviWishSingleItemOffLine" type="text/x-jquery-tmpl">\n        <div class="GOOD-Img"><a href="ProductDetail.aspx?StoreID=${StoreID}&CategoryID=${CategoryID}&ProductSKU=${ProductSKU}"><img src="../R6Images/shoppingBag/ProductNotOnLine.gif" width="120" height="120"></a></div>\n        <ul>\n            <li class="GOOD-NM">${DoubleToSingle(ProductName)}</li>\n            <li class="GOOD-PRC">＄${Sys_FormatNumber(Price)}</li>\n            <li class="GOOD-Cart">\n                <input type="checkbox" class="inputM" disabled="disabled"> 立即結帳\n            </li>\n        </ul>\n</script>\n<script id="jt_E68LeftCategoryBar" type="text/x-jquery-tmpl">\n    {{if setLimitPromoCategoryArray.length > 0}}\n        {{tmpl($item.data) "#jt_E68LeftCategoryBar_promo"}}\n    {{/if}}\n    <div class="store-category clearfix">\n        <div class="section-title">\n            <i class="block member-navi-bg ico-cate"></i>\n        </div>\n        <div class="section-lists">\n            <div class="open-category">\n                {{if setNowLevelCategoryInfo.Hiline == \'N\' && setNowLevelCategoryInfo.Hidden != \'Y\'}}\n                    <a class="cate-level-1 ${GARecord} odd Brand-cate-level-1-odd " GA_EventName="store${storeID}_Home" GA_EventType="G1" href="${setNowLevelCategoryInfo.URL}"><span class="cate-level-1-name">${setNowLevelCategoryInfo.Name}</span> <i class="inline-block sprite-image ico-storeCate-arrow"></i></a>\n\t\t\t\t\t{{tmpl($item.data) "#jt_E68LeftCategoryBar_levelTwo"}}\n                {{/if}}\n            </div>\n\t\t\t\n            <div class="other-category">\n                {{each setLevelOneCategoryArray}}\n                {{if $index % 2 == 0}}\n\t\t\t\t\t\t<a href="${URL}" class="cate-level-1 Brand-cate-level-1-odd ${GARecord} ${ClassStyle}" GA_EventName="store${storeID}_Home" GA_EventType="G${$index + 1}" rel="cateID_${ID}"><span class="cate-level-1-name">${Name}</span><i class="inline-block sprite-image ico-storeCate-arrow"></i></a>\n\t\t\t\t{{else}}\n                        <a href="${URL}" class="cate-level-1 Brand-cate-level-1-even ${GARecord} ${ClassStyle}" GA_EventName="store${storeID}_Home" GA_EventType="G${$index + 1}" rel="cateID_${ID}"><span class="cate-level-1-name">${Name}</span><i class="inline-block sprite-image ico-storeCate-arrow"></i></a>\n                {{/if}}\n\t\t\t\t{{/each}}\n            </div>\n\t\t\t\n        </div>\n    </div>\n</script>\n<script id="jt_E68LeftCategoryBar_promo" type="text/x-jquery-tmpl">\n    <div class="promo-category clearfix">\n        <div class="section-title">\n            <i class="block member-navi-bg ico-cate"></i>\n            {{if setPromoCategoryArray.length > 5}}\n                {{tmpl($item.data) "#jt_E68LeftCategoryBar_promo_more"}}\n            {{/if}}\n        </div>\n        <div class="section-lists">\n            \n\t\t\t{{if setNowLevelCategoryInfo.Hiline == \'Y\' && setNowLevelCategoryInfo.Hidden != \'Y\' && setNowLevelCategoryInfo.HIGHLIGHT_TYPE == \'0\'}}\n\t\t\t\t<div class="open-categorysp openDivSP">\n\t\t\t\t\t<a class="cate-level-1 ${GARecord} ${ClassStyle} openSP" GA_EventName="store${storeID}_Home" A_EventType="K1" cateID="${ID}" href="${setNowLevelCategoryInfo.URL}"><span class="cate-level-1-name">${setNowLevelCategoryInfo.Name}</span></a>\n\t\t\t\t\t{{tmpl($item.data) "#jt_E68LeftCategoryBar_levelTwo"}}\n\t\t\t\t</div>\n\t\t\t {{else}}\n\t\t\t\t {{if setNowLevelCategoryInfo.Hiline == \'Y\' && setNowLevelCategoryInfo.Hidden != \'Y\'}}\n\t\t\t\t <div class="open-categorysp openDiv">\n\t\t\t\t\t<a class="cate-level-1 ${GARecord} ${ClassStyle} open" GA_EventName="store${storeID}_Home" A_EventType="K1" cateID="${ID}" href="${setNowLevelCategoryInfo.URL}"><span class="cate-level-1-name">${setNowLevelCategoryInfo.Name}</span></a>\n\t\t\t\t\t{{tmpl($item.data) "#jt_E68LeftCategoryBar_levelTwo"}}\n\t\t\t\t</div>\n\t\t\t\t{{/if}}\n\t\t\t{{/if}}\n            \n            <div cateID="${ID}" class="other-category">\n            <div class = "highlightup">\n            {{each setLimitPromoCategoryArray}}\n\t\t\t{{if ClassStyle ==\'HIGHLIGHTUP\'}}\n\t\t\t\n                <a class="${GARecord} ${ClassStyle}" GA_EventName="store${storeID}_Home" GA_EventType="K${$index + 1}"href="${URL}">${Name}</a>\n\t\t\t{{/if}}\t\n            {{/each}}\n\t\t\t</div>\n\t\t\t<div class = "highlightdown">\n            {{each setLimitPromoCategoryArray}}\n\t\t\t{{if ClassStyle ==\'HIGHLIGHTDOWN\'}}\n\t\t\t\n                <a class="${GARecord} ${ClassStyle}" GA_EventName="store${storeID}_Home" GA_EventType="K${$index + 1}"href="${URL}">${Name}</a>\n\t\t\t{{/if}}\t\n            {{/each}}\n\t\t\t</div>\n            </div>\n        </div>\n    </div>\n</script>\n<script id="jt_E68NewLeftCategoryBar" type="text/x-jquery-tmpl">\n    {{if setLimitPromoCategoryArray.length > 0}}\n        {{tmpl($item.data) "#jt_E68NewLeftCategoryBar_promo"}}\n    {{/if}}\n    <div class="store-category clearfix">\n        <div class="section-title">\n            <i class="block member-navi-bg ico-cate"></i>\n        </div>\n        <div class="section-lists">\n            <div class="open-category">\n\t\t\t\t{{if setNowLevelCategoryInfo.ID != \'79014\'}}\n\t\t\t\t\t{{if setNowLevelCategoryInfo.Hiline == \'N\' && setNowLevelCategoryInfo.Hidden != \'Y\'}}\n\t\t\t\t\t\t<a class="cate-level-1 ${GARecord} odd Brand-cate-level-1-odd " GA_EventName="store${storeID}_Home" GA_EventType="G1" cateID="${setNowLevelCategoryInfo.ID}" parentID="${storeID}" href="${setNowLevelCategoryInfo.URL}"><span class="cate-level-1-name">${setNowLevelCategoryInfo.Name}</span> <i class="inline-block sprite-image ico-storeCate-arrow"></i></a>\n\t\t\t\t\t\t{{tmpl($item.data) "#jt_E68LeftCategoryBar_levelTwo_MoveToTop"}}\n\t\t\t\t\t\t{{tmpl($item.data) "#jt_E68LeftCategoryBar_levelTwo"}}\n\t\t\t\t\t{{/if}}\n\t\t\t\t{{/if}}\n            </div>\n            <div class="other-category">\n                {{each setLevelOneCategoryArray}}\n                        <a href="${URL}" class="cate-level-1 ${GARecord} ${ClassStyle}" GA_EventName="store${storeID}_Home" GA_EventType="G${$index + 1}" cateID="${setNowLevelCategoryInfo.ID}" parentID="${storeID}" rel="cateID_${ID}"><span class="cate-level-1-name">${Name}</span><i class="inline-block sprite-image ico-storeCate-arrow"></i></a>\n                {{/each}}\n            </div>\n        </div>\n    </div>\n</script>\n<script id="jt_E68NewLeftCategoryBar_promo" type="text/x-jquery-tmpl">\n    <div class="promo-category clearfix">\n        <div class="section-title">\n            <i class="block member-navi-bg ico-cate"></i>\n            {{if setPromoCategoryArray.length > 5}}\n                {{tmpl($item.data) "#jt_E68LeftCategoryBar_promo_more"}}\n            {{/if}}\n        </div>\n        <div class="section-lists">\n\t\t\t{{if setNowLevelCategoryInfo.Hiline == \'Y\' && setNowLevelCategoryInfo.Hidden != \'Y\' && setNowLevelCategoryInfo.HIGHLIGHT_TYPE != \'0\'}}\n\t\t\t\t<div class="open-categorysp openDiv">\n\t\t\t\t\t<a class="cate-level-1 ${GARecord} ${ClassStyle} open" GA_EventName="store${storeID}_Home" A_EventType="K1" cateID="${ID}" href="${setNowLevelCategoryInfo.URL}"><span class="cate-level-1-name">${setNowLevelCategoryInfo.Name}</span></a>\n\t\t\t\t\t{{tmpl($item.data) "#jt_E68LeftCategoryBar_levelTwo"}}\n\t\t\t\t</div>\n\t\t\t{{/if}}\n\n\t\t\t{{each setLimitPromoCategoryArray}}\n\t\t\t\t{{if Hiline == \'Y\' && HIGHLIGHT_TYPE != \'0\'}}\n\t\t\t\t<div cateID="${ID}" class="other-category">\n\t\t\t\t\t<a class="${GARecord} ${ClassStyle}" GA_EventName="store${storeID}_Home" GA_EventType="K${$index + 1}"href="${URL}">${Name}</a>\n\t\t\t\t</div>\n\t\t\t\t{{/if}}\n            {{/each}}\n\t\t\t\n\t\t\t{{if setNowLevelCategoryInfo.Hiline == \'Y\' && setNowLevelCategoryInfo.Hidden != \'Y\' && setNowLevelCategoryInfo.HIGHLIGHT_TYPE == \'0\'}}\n\t\t\t\t<div class="open-categorysp openDivSP">\n\t\t\t\t\t<a class="cate-level-1 ${GARecord} ${ClassStyle} openSP" GA_EventName="store${storeID}_Home" A_EventType="K1" cateID="${ID}" href="${setNowLevelCategoryInfo.URL}"><span class="cate-level-1-name">${setNowLevelCategoryInfo.Name}</span></a>\n\t\t\t\t\t{{tmpl($item.data) "#jt_E68LeftCategoryBar_levelTwo"}}\n\t\t\t\t</div>\n\t\t\t{{/if}}\n\t\t\t\n\t\t\t{{each setLimitPromoCategoryArray}}\n\t\t\t\t{{if Hiline == \'Y\' && HIGHLIGHT_TYPE == \'0\'}}\n\t\t\t\t<div cateID="${ID}" class="other-category">\n\t\t\t\t\t<a class="${GARecord} ${ClassStyle}" GA_EventName="store${storeID}_Home" GA_EventType="K${$index + 1}"href="${URL}">${Name}</a>\n\t\t\t\t</div>\n\t\t\t\t{{/if}}\n            {{/each}}\n            \n        </div>\n    </div>\n</script>\n<script id="jt_E68LeftCategoryBar_promo_more" type="text/x-jquery-tmpl">\n        <span class="more">更多組合<i class="inline-block member-navi-bg ico-promo-cate-more"></i></span>\n        <div class="section-lists-more">\n            {{each setPromoCategoryArray}}\n                <a href="${URL}">${Name}</a>\n            {{/each}}\n        </div>\n</script>\n<script>\n    var checkLastNode = function(lastNode)\n    {\n        if(lastNode.toUpperCase() == \'Y\')\n        {\n            return "-last";\n        }\n        else\n        {\n            return "";\n        }\n    }\n</script>\n<!--將該分類移至最上方-->\n<script id="jt_E68LeftCategoryBar_levelTwo_MoveToTop" type="text/x-jquery-tmpl">\n        {{each(m) setNowLevelCategoryInfo.L1}}\n\t\t\t{{if setNowLevelCategoryInfo.L1[m].cateid}}\n\t\t\t\t{{if setNowLevelCategoryInfo.moveToTop_CateID == cateid}}\n\t\t\t\n\t\t\t\t\t\t{{if TreeNext}}\n\t\t\t\t\t\t\t{{if TreeNext == \'false\'}}\n\t\t\t\t\t\t\t\t<a href="${URL}" cateID="${cateid}" class="cate-level-2-nosub{{html checkLastNode(LASTNODE) }}"><span class="cate-level-2-name">${Name}</span></a>\n\t\t\t\t\t\t\t{{else}}\n\t\t\t\t\t\t\t\t{{if setNowLevelCategoryInfo.showL2 == \'false\'}}\n\t\t\t\t\t\t\t\t\t<a href="${URL}" cateID="${cateid}" class="cate-level-2-hassub-close{{html checkLastNode(LASTNODE) }} switchCate"><span class="cate-level-2-name">${Name}</span></a>\n\t\t\t\t\t\t\t\t{{else}}\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t{{if L2}}\n\t\t\t\t\t\t\t\t\t\t\t<a href="${URL}" cateID="${cateid}" class="cate-level-2-hassub-close{{html checkLastNode(LASTNODE) }} switchCate"><ins></ins><span class="cate-level-2-name">${Name}</span></a>\n\t\t\t\t\t\t\t\t\t\t\t{{if L2.length > 0}}\n\t\t\t\t\t\t\t\t\t\t\t\t{{each(i) L2}}\n                                                    {{if cateid != \'91070\'}}\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t<a href="${URL}" cateID="${cateid}" parentID="${setNowLevelCategoryInfo.L1[m].cateid}" class="wowowowo cate-level-3-hassub{{html checkLastNode(LASTNODE) }}" style="${setNowLevelCategoryInfo.displayHideL2}"><span class="cate-level-3-name">${Name}</span></a>\n                                                    {{/if}}\n                                                {{/each}}\n\t\t\t\t\t\t\t\t\t\t\t{{else}}\n\t\t\t\t\t\t\t\t\t\t\t\t{{if LASTNODE == \'N\'}}\n                                                    {{if cateid != \'91070\'}}\n                                                        <a href="${L2.URL}" cateID="${cateid}" parentID="${setNowLevelCategoryInfo.L1[m].cateid}" class="wowowowo cate-level-3-hassub-last" style="${setNowLevelCategoryInfo.displayHideL2}"><span class="cate-level-3-name">${L2.Name}</span></a>\n                                                    {{/if}}\n                                                {{else}}\n                                                    {{if cateid != \'91070\'}}\n                                                        <a href="${L2.URL}" cateID="${cateid}" parentID="${setNowLevelCategoryInfo.L1[m].cateid}" class="wowowowo cate-level-3-nosub{{html checkLastNode(LASTNODE) }}" style="${setNowLevelCategoryInfo.displayHideL2}"><span class="cate-level-3-name">${L2.Name}</span></a>\n                                                    {{/if}}\n                                                {{/if}}\n\t\t\t\t\t\t\t\t\t\t\t{{/if}}\n\t\t\t\t\t\t\t\t\t\t{{else}}\n\t\t\t\t\t\t\t\t\t\t\t<a href="${URL}" cateID="${cateid}" class="cate-level-2-hassub-close{{html checkLastNode(LASTNODE) }} switchCate"><ins></ins><span class="cate-level-2-name">${Name}</span></a>\n\t\t\t\t\t\t\t\t\t\t{{/if}}\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t{{/if}}\n\t\t\t\t\t\t\t{{/if}}\n\t\t\t\t\t\t{{/if}}\n\t\t\t\t\n\t\t\t\t{{/if}}\n\t\t\t{{/if}}\n        {{/each}}\n</script>\n<script id="jt_E68LeftCategoryBar_levelTwo" type="text/x-jquery-tmpl">\n        {{each(m) setNowLevelCategoryInfo.L1}}\n\t\t\n\t\t\t{{if setNowLevelCategoryInfo.L1[m].cateid}}\n\t\t\t\t\t{{if setNowLevelCategoryInfo.moveToTop_CateID != cateid}}\n\t\t\t\t\t\t\t{{if TreeNext}}\n\t\t\t\t\t\t\t\t{{if TreeNext == \'false\'}}\n\t\t\t\t\t\t\t\t\t<a href="${URL}" cateID="${cateid}" class="cate-level-2-nosub{{html checkLastNode(LASTNODE) }}"><span class="cate-level-2-name">${Name}</span></a>\n\t\t\t\t\t\t\t\t{{else}}\n\t\t\t\t\t\t\t\t\t{{if setNowLevelCategoryInfo.showL2 == \'false\'}}\n\t\t\t\t\t\t\t\t\t\t<a href="${URL}" cateID="${cateid}" class="cate-level-2-hassub-close{{html checkLastNode(LASTNODE) }} switchCate"><span class="cate-level-2-name">${Name}</span></a>\n\t\t\t\t\t\t\t\t\t{{else}}\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t{{if L2}}\n\t\t\t\t\t\t\t\t\t\t\t\t<a href="${URL}" cateID="${cateid}" class="cate-level-2-hassub-close{{html checkLastNode(LASTNODE) }} switchCate"><ins></ins><span class="cate-level-2-name">${Name}</span></a>\n\t\t\t\t\t\t\t\t\t\t\t\t{{if L2.length > 0}}\n\t\t\t\t\t\t\t\t\t\t\t\t\t{{each(i) L2}}\n                                                        {{if cateid != \'91070\'}}\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<a href="${URL}" cateID="${cateid}" parentID="${setNowLevelCategoryInfo.L1[m].cateid}" class="wowowowo cate-level-3-hassub{{html checkLastNode(LASTNODE) }}" style="${setNowLevelCategoryInfo.displayHideL2}"><span class="cate-level-3-name">${Name}</span></a>\n                                                        {{/if}}\n                                                    {{/each}}\n\t\t\t\t\t\t\t\t\t\t\t\t{{else}}\n\t\t\t\t\t\t\t\t\t\t\t\t\t{{if LASTNODE == \'N\'}}\n                                                        {{if cateid != \'91070\'}}\n                                                            <a href="${L2.URL}" cateID="${cateid}" parentID="${setNowLevelCategoryInfo.L1[m].cateid}" class="wowowowo cate-level-3-hassub-last" style="${setNowLevelCategoryInfo.displayHideL2}"><span class="cate-level-3-name">${L2.Name}</span></a>\n                                                        {{/if}}\n                                                    {{else}}\n                                                        {{if cateid != \'91070\'}}\n                                                            <a href="${L2.URL}" cateID="${cateid}" parentID="${setNowLevelCategoryInfo.L1[m].cateid}" class="wowowowo cate-level-3-nosub{{html checkLastNode(LASTNODE) }}" style="${setNowLevelCategoryInfo.displayHideL2}"><span class="cate-level-3-name">${L2.Name}</span></a>\n                                                        {{/if}}\n                                                    {{/if}}\n\t\t\t\t\t\t\t\t\t\t\t\t{{/if}}\n\t\t\t\t\t\t\t\t\t\t\t{{else}}\n\t\t\t\t\t\t\t\t\t\t\t\t<a href="${URL}" cateID="${cateid}" class="cate-level-2-hassub-close{{html checkLastNode(LASTNODE) }} switchCate"><ins></ins><span class="cate-level-2-name">${Name}</span></a>\n\t\t\t\t\t\t\t\t\t\t\t{{/if}}\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t{{/if}}\n\t\t\t\t\t\t\t\t{{/if}}\n\t\t\t\t\t\t\t{{/if}}\n\t\t\t\t\t{{/if}}\n\t\t\t{{else}}\n\t\t\t\n\t\t\t\t\t\t\t{{if TreeNext}}\n\t\t\t\t\t\t\t\t{{if TreeNext == \'false\'}}\n\t\t\t\t\t\t\t\t\t<a href="${URL}" cateID="${cateid}" class="cate-level-2-nosub{{html checkLastNode(LASTNODE) }}"><span class="cate-level-2-name">${Name}</span></a>\n\t\t\t\t\t\t\t\t{{else}}\n\t\t\t\t\t\t\t\t\t{{if setNowLevelCategoryInfo.showL2 == \'false\'}}\n\t\t\t\t\t\t\t\t\t\t<a href="${URL}" cateID="${cateid}" class="cate-level-2-hassub-close{{html checkLastNode(LASTNODE) }} switchCate"><span class="cate-level-2-name">${Name}</span></a>\n\t\t\t\t\t\t\t\t\t{{else}}\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t{{if L2}}\n\t\t\t\t\t\t\t\t\t\t\t\t<a href="${URL}" cateID="${cateid}" class="cate-level-2-hassub-close{{html checkLastNode(LASTNODE) }} switchCate"><ins></ins><span class="cate-level-2-name">${Name}</span></a>\n\t\t\t\t\t\t\t\t\t\t\t\t{{if L2.length > 0}}\n\t\t\t\t\t\t\t\t\t\t\t\t\t{{each(i) L2}}\n                                                        {{if cateid != \'91070\'}}\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<a href="${URL}" cateID="${cateid}" parentID="${setNowLevelCategoryInfo.L1[m].cateid}" class="wowowowo cate-level-3-hassub{{html checkLastNode(LASTNODE) }}" style="${setNowLevelCategoryInfo.displayHideL2}"><span class="cate-level-3-name">${Name}</span></a>\n                                                        {{/if}}\n                                                    {{/each}}\n\t\t\t\t\t\t\t\t\t\t\t\t{{else}}\n\t\t\t\t\t\t\t\t\t\t\t\t\t{{if LASTNODE == \'N\'}}\n                                                        {{if cateid != \'91070\'}}\n                                                            <a href="${L2.URL}" cateID="${cateid}" parentID="${setNowLevelCategoryInfo.L1[m].cateid}" class="wowowowo cate-level-3-hassub-last" style="${setNowLevelCategoryInfo.displayHideL2}"><span class="cate-level-3-name">${L2.Name}</span></a>\n                                                        {{/if}}\n                                                    {{else}}\n                                                        {{if cateid != \'91070\'}}\n                                                            <a href="${L2.URL}" cateID="${cateid}" parentID="${setNowLevelCategoryInfo.L1[m].cateid}" class="wowowowo cate-level-3-nosub{{html checkLastNode(LASTNODE) }}" style="${setNowLevelCategoryInfo.displayHideL2}"><span class="cate-level-3-name">${L2.Name}</span></a>\n                                                        {{/if}}\n                                                    {{/if}}\n\t\t\t\t\t\t\t\t\t\t\t\t{{/if}}\n\t\t\t\t\t\t\t\t\t\t\t{{else}}\n\t\t\t\t\t\t\t\t\t\t\t\t<a href="${URL}" cateID="${cateid}" class="cate-level-2-hassub-close{{html checkLastNode(LASTNODE) }} switchCate"><ins></ins><span class="cate-level-2-name">${Name}</span></a>\n\t\t\t\t\t\t\t\t\t\t\t{{/if}}\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t{{/if}}\n\t\t\t\t\t\t\t\t{{/if}}\n\t\t\t\t\t\t\t{{/if}}\n\t\t\t\n\t\t\t{{/if}}\n\t\t\t\n        {{/each}}\n</script>\n<script id="jt_E68StoreHomeLeftCategory" type="text/x-jquery-tmpl">\n        <div class="LcateMenu cateID_${cateID} clearfix">\n            <ul class="clearfix">\n                {{each(i,v) L2}}\n                <li>\n                    <h4>\n                    {{if L2.URL}}\n                        <a class="tit" href="${URL}">${Name}</a>\n                        <a href="${URL}"><i class="inline-block sprite-image ico-cate-more"></i></a>\n                    {{else}}\n                        <a class="tit" href="#">${Name}</a>\n                        <a href="#"><i class="inline-block sprite-image ico-cate-more"></i></a>\n                    {{/if}}\n                    </h4>\n                    <div class="sub">\n                        {{if L3}}\n                        {{each(i,v) ConverCont(L3)}}\n\t\t\t\t\t\t\t{{if L3[i].URL}}\n\t\t\t\t\t\t\t\t<a href="${URL}">${Name}</a>\n\t\t\t\t\t\t\t{{else}}\n\t\t\t\t\t\t\t\t<a href="#">${Name}</a>\n\t\t\t\t\t\t\t{{/if}}\n                        {{/each}}\n                        {{/if}}\n                    </div>\n                </li>\n                {{/each}}\n            </ul>\n        </div>\n</script>\n<script>\n    var checkHTTPSSL = function()\n    {\n        /*\n\t\tif(document.location.protocol == \'https:\')\n        {\n            return "https://";\n        }\n        else\n        {\n            return "http://";\n        }\n\t\t*/\n\t\t\n\t\treturn "//";\n    }\n</script>\n<script>\n    var checkProductItemLabel = function(SHOWLABEL)\n    {\n        switch(SHOWLABEL)\n        {\n            // 0：不顯示Label\n            case (\'0\'):{\n                return "ico-label-none";\n                break;\n            };\n            // 1：顯示"集購"Label\n            case (\'1\'):{\n                return "ico-label-gbSale";\n                break;\n            };\n            // 2：顯示"好康"Label\n            case (\'2\'):{\n                return "ico-label-Hokang";\n                break;\n            };\n            // 3：顯示"熱銷"Label\n            case (\'3\'):{\n                return "ico-label-hotSale";\n                break;\n            };\n            // 4：顯示"新品"Label\n            case (\'4\'):{\n                return "ico-label-newItem";\n                break;\n            };\n            // 5：顯示"人氣"Label\n            case (\'5\'):{\n                return "ico-label-hotView";\n                break;\n            };\n            // 6：顯示"任選"Label\n            case (\'6\'):{\n                return "ico-label-anybuy";\n                break;\n            };\n            \n            default:{\n                return "ico-label-none";\n                break;\n            };\n            \n        };\n    }\n</script>\n<script>\n\tvar checkProductItemWouldAddToCart = function(ONLINE, GOOD_ID, BUNDLE_CD, isKit, isPontaVoucher, getStoreID, getCategoryID)\n\t{\n\t\tif(isKit == \'Y\')\n\t\t{\n\t\t\tif(ONLINE == \'1\' || ONLINE == \'Y\')\n\t\t\t{\n\t\t\t\treturn \'<a class="btn_Gd_compare" href="ProductDetail.aspx?StoreID=\'+ getStoreID +\'&CategoryID=\'+ getCategoryID +\'&ProductSKU=\'+ GOOD_ID +\'" GOODID="\'+ GOOD_ID +\'">加入購物車</a>\';\n\t\t\t}\n\t\t\telse\n\t\t\t{\n\t\t\t\treturn \'<a class="btn_Gd_compare" onclick="sys_KiTcantAddToShoppingCar(\\\'\'+ GOOD_ID +\'\\\')">加入購物車</a>\';\n\t\t\t}\n\t\t}\n\t\telse\n\t\t{\n\t\t\t//if(BUNDLE_CD != \'555\')\n\t\t\t//{\n\t\t\t\treturn \'<a class="btn_Gd_compare" onclick="sys_AddToShoppingCar(\\\'\'+ GOOD_ID +\'\\\')">加入購物車</a>\';\n\t\t\t//}\n\t\t}\n\t}\n</script>\n<script>\n    var checkProductItemOnline = function(ONLINE, GOOD_ID, BUNDLE_CD, isKit, isPontaVoucher, getStoreID, getCategoryID)\n    {\n\t\tvar OK_canBuy = \'立即結帳\';\n\t\tvar notOK_cantBuy = \'貨到通知\';\n\t\t\n\t\tif(BUNDLE_CD == \'555\')\n\t\t{\n\t\t\tOK_canBuy = \'立即兌換\';\n\t\t\tnotOK_cantBuy = \'兌換完畢\';\n\t\t}\n\n        switch(ONLINE)\n        {\n            // 0：貨到通知\n            case (\'0\'):{\n                //return "貨到通知";\n                //return \'<a class="btn_Gd_soldOut" onclick="GoColorStyle(\'+ GOOD_ID +\')" href="javascript:;">貨到通知</a>\';\n\t\t\t\tif(isKit == \'Y\')\n\t\t\t\t{\n\t\t\t\t\treturn \'<a class="btn_GdKit_BuyNow" ONLINE="\'+ ONLINE +\'" isKit="\'+ isKit +\'" isPontaVoucher="\'+ isPontaVoucher +\'" href="ProductDetail.aspx?StoreID=\'+ getStoreID +\'&CategoryID=\'+ getCategoryID +\'&ProductSKU=\'+ GOOD_ID +\'" GOODID="\'+ GOOD_ID +\'">\'+ OK_canBuy +\'</a>\';\n\t\t\t\t}\n                else if(isPontaVoucher == \'Y\')\n                {\n                    return \'<a class="btn_GdTicket_BuyNow" ONLINE="\'+ ONLINE +\'" isKit="\'+ isKit +\'" isPontaVoucher="\'+ isPontaVoucher +\'" href="ProductDetail.aspx?StoreID=\'+ getStoreID +\'&CategoryID=\'+ getCategoryID +\'&ProductSKU=\'+ GOOD_ID +\'" GOODID="\'+ GOOD_ID +\'">\'+ OK_canBuy +\'</a>\';\n                }\n\t\t\t\telse\n\t\t\t\t{\n\t\t\t\t\treturn \'<a class="btn_Gd_BuyNow" ONLINE="\'+ ONLINE +\'" isKit="\'+ isKit +\'" isPontaVoucher="\'+ isPontaVoucher +\'" onclickFun="GoColorStyle(\\\'\'+ GOOD_ID +\'\\\')" href="javascript:;" GOODID="\'+ GOOD_ID +\'">\'+ OK_canBuy +\'</a>\';\n\t\t\t\t}\n                break;\n            };\n            // N：貨到通知\n            case (\'N\'):{\n                //return "貨到通知";\n                return \'<a class="btn_Gd_soldOut" ONLINE="\'+ ONLINE +\'" isKit="\'+ isKit +\'" isPontaVoucher="\'+ isPontaVoucher +\'" onclick="GoColorStyle(\'+ GOOD_ID +\')" href="javascript:;" GOODID="\'+ GOOD_ID +\'">\'+ notOK_cantBuy +\'</a>\';\n                break;\n            };\n            // 1：立即結帳\n            case (\'1\'):{\n                //return "立即結帳";\n\t\t\t\tif(isKit == \'Y\')\n\t\t\t\t{\n\t\t\t\t\treturn \'<a class="btn_GdKit_BuyNow" ONLINE="\'+ ONLINE +\'" isKit="\'+ isKit +\'" isPontaVoucher="\'+ isPontaVoucher +\'" href="ProductDetail.aspx?StoreID=\'+ getStoreID +\'&CategoryID=\'+ getCategoryID +\'&ProductSKU=\'+ GOOD_ID +\'" GOODID="\'+ GOOD_ID +\'">\'+ OK_canBuy +\'</a>\';\n\t\t\t\t}\n                else if(isPontaVoucher == \'Y\')\n                {\n                    return \'<a class="btn_GdTicket_BuyNow" ONLINE="\'+ ONLINE +\'" isKit="\'+ isKit +\'" isPontaVoucher="\'+ isPontaVoucher +\'" href="ProductDetail.aspx?StoreID=\'+ getStoreID +\'&CategoryID=\'+ getCategoryID +\'&ProductSKU=\'+ GOOD_ID +\'" GOODID="\'+ GOOD_ID +\'">\'+ OK_canBuy +\'</a>\';\n                }\n\t\t\t\telse\n\t\t\t\t{\n\t\t\t\t\treturn \'<a class="btn_Gd_BuyNow" ONLINE="\'+ ONLINE +\'" isKit="\'+ isKit +\'" isPontaVoucher="\'+ isPontaVoucher +\'" onclickFun="GoColorStyle(\\\'\'+ GOOD_ID +\'\\\')" href="javascript:;" GOODID="\'+ GOOD_ID +\'">\'+ OK_canBuy +\'</a>\';\n\t\t\t\t}\n\t\t\t\t\n                break;\n            };\n            // Y：立即結帳\n            case (\'Y\'):{\n                //return "立即結帳";\n\t\t\t\tif(isKit == \'Y\')\n\t\t\t\t{\n\t\t\t\t\treturn \'<a class="btn_GdKit_BuyNow" ONLINE="\'+ ONLINE +\'" isKit="\'+ isKit +\'" isPontaVoucher="\'+ isPontaVoucher +\'" href="ProductDetail.aspx?StoreID=\'+ getStoreID +\'&CategoryID=\'+ getCategoryID +\'&ProductSKU=\'+ GOOD_ID +\'" GOODID="\'+ GOOD_ID +\'">\'+ OK_canBuy +\'</a>\';\n\t\t\t\t}\n                else if(isPontaVoucher == \'Y\')\n                {\n                    return \'<a class="btn_GdTicket_BuyNow" ONLINE="\'+ ONLINE +\'" isKit="\'+ isKit +\'" isPontaVoucher="\'+ isPontaVoucher +\'" href="ProductDetail.aspx?StoreID=\'+ getStoreID +\'&CategoryID=\'+ getCategoryID +\'&ProductSKU=\'+ GOOD_ID +\'" GOODID="\'+ GOOD_ID +\'">\'+ OK_canBuy +\'</a>\';\n                }\n\t\t\t\telse\n\t\t\t\t{\n\t\t\t\t\treturn \'<a class="btn_Gd_BuyNow" ONLINE="\'+ ONLINE +\'" isKit="\'+ isKit +\'" isPontaVoucher="\'+ isPontaVoucher +\'" onclickFun="GoColorStyle(\'+ GOOD_ID +\')" href="javascript:;" GOODID="\'+ GOOD_ID +\'">\'+ OK_canBuy +\'</a>\';\n\t\t\t\t}\n                \n                break;\n            };\n        };\n    }\n</script>\n<script>\n    var removeMargin = function(index, Divisor)\n    {\n        var index = parseInt(index);\n        var Divisor = parseInt(Divisor);\n\n        if( index % Divisor == (Divisor -1)  )\n        {\n            return "SingleProductItemCount"+ index +"  nomergin-right";\n        }\n        else\n        {\n            return "SingleProductItemCount"+ index;\n        }\n    }\n</script>\n<script>\n    var base_SingleProductItem_JSON = {\n                                            "BUNDLE_CD": "70", \n                                            "GOOD_ID": "1214024", \n                                            "GOOD_NM": "三陽 GT(Super)125斜鼓(領)五期噴射-24網..", \n                                            "ONLINE": "0", \n                                            "PRC": "59500", \n                                            "SHOWLABEL": "0", \n                                            "SMS1": "高亮度HS1頭燈", \n                                            "SMS2": "贈送大鎖+安全帽", \n                                            "SMS3": "送一年8萬好險(4萬失竊險+4萬火險)" \n                                      };\n</script>\n<script id="jt_SingleProductItemHasBUNDLECD" type="text/x-jquery-tmpl">\n    {{each products}}\n    <div class="SingleProductItem ${SingleProductItemStyle} {{html removeMargin($index, Divisor) }} clearfix GOODIDStr${GOOD_ID}">\n        <div class="GOOD-img" billy="${BUNDLE_CD}">\n\t\t\n\t\t{{if BUNDLE_CD == \'555\'}}\n            {{if addStoreID}}\n            <a class="${GA_ClassName}" GA_EventType="${GA_EventType}" GA_EventName="${GA_EventName}" GA_EventPicTxt="pic" href="OneKaProductDetail.aspx?StoreID=${getStoreID}&ProductSKU=${GOOD_ID}" title="${DoubleToSingle(GOOD_NM)}">\n            {{else}}\n            <a class="${GA_ClassName}" GA_EventType="${GA_EventType}" GA_EventName="${GA_EventName}" GA_EventPicTxt="pic" href="OneKaProductDetail.aspx?StoreID=${getStoreID}&CategoryID=${getCategoryID}&ProductSKU=${GOOD_ID}" title="${DoubleToSingle(GOOD_NM)}">\n            {{/if}}\n\t\t{{else}}\n            {{if addStoreID}}\n            <a class="${GA_ClassName}" GA_EventType="${GA_EventType}" GA_EventName="${GA_EventName}" GA_EventPicTxt="pic" href="ProductDetail.aspx?StoreID=${getStoreID}&ProductSKU=${GOOD_ID}" title="${DoubleToSingle(GOOD_NM)}">\n            {{else}}\n            <a class="${GA_ClassName}" GA_EventType="${GA_EventType}" GA_EventName="${GA_EventName}" GA_EventPicTxt="pic" href="ProductDetail.aspx?StoreID=${getStoreID}&CategoryID=${getCategoryID}&ProductSKU=${GOOD_ID}" title="${DoubleToSingle(GOOD_NM)}">\n            {{/if}}\n\t\t{{/if}}\n\t\t\t\n\t\t\t\n                <div class="label">\n                    <i class="inline-block sprite-image {{html checkProductItemLabel(SHOWLABEL) }}"></i>\n                </div>\n                {{if RMBPRC}}\n                    {{if RMBPRC != \'\' && getStoreID == \'22223\'}}\n                <div class="labelRMB">\n                    <i class="inline-block sprite-image ico-label-RMB"></i>\n                </div>\n                    {{/if}}\n                {{/if}}\n                <div class="imgSrc">\n                    <img src="{{html getPdImg(GOOD_ID, \'XL\') }}" class="main-img" alt="${DoubleToSingle(GOOD_NM)}">\n                    <img src="{{html getPdImg(GOOD_ID, \'XL\', \'-2\') }}" class="next-img" onerror="this.src=\'{{html getPdImg(GOOD_ID, \'XL\') }}\';">\n                </div>\n                <div class="sms">\n                    <div class="animation-hidden">\n                        <div class="black-overlay">\n                        </div>\n                        <ul class="clearfix">\n                            {{if SMS1 != \'\' && SMS1 != null}}<li>${DoubleToSingle(SMS1)}</li>{{/if}}\n                            {{if SMS2 != \'\' && SMS2 != null}}<li>${DoubleToSingle(SMS2)}</li>{{/if}}\n                            {{if SMS3 != \'\' && SMS3 != null}}<li>${DoubleToSingle(SMS3)}</li>{{/if}}\n                        </ul>\n                    </div>\n                </div>\n            </a>\n        </div>\n        <div class="GOOD-InfoBox">\n            <div class="GOOD-NM">\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t{{if BUNDLE_CD == \'555\'}}\n\t\t\t\t\t{{if addStoreID}}\n\t\t\t\t\t<a class="${GA_ClassName}" GA_EventType="${GA_EventType}" GA_EventName="${GA_EventName}" GA_EventPicTxt="text" href="OneKaProductDetail.aspx?StoreID=${getStoreID}&CategoryID=${getCategoryID}&ProductSKU=${GOOD_ID}" title="${DoubleToSingle(GOOD_NM)}">${DoubleToSingle(GOOD_NM)}</a>\n\t\t\t\t\t{{else}}\n\t\t\t\t\t<a class="${GA_ClassName}" GA_EventType="${GA_EventType}" GA_EventName="${GA_EventName}" GA_EventPicTxt="text" href="OneKaProductDetail.aspx?StoreID=${getStoreID}&CategoryID=${getCategoryID}&ProductSKU=${GOOD_ID}" title="${DoubleToSingle(GOOD_NM)}">${DoubleToSingle(GOOD_NM)}</a>\n\t\t\t\t\t{{/if}}\n\t\t\t\t{{else}}\n\t\t\t\t\t{{if addStoreID}}\n\t\t\t\t\t<a class="${GA_ClassName}" GA_EventType="${GA_EventType}" GA_EventName="${GA_EventName}" GA_EventPicTxt="text" href="ProductDetail.aspx?StoreID=${getStoreID}&CategoryID=${getCategoryID}&ProductSKU=${GOOD_ID}" title="${DoubleToSingle(GOOD_NM)}">${DoubleToSingle(GOOD_NM)}</a>\n\t\t\t\t\t{{else}}\n\t\t\t\t\t<a class="${GA_ClassName}" GA_EventType="${GA_EventType}" GA_EventName="${GA_EventName}" GA_EventPicTxt="text" href="ProductDetail.aspx?StoreID=${getStoreID}&CategoryID=${getCategoryID}&ProductSKU=${GOOD_ID}" title="${DoubleToSingle(GOOD_NM)}">${DoubleToSingle(GOOD_NM)}</a>\n\t\t\t\t\t{{/if}}\n\t\t\t\t{{/if}}\n\t\t\t\t\n\t\t\t\t\n            </div>\n            <div class="GOOD-SMS">\n                <ul class="clearfix">\n                    {{if SMS1 != \'\' && SMS1 != null}}<li>${DoubleToSingle(SMS1)}</li>{{/if}}\n                    {{if SMS2 != \'\' && SMS2 != null}}<li>${DoubleToSingle(SMS2)}</li>{{/if}}\n                    {{if SMS3 != \'\' && SMS3 != null}}<li>${DoubleToSingle(SMS3)}</li>{{/if}}\n                </ul>\n            </div>\n        </div>\n        <div class="GOOD-BuyBox" BUNDLE_CD="${BUNDLE_CD}">\n\t\t{{if BUNDLE_CD == \'555\'}}\n            <div class="GOOD-PRC">\n\t\t\t\t得易Ponta卡兌換點數：<br>\n                <b>${Sys_FormatNumber(UsePoint)}<span style="padding-left:2px;font-size: 15px;">點</span></b>\n            </div>\n\t\t{{else}}\n            <div class="GOOD-PRC" GOODPRC="${PRC}">\n                {{if isPontaVoucher == \'Y\'}}\n                    {{if DISCOUNT}}{{if DISCOUNT != \'\'}}<em>$${Sys_FormatNumber(PRC)}</em>{{/if}}{{/if}}\n                    {{if pointType==\'1\'}}\n                        <div class="promoMsgPrc"><ins class="Exchange_icon"></ins>${Sys_FormatNumber(pointNum1)}<ins>點</ins></div>\n                    {{else}}\n                        <div class="promoMsgPrc"><ins class="Exchange_icon"></ins>${Sys_FormatNumber(pointNum2)}<ins>點 + </ins>${Sys_FormatNumber(pointPlusMoney)}<ins>元</ins></div>\n                    {{/if}}\n                \n                {{else}}\n                    {{if DISCOUNT}}{{if DISCOUNT != \'\'}}<em>$${Sys_FormatNumber(PRC)}</em>{{/if}}{{else}}$<b>${Sys_FormatNumber(PRC)}</b>{{/if}} {{if RMBPRC}}{{if RMBPRC != \'\' && getStoreID == \'22223\'}} / <span style="font-size:12px;">￥</span><b>${Sys_FormatNumber(RMBPRC)}</b> {{/if}}{{/if}}\n                    <div class="promoMsgPrc">{{if DISCOUNT}}{{if DISCOUNT != \'\'}}<ins>${DISCOUNTTEXT}$</ins>${Sys_FormatNumber(DISCOUNT)}{{/if}}{{/if}}</div>\n                {{/if}}\n            </div>\n\t\t{{/if}}\n            <div class="GOOD-Btns">\n                <!--a class="btn_pink" onclick="GoColorStyle(${GOOD_ID})" href="javascript:;">{{html checkProductItemOnline(ONLINE, GOOD_ID) }}</a-->\n\t\t\t\t{{if BUNDLE_CD == \'30\'}}\n\t\t\t\t\t<a class="btn_Gd_GBBuyNow" goodid="5232395" href="GBProductDetail.aspx?ProductSKU=${GOOD_ID}" iskit="N" online="Y">立即結帳</a>\n\t\t\t\t\t<a class="btn_Gd_compare" onclick="sys_AddToShoppingCar(\'${GOOD_ID}\')">加入購物車</a>\n\t\t\t\t{{else}}\n\t\t\t\t\t{{html checkProductItemOnline(ONLINE, GOOD_ID, BUNDLE_CD, isKit, isPontaVoucher, getStoreID, getCategoryID) }}\n\t\t\t\t\t{{html checkProductItemWouldAddToCart(ONLINE, GOOD_ID, BUNDLE_CD, isKit, isPontaVoucher, getStoreID, getCategoryID) }}\n\t\t\t\t{{/if}}\n\t\t\t\t{{if BUNDLE_CD != \'555\'}}\n\t\t\t\t\t<!--a class="btn_Gd_compare" onclick="sys_AddToShoppingCar(\'${GOOD_ID}\')">加入購物車</a-->\n\t\t\t\t{{/if}}\n            </div>\n        </div>\n    </div>\n    {{/each}}\n</script>\n<script id="jt_SingleProductItem" type="text/x-jquery-tmpl">\n    {{each products}}\n    <div class="SingleProductItem ${SingleProductItemStyle} {{html removeMargin($index, Divisor) }} clearfix">\n        <div class="GOOD-img">\n            {{if addStoreID}}\n            <a class="${GA_ClassName}" GA_EventType="${GA_EventType}" GA_EventName="${GA_EventName}" GA_EventPicTxt="pic" href="ProductDetail.aspx?StoreID=${getStoreID}&ProductSKU=${GOOD_ID}" title="${DoubleToSingle(GOOD_NM)}">\n            {{else}}\n            <a class="${GA_ClassName}" GA_EventType="${GA_EventType}" GA_EventName="${GA_EventName}" GA_EventPicTxt="pic" href="ProductDetail.aspx?StoreID=${getStoreID}&CategoryID=${getCategoryID}&ProductSKU=${GOOD_ID}" title="${DoubleToSingle(GOOD_NM)}">\n            {{/if}}\n                <div class="label">\n                    <i class="inline-block sprite-image {{html checkProductItemLabel(SHOWLABEL) }}"></i>\n                </div>\n                {{if RMBPRC}}\n                    {{if RMBPRC != \'\' && getStoreID == \'22223\'}}\n                <div class="labelRMB">\n                    <i class="inline-block sprite-image ico-label-RMB"></i>\n                </div>\n                    {{/if}}\n                {{/if}}\n                <div class="imgSrc">\n                    <img src="{{html getPdImg(GOOD_ID, \'XL\') }}" class="main-img" alt="${DoubleToSingle(GOOD_NM)}">\n                    <img src="{{html getPdImg(GOOD_ID, \'XL\', \'-2\') }}" class="next-img" onerror="this.src=\'{{html getPdImg(GOOD_ID, \'XL\') }}\';">\n                </div>\n                <div class="sms">\n                    <div class="animation-hidden">\n                        <div class="black-overlay">\n                        </div>\n                        <ul class="clearfix">\n\t\t\t\t\t\t\t{{if SMS1 != \'\' && SMS1 != null}}<li>${DoubleToSingle(SMS1)}</li>{{/if}}\n\t\t\t\t\t\t\t{{if SMS2 != \'\' && SMS2 != null}}<li>${DoubleToSingle(SMS2)}</li>{{/if}}\n\t\t\t\t\t\t\t{{if SMS3 != \'\' && SMS3 != null}}<li>${DoubleToSingle(SMS3)}</li>{{/if}}\n                        </ul>\n                    </div>\n                </div>\n            </a>\n        </div>\n        <div class="GOOD-InfoBox">\n            <div class="GOOD-NM">\n                {{if addStoreID}}\n                <a class="${GA_ClassName}" GA_EventType="${GA_EventType}" GA_EventName="${GA_EventName}" GA_EventPicTxt="text" href="ProductDetail.aspx?StoreID=${getStoreID}&CategoryID=${getCategoryID}&ProductSKU=${GOOD_ID}" title="${DoubleToSingle(GOOD_NM)}">${DoubleToSingle(GOOD_NM)}</a>\n                {{else}}\n                <a class="${GA_ClassName}" GA_EventType="${GA_EventType}" GA_EventName="${GA_EventName}" GA_EventPicTxt="text" href="ProductDetail.aspx?StoreID=${getStoreID}&CategoryID=${getCategoryID}&ProductSKU=${GOOD_ID}" title="${DoubleToSingle(GOOD_NM)}">${DoubleToSingle(GOOD_NM)}</a>\n                {{/if}}\n            </div>\n            <div class="GOOD-SMS">\n                <ul class="clearfix">\n\t\t\t\t\t\t\t{{if SMS1 != \'\' && SMS1 != null}}<li>${DoubleToSingle(SMS1)}</li>{{/if}}\n\t\t\t\t\t\t\t{{if SMS2 != \'\' && SMS2 != null}}<li>${DoubleToSingle(SMS2)}</li>{{/if}}\n\t\t\t\t\t\t\t{{if SMS3 != \'\' && SMS3 != null}}<li>${DoubleToSingle(SMS3)}</li>{{/if}}\n                </ul>\n            </div>\n        </div>\n        <div class="GOOD-BuyBox">\n            <div class="GOOD-PRC">\n                {{if DISCOUNT}}{{if DISCOUNT != \'\'}}<em>$${Sys_FormatNumber(PRC)}</em>{{/if}}{{else}}$<b>${Sys_FormatNumber(PRC)}</b>{{/if}} {{if RMBPRC}}{{if RMBPRC != \'\' && getStoreID == \'22223\'}} / <span style="font-size:12px;">￥</span><b>${Sys_FormatNumber(RMBPRC)}</b> {{/if}}{{/if}}\n\t\t\t\t<div class="promoMsgPrc">{{if DISCOUNT}}{{if DISCOUNT != \'\'}}<ins>${DISCOUNTTEXT}$</ins>${Sys_FormatNumber(DISCOUNT)}{{/if}}{{/if}}</div>\n            </div>\n            <div class="GOOD-Btns">\n                <!--a class="btn_pink" onclick="GoColorStyle(${GOOD_ID})" href="javascript:;">{{html checkProductItemOnline(ONLINE, GOOD_ID) }}</a-->\n                {{html checkProductItemOnline(ONLINE, GOOD_ID, \'\', \'\', \'\', getStoreID, getCategoryID) }}\n                <a class="btn_Gd_compare" onclick="sys_AddToShoppingCar(\'${GOOD_ID}\')">加入購物車</a>\n            </div>\n        </div>\n    </div>\n    {{/each}}\n</script>\n<script id="jt_E68_LeftHotView" type="text/x-jquery-tmpl">\n    {{each products}}\n        <h4 class="acc_trigger"><a href="#"><i class="inline-block member-navi-bg ico-liDot"></i>${DoubleToSingle(GOOD_NM)}</a></h4>\n        <div class="acc_container"><span class="lab"><strong>${$index + 1}</strong></span><a class="GAEventTracking PHType-AD" GA_EventType="${GA_EventType}" GA_EventName="${GA_EventName}" GA_EventPicTxt="pic" href="ProductDetail.aspx?ProductSKU=${GOOD_ID}"><img data-original="{{html getPdImg(GOOD_ID, \'LM\') }}" src="../E68Images/1x1_transparent.gif" class="lazy"></a></div>\n    {{/each}}\n</script>\n<script>\nfunction getMediaImgStr(str){\n\tvar isSSL = false;\n    \n    if(document.location.protocol == \'https:\')\n    {\n        isSSL = true;\n    }\n\t\n    var IMGsrc = str;\n\n    if(IMGsrc.indexOf(\'../\') != -1)\n    {\n\t\tif (isSSL)\n\t\t{\n\t\t\treturn \'https://www.etmall.com.tw/\' + IMGsrc.substr(3,(IMGsrc.length-1));\n\t\t}\n\t\telse\n\t\t{\n\t\t\treturn \'//media.etmall.com.tw/\' + IMGsrc.substr(3,(IMGsrc.length-1));\n\t\t}\n    }\n    else\n    {\n        return IMGsrc ;\n    }\n\n}\n\nvar Sys_FormatNumber = function(strNumber)\n{\n    var i;\n    \n    if( typeof(strNumber) == "number"  )\n    {\n        strNumber = strNumber.toString();\n    }\n    \n    for( i=strNumber.length-3 ;i>0; i-=3)\n    {\n        strNumber = strNumber.substring(0,i) + "," + strNumber.substring(i);\n    }\n    return strNumber;\n}\n\nvar sys_AddToShoppingCar = function(ProductSKU)\n{\n    var tHashParm = $H();\n    tHashParm["ProductSKU"] = ProductSKU;\n    tHashParm["MethodName"] = "AddCartListDelivery";\n\t//------------------------------------------------\n\tvar myAjaxEntity = new AjaxProtal();\n\tmyAjaxEntity.ControllerPage ="Controller_AddToCartListBag.aspx";\n\tmyAjaxEntity.ActionType = "POST";\n\tmyAjaxEntity.Parm = tHashParm;\n\tmyAjaxEntity.CallBackFunction = "AddToCartListBagCallBack";\n\t//RunMethod();\n\tmyAjaxEntity.RunMethod();\n}\n\nfunction AddToCartListBagCallBack(myObjData) {\n    if (myObjData.StateCode == \'1\') \n\t{\n        alert("您已成功加入購物車!");\n\t\tNewTopNaviCartVV()\n    }\n    else if (myObjData.StateCode == \'-2\' || myObjData.StateCode == \'-3\') {\n        hidePopWin(false);\n        alert( DoubleToSingle(myObjData.StateMessage) );\n    }\n    else {\n        hidePopWin(false);\n        alert( DoubleToSingle(myObjData.StateMessage) );\n    }\n\n}\n\nfunction NewTopNaviCartVV()\n\t{\n\t\t\tvar  tHashParm = $H();\n\t\t\ttHashParm["EncryptKey"] = E68_HeaderBagEncryptKey;\n\t\t\ttHashParm["CartListName"] = \'CartListDeliveryBag\';\n\t\t\t//------------------------------------------------\n\t\t\t//要回傳的Data\n\t\t\tvar tCallBackParm = $H();\n\t\t\t//tCallBackParm["BagName"] = Cstr;\n\t\t\ttCallBackParm["CallBagName"] = \'CartListDeliveryBag\';\n\t\t\t//------------------------------------------------\n\t\t\tvar myAjaxEntity = new AjaxProtal();\n\t\t\tmyAjaxEntity.ControllerPage = "Controller_ShoppingCartListBag.aspx"; \n\t\t\tmyAjaxEntity.ActionType = "POST";\n\t\t\tmyAjaxEntity.Parm = tHashParm;\n\t\t\tmyAjaxEntity.CallBackFunction = "RunCallBackListVV2";\n\t\t\tmyAjaxEntity.CallBackParm = tCallBackParm;\n\t\t\t//var tCallBackParm = $H(); \n\t\t\t//tCallBackParm["historyType"] = type; \n\t\t\t//RunMethod();\n\t\t\tmyAjaxEntity.RunMethod();\n\t}\n\tfunction RunCallBackListVV2(myObjData)\n\t{\n\t\t\tvar asStateObject = myObjData.StateObject.parseJSON();\n\t\t\tjQuery(\'.navi-links-cartlist-old span\').text(\'(\'+ asStateObject.Data.TotalCount +\')\');\n            jQuery(\'.n-dropmenu-basket span\').text(\'(\'+ asStateObject.Data.TotalCount +\')\');\n\t}\n\n\n\n</script>\n<script id="jt_E68_AD_widthLabel" type="text/x-jquery-tmpl">\n    {{if Label != \'\'}}\n    <i class="inline-block sprite-image"><img src="{{html getMediaImgStr(Label)}}"></i>\n    {{/if}}\n    <a href="${Link}" class="GARecord" GA_EventName="${GA_EventName}" GA_EventType="${GA_EventType}"><img data-original="{{html getMediaImgStr(Image)}}" src="../E68Images/1x1_transparent.gif" class="lazy"></a>\n</script>\n<script>\n                var public = checkbrowse(); \n                var showeffect = ""; \n                if ((public[\'is\'] == \'msie\' && public[\'ver\'] < 8.0))\n                { \n                    showeffect = "show" \n                }\n                else\n                { \n                    showeffect = "fadeIn" \n                } \n</script>\n<link href="../R6CSS/Standard.css" rel="stylesheet" type="text/css"/>\n<link href="../E68CSS_Src/BrandCateTopMenu.css?version=20170207160412" media="screen" rel="stylesheet" type="text/css"/>\n<link href="/bundles/E68pageCSS?v=ehidHG0qtNyrABn6WKmmW5erusHd5a-l2XYS7aiuXKg1" rel="stylesheet"/>\n<script src="../E68Includes/fancybox/jquery.mousewheel-3.0.4.pack.js" type="text/javascript"></script>\n<script src="../E68Includes/fancybox/jquery.fancybox-1.3.4.js" type="text/javascript"></script>\n<link href="../E68CSS/jquery.fancybox-1.3.4.css" media="screen" rel="stylesheet" type="text/css"/>\n<!--ShowPOP功能用-->\n<script src="../Includes/subModal.js" type="text/javascript"></script>\n<!--ShowPOP功能用END-->\n<script src="../includes/membercentersub.js" type="text/javascript"></script>\n<script language="javascript">\r\n            //偷偷塞入客代\r\n            var ga_CUST_ACCT_ID = \'0\';\r\n\t\t\tvar ga_CUST_LVL_CD  = \'\';\r\n            ga_CUST_ACCT_ID = parseInt(ga_CUST_ACCT_ID);\r\n            var CUST_LVL_CD = parseInt(ga_CUST_ACCT_ID);\r\n            \r\n            var PHRef = "";\r\n            \r\n            var gogoWeek = "1";\r\n            var s_Dnow = \'20170207\';\r\n            var s_DAfter = \'20170208\';\r\n            var s_DBefore = \'20170206\';\r\n            var ShowSPID="104";\r\n            var showIP="104";\r\n        </script>\n<script>\n    var ETU_Scupio_cookieName = \'newRecomCookieName\';\n</script>\n<script>\n    var ETU_CookieSet = \'ETU\';\n    var Scupio_CookieSet = \'ETU\';\n</script>\n<script>\r\n            var NowStoreID = "0";\r\n            var StoreID=NowStoreID;\r\n            var sam_count=1;\r\n            \r\n            var d = new Date();\r\n            var Even = (d.getSeconds() % 2 == 0)? "true" : "false";\r\n            //showETUProduct已經沒有判別了，先留著只是預防寫錯\r\n            var showETUProduct = \'\';\r\n            var showScupioOrETUProduct = \'\';\r\n            var st = ""\r\n            var expires = new Date();\r\n            expires.setTime(expires.getTime() + 90 * 24 * 60 * 60 * 1000);\r\n\r\n        </script>\n<!--中華優購專案-->\n<script>\n\tvar isfromBenefit = \'N\';\n</script>\n<!--中華優購專案-->\n<script>\n\tvar myCouponTik        = new Array();\n\tvar myCouponTotalCount = \'0\';</script>\n<script type="text/javascript">\n    var headerJSON = {"HeaderBanner":[{"Image":"../XML/AdvImage/2017/02/6349_20170206175921_257/et_190x60_02-175918976.jpg","Link":"SimpleTemplate.aspx?SubPage=DMSetting/Final/
-shortcut">\n<div class="n-content">\n<a class="n-icon-shortcut-scroll__logo" href="Home.aspx"></a>\n<ul class="n-shortcut__other">\n<li><a class="sendGA" gaaction="" galabel="左上功能列_Icon" ganame="TopLeftBT_1" gapictext="pic" gatype="Head" href="Home.aspx" title="返回首頁"><img alt="home" class="svg svg-home" src="../img201607/svg/home.svg"/></a></li>\n</ul>\n<ul class="n-shortcut__menu">\n<li class="is--hide noLogin"><a class="sendGA" gaaction="" galabel="右上功能列_登入" ganame="TopLogin" gapictext="text" gatype="Head" href="javascript:;" id="newloginpop" rel="nofollow">登入</a></li>\n<li class="is--hide noLogin"><a class="sendGA" gaaction="" galabel="右上功能列_註冊" ganame="TopRegi" gapictext="text" gatype="Head" href="javascript:;" id="newregisterpop" rel="nofollow">註冊</a></li>\n<li class="is--hide isLogined"><a class="userLogout sendGA" gaaction="" galabel="右上功能列_登出" ganame="TopLogout" gatype="Head" href="#" rel="nofollow">登出</a></li>\n<li class="n-shortcut__submenu"><a href="javascript:;">得易Ponta</a>\n<div class="n-dropmenu">\n<a class="n-dropmenu__items pontaMore sendGA" gaaction="" galabel="右上功能列_加入得易Ponta" ganame="TopPonta_1" gapictext="text" gatype="Head" href="OneCardSP.aspx" title="加入得易Ponta">加入得易Ponta</a>\n<!--a href="OneCardQuery.aspx" class="n-dropmenu__items">點數明細</a-->\n</div>\n</li>\n<li class="is--hide n-shortcut__submenu"><a href="javascript:;">禮物卡</a>\n<div class="n-dropmenu n-dropmenu-giftCard">\n</div>\n</li>\n<li class="n-shortcut__submenu"><a class="sendGA" gaaction="" galabel="右上功能列_會員服務" ganame="TopMemService_1" gapictext="text" gatype="Head" href="MemberCenter.aspx">會員服務</a>\n<div class="n-dropmenu">\n<a class="n-dropmenu__items sendGA" gaaction="" galabel="右上功能列_會員服務" ganame="TopMemService_2" gapictext="text" gatype="Head" href="R6MemCenterFAQ_sub.aspx?Page=3_1_Question_QA">常見問題</a>\n<a class="n-dropmenu__items sendGA" gaaction="" galabel="右上功能列_訂單查詢" ganame="TopMemService_3" gapictext="text" gatype="Head" href="OrderHistory.aspx">訂單查詢</a>\n<a class="n-dropmenu__items sendGA" gaaction="" galabel="右上功能列_聯絡我們" ganame="TopMemService_4" gapictext="text" gatype="Head" href="Contact.aspx">聯絡我們</a>\n</div>\n</li>\n<li class="is--hide isLogined n-shortcut__submenu"><a class="sendGA" gaaction="" galabel="右上功能列_優惠券" ganame="TopCoupon_1" gapictext="text" gatype="Head" href="Ecoupon.aspx">優惠劵(0)</a>\n<div class="n-dropmenu n-dropmenu-coupon">\n<div class="n-dropmenu__items">\r\n                                輸入好康序號 / 優惠劵序號：\r\n                                <div class="n-dropmenu-coupon__input">\n<input class="form--control" placeholder="注意大小寫" type="text"/>\n<input class="btn btn--primary btn--small" type="button" value="送出"/>\n<div class="n-dropmenu-coupon__errormsg form--error is--hide"></div>\n</div>\n</div>\n<div class="n-dropmenu__items">\r\n                                以下是您於效期內的<a class="underline--link sendGA" gaaction="" galabel="右上功能列_電子優惠券明細" ganame="TopCoupon_3" gapictext="text" gatype="Head" href="Ecoupon.aspx">電子優惠券明細</a>：\r\n                                <table class="table table--lv1">\n<thead>\n<tr>\n<th>折價</th><th>數量</th>\n</tr>\n</thead>\n<tbody>\n</tbody>\n</table>\n</div>\n</div>\n</li>\n<li class="is--hide isLogined"><a class="sendGA" gaaction="" galabel="右上功能列_追蹤清單" ganame="TopTrackList" gapictext="text" gatype="Head" href="WishList.aspx">追蹤清單</a></li>\n<li class="n-shortcut__submenu"><a class="n-dropmenu-basket sendGA" gaaction="" galabel="右上功能列_購物車" ganame="HeadTopShopCart_1" gapictext="text" gatype="Head" href="Basket.aspx">購物車(<span>0</span>)</a></li>\n</ul>\n</div>\n</div>\n<!--ul class="n-top-banner cycle-slideshow" data-cycle-fx="scrollVert" data-cycle-loader="wait" data-cycle-timeout="5000" data-cycle-slides="> li" data-cycle-pause-on-hover="true"-->\n<div class="n-top-banner-div">\n<ul class="n-top-banner"></ul>\n<div class="n-top-banner__close">關閉</div>\n<div class="n-top-banner__nav cycle-pager" id="Billy"></div>\n</div>\n<header class="n-header">\n<div class="n-content">\n<div class="n-top-banner__open">展開優惠<span class="icon-down"></span></div>\n<ul class="n-logo">\n<li><a class="sendGA" gaaction="" galabel="Head左側BN_1" ganame="LeftBN_1" gapictext="pic" gatype="Head" href="Home.aspx" title="返回首頁"><img alt="東森購物網" src="../img201607/logo.png"/><h1 itemprop="name">東森購物網</h1></a></li>\n</ul>\n<div class="n-search">\n<form autocomplete="off" class="AutoCompleteForm n-search__form" id="HomeSearch" method="post" name="HomeSearch">\n<input name="query_advance" type="hidden" value="N"/>\n<input id="searchObj" name="query_storeid" type="hidden" value=""/>\n<input name="query_type" type="hidden" value="0"/>\n<input name="query_Scope" type="hidden" value="ETMall_FullText_All"/>\n<input name="ProductSource" type="hidden"/>\n<input name="SearchKeyword" type="hidden"/>\n<input name="OnlineDateStart" type="hidden"/>\n<input name="OnlineDateEnd" type="hidden"/>\n<input name="ProductMoneyStart" type="hidden"/>\n<input name="ProductMoneyEnd" type="hidden"/>\n<input name="Video" type="hidden"/>\n<input name="OrderBy" type="hidden" value=""/>\n<input name="QueryCmd" type="hidden"/>\n<input name="PageIndex" type="hidden" value="0"/>\n<input name="PageSize" type="hidden" value="20"/>\n<input name="CombinedCode" type="hidden"/>\n<input name="QueryCmdName" type="hidden"/>\n<input name="CategoryName" type="hidden"/>\n<input name="hiotoryTree" type="hidden"/>\n<input name="hiotoryTreeName" type="hidden"/>\n<input name="noResultUse" type="hidden"/>\n<input name="Color" type="hidden"/>\n<input name="Style" type="hidden"/>\n<input name="ColorValue" type="hidden"/>\n<input name="StyleValue" type="hidden"/>\n<input class="n-search__input searchInput" id="query_keyword" name="query_keyword" placeholder="請輸入商品關鍵字" type="text"/>\n<select class="n-search__select" name="">\n<option value="">全商品</option>\n</select>\n<button class="n-search__submit btn" type="submit">搜尋</button>\n</form>\n<div class="n-search__recommend">\r\n                        熱搜：\r\n                    </div>\n</div>\n<div class="n-store-go">\n<a class="icon-go sendGA" gaaction="集綠點" galabel="Head_集綠點" ganame="3BT_0" gapictext="text" gatype="Head" href="http://www.etmall.com.tw/Pages/greenpointsp.aspx" target="_blank" title="集綠點"><img alt="" src="../img201607/sprite/ico-green-go.png"/></a>\n<a class="icon-go n-icon-h24-go sendGA" gaaction="24h到貨" galabel="Head_24H到貨" ganame="3BT_1" gapictext="text" gatype="Head" href="http://www.etmall.com.tw/Pages/Pa_Home.aspx?StoreID=9" target="_blank" title="24h到貨"></a>\n<a class="icon-go n-icon-hokang-go sendGA" gaaction="好康" galabel="Head_好康" ganame="3BT_2" gapictext="text" gatype="Head" href="Hokang.aspx?Stage=2" target="_blank" title="好康"></a>\n<a class="icon-go n-icon-gbsale-go sendGA" gaaction="集購" galabel="Head_集購" ganame="3BT_3" gapictext="text" gatype="Head" href="gbsale.aspx?Stage=1" target="_blank" title="集購"></a>\n</div>\n</div>\n</header>\n<nav class="n-nav">\n<div class="n-content">\n<ul class="n-nav-category">\n<li class="n-nav__items n-nav-brand__items"><a class="brand" href="javascript: void(0)"><span class="font--red">品牌旗艦</span></a>\n<div class="n-dropmenu n-dropmenu-brand">\n</div>\n</li>\n</ul>\n<ul class="n-nav-new">\n<div class="n-nav-new__tag"></div>\n</ul>\n<div class="n-nav-openlayer">\n</div>\n</div>\n</nav>\n<div id="wrapMain">\n<div class="wrapTop"></div>\n<!-- (begin) content_body -->\n<div class="fullscreen bigIndex_CB clearfix" id="content_body">\n<div class="div998 clearfix">\n<!-- Bridgewell_JS Start-->\n<!-- Bridgewell_JS End-->\n<script>\n\tString.prototype.trim=function()\n\t{\n\t  return(this.split(/(^\\s+|\\s+$)/g)[0]);\n\t}\n</script>\n<link href="../R6CSS/E68_search.css" media="screen" rel="stylesheet" type="text/css"/>\n<script type="text/javascript">\n\tvar squery_CategoryID \t\t\t    = \'\';\n\tvar squery_QueryCmdHistory \t\t\t= \'\';\n\tvar squery_queryKeyword    \t\t\t= \'\';\n\tvar no_tern_squery_SearchKeyword\t= \' MeFOTO MK10 藍牙遙控 自拍棒／三角腳架 公司貨 \';\n\tvar squery_SearchKeyword   \t\t\t= \' MeFOTO MK10 藍牙遙控 自拍棒／三角腳架 公司貨 \';\n    \n    squery_SearchKeyword = squery_SearchKeyword.replace(/\\&/g, \'＆\');\n    \n\tvar squery_hiotoryTree     \t\t\t= \'\';\n\tvar squery_hiotoryTreeName \t\t\t= \'\';\n\n    ga(\'send\', \'event\', \'All_searchResult\', squery_SearchKeyword, squery_SearchKeyword);\n\n\tjQuery(document).attr("title", no_tern_squery_SearchKeyword + \'｜搜尋結果｜ETMall東森購物網\');\n\n\tif(squery_queryKeyword != \'\')\n\t{\n\t\tdocument.HomeSearch.query_keyword.value = squery_queryKeyword;\n\t}\n\t\n\tif(squery_SearchKeyword != \'\')\n\t{\n\t\tdocument.HomeSearch.query_keyword.value = no_tern_squery_SearchKeyword;\n\t}\n\n\tvar DownList1 = \'\';\n\tvar DownList2 = \'\';\n</script>\n<script id="etu-recommender" type="text/javascript"> \nvar ETU_CUST_ACCT_ID = \'0\';\nif(ETU_CUST_ACCT_ID == \'0\')\n{\n\tETU_CUST_ACCT_ID = \'\';\n}\n\nvar erHostname = \'rec.eitc.com.tw\';\nvar _qevents   = _qevents || []; \n_qevents.push({ \n\tgroup : \'ec\',\n\tcid : \'etmall\', \n\tact : \'view\', \n\tuid : (\'0\' == \'0\')? \'\' : \'0\',\n\tkeywords : squery_SearchKeyword,\n\tsearchcat:squery_CategoryID,\n\terTag : \'SearchResult\',\n\terpage : \'SEARCH\'\n});  \nvar erUrlPrefix=(\'https:\' == document.location.protocol ?  \n\'https://\':\'http://\')+erHostname+\'/\'; \n\nif(ETU_opener == \'Y\')\n{\n\t(function() \n\t{ \n\t\tvar er = document.createElement(\'script\'); \n\t\ter.type = \'text/javascript\'; \n\t\ter.async = true; \n\t\ter.src = erUrlPrefix+\'etu.js?\'+(new Date().getTime());\n\t\tvar currentJs=document.getElementById(\'etu-recommender\'); \n\t\tcurrentJs.parentNode.insertBefore(er,currentJs); \n\t})(); \n}\n\nif(FBrecord_opener == \'Y\')\n{\n\t(function() \n\t{\n\t\tvar _fbq = window._fbq || (window._fbq = []);\n\t\tif (!_fbq.loaded) {\n\t\tvar fbds = document.createElement(\'script\');\n\t\tfbds.async = true;\n\t\tfbds.src = \'//connect.facebook.net/en_US/fbds.js\';\n\t\tvar s = document.getElementsByTagName(\'script\')[0];\n\t\ts.parentNode.insertBefore(fbds, s);\n\t\t_fbq.loaded = true;\n\t\t}\n\t\t_fbq.push([\'addPixelId\', \'701110716660336\']);\n\t})();\n}\n\nfunction BagtoETU(sPSKU, PRC, itemQty, categoryString) //加入購物車\n{\n\tif(FBrecord_opener == \'Y\')\n\t{\n\t\twindow._fbq = window._fbq || [];\n\t\twindow._fbq.push([\'track\', \'PixelInitialized\', {}]);\n\t\t\n\t\t// if you have a separate add to cart page that is loaded\n\t\twindow._fbq.push([\'track\', \'AddToCart\', {\n\t\t\tcontent_ids: [sPSKU],\n\t\t\tcontent_type: \'product\'\n\t\t}]);\n\t}\n}\n\nvar addETUCAT            = \'\';\nvar sys_AddToShoppingCar = function(ProductSKU)\n{\n\tvar tHashParm = $H();\n\ttHashParm["ProductSKU"] = ProductSKU;\n\ttHashParm["MethodName"] = "AddCartListDelivery";\n\ttHashParm["GACode"] = "search_resuleAddCart";\n\n\t\n\t//------------------------------------------------\n\tvar myAjaxEntity = new AjaxProtal();\n\tmyAjaxEntity.ControllerPage   = "Controller_AddToCartListBag.aspx";\n\tmyAjaxEntity.ActionType       = "POST";\n\tmyAjaxEntity.Parm             = tHashParm;\n\tmyAjaxEntity.CallBackFunction = "AddToCartListBagCallBack";\n\t\n\t//RunMethod();\n\tmyAjaxEntity.RunMethod();\n\n\tvar attr_ProductPRC = jQuery(\'.GOODIDStr\' + ProductSKU).find(\'.GOOD-PRC\').attr(\'GOODPRC\');\n\tfbq(\'track\', \'AddToCart\');\n\tBagtoETU(ProductSKU, attr_ProductPRC, \'1\', addETUCAT);\n}\t\n</script>\n<!--PlaceHolder：E68_SearchResultHotKeyWord：大家正在找 + 熱門搜尋排行榜 兩組關鍵字start-->\n<script type="text/javascript">\n                var HotKeyWord_everyone = \'福利品,即期品,收納櫃,蘭陵,護髮\';\n                var HotKeyWord_topRank = \'福利品,即期品,外套,行李箱,COACH 包,小米,洋裝,鍋寶,鑄鐵鍋,蘭陵\';\n\n                //alert(\'HotKeyWord_everyone = \' + HotKeyWord_everyone);\n                //alert(\'HotKeyWord_topRank = \' + HotKeyWord_topRank);\n            </script>\n<!--PlaceHolder：E68_SearchResultHotKeyWord：大家正在找 + 熱門搜尋排行榜 兩組關鍵字end-->\n<!--PlaceHolder：E68_SearchResultMyRecentKeyWord：你最近蒐尋過的關鍵字start-->\n<script type="text/javascript">\n                var E68_SearchResultMyRecentKeyWord = \'\';\n                //alert(\'E68_SearchResultMyRecentKeyWord = \' + E68_SearchResultMyRecentKeyWord);\n            </script>\n<!--PlaceHolder：E68_SearchResultMyRecentKeyWord：你最近蒐尋過的關鍵字end-->\n<!--PlaceHolder：E68_SearchResult：搜尋結果start-->\n<script>\n    var ETU_Scupio_cookieName = \'newRecomCookieName\';\n</script>\n<div class="div998 searchBGLogo member-navi-bg clearfix" style="height:40px;">\n<div class="searchKWs clearfix">\n<div class="left clearfix" style="height:18px;">\n<h4>你是不是要找：</h4>\n<script>\n                var RelatedKeyWord = \'\';\n                var RelatedKeyWord_array = RelatedKeyWord.split(\',\');\n                for(var i=0, j=RelatedKeyWord_array.length; i<j; i++)\n                {\n                    document.write(\'<a href="#" class="GAEventTracking PHType-AD singleKWSearch" ga_eventtype="search" ga_eventname="RelatedKeyWord" ga_eventpictxt="text">\'+ RelatedKeyWord_array[i] +\'</a>\');\n                }\n            </script>\n</div>\n<div class="right clearfix" style="height:18px;">\n<h4>大家正在找：</h4>\n<script>\n                var HotKeyWord_everyone_array = HotKeyWord_everyone.split(\',\');\n                for(var i=0, j=HotKeyWord_everyone_array.length; i<j; i++)\n                {\n                    document.write(\'<a href="#" class="GAEventTracking PHType-AD singleKWSearch" ga_eventtype="search" ga_eventname="HotKeyWordByDay" ga_eventpictxt="text">\'+ HotKeyWord_everyone_array[i] +\'</a>\');\n                }\n            </script>\n</div>\n</div>\n</div>\n<div class="div998 searchForm clearfix">\n<form action="AllSearchFormResult.aspx" id="realForm" method="post" name="realForm">\n<input name="ProductSource" type="hidden" value=""/>\n<input name="CategoryID" type="hidden" value=""/>\n<input name="SearchKeyword" type="hidden" value=""/>\n<input name="OnlineDateStart" type="hidden" value=""/>\n<input name="OnlineDateEnd" type="hidden" value=""/>\n<input name="ProductMoneyStart" type="hidden" value=""/>\n<input name="ProductMoneyEnd" type="hidden" value=""/>\n<input name="Video" type="hidden" value="false"/>\n<input name="OrderBy" type="hidden" value="_weight_,DESC"/>\n<input name="QueryCmd" type="hidden" value=\'{"QCompC1":{"QC1":{"QT":2,"Operand1":"0","BOP":2,"Operand2":"","MetaField":"AdultProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":1,"Operand2":"554","MetaField":"BUNDLE_CD"}},"QCOP":2,"QC2":{"QT":2,"Operand1":"666","BOP":2,"Operand2":"","MetaField":"BUNDLE_CD"}}\'/>\n<input name="PageIndex" type="hidden" value="0"/>\n<input name="PageSize" type="hidden" value="40"/>\n<input name="CombinedCode" type="hidden" value=""/>\n<input name="QueryCmdName" type="hidden" value=""/>\n<input name="CategoryName" type="hidden" value=""/>\n<input name="hiotoryTree" type="hidden" value=""/>\n<input name="hiotoryTreeName" type="hidden" value=""/>\n<input name="Color" type="hidden" value=""/>\n<input name="Style" type="hidden" value=""/>\n<input name="ColorValue" type="hidden" value=""/>\n<input name="StyleValue" type="hidden" value=""/>\n<!--右上角分類階層結構 請於頁面新增此tag 並於form Submit時填入目前分類階層結構值-->\n<input id="CategoryTree" name="CategoryTree" type="hidden" value=""/>\n<!--搜尋頁傳值Form請幫我多加一個hidden欄位為進階關鍵字 關鍵字間以 ╪ 間隔-->\n<input name="AdvancedKeyword" type="hidden" value=""/>\n<!--input type="hidden" name="CacheSearch" value="true"-->\n</form>\n<script type="text/javascript">\n        var setSearchKeywordvalue = \' MeFOTO MK10 藍牙遙控 自拍棒／三角腳架 公司貨 \';\n        document.realForm.SearchKeyword.value = setSearchKeywordvalue;\n        //document.realForm.hiotoryTree.value = squery_hiotoryTree;\n        //document.realForm.hiotoryTreeName.value = squery_hiotoryTreeName;\n        //alert(squery_hiotoryTree);\n        //alert(document.realForm.hiotoryTreeName.value);\n        \n        var previousBack = function()\n        {\n                //document.realForm.ProductSource.value = \'\';\n                var billytree = squery_hiotoryTree.split(\',\');\n                var billytreeName = squery_hiotoryTreeName.split(\',\');\n\n                if(billytree.length >= 2)\n                {\n                    document.realForm.CategoryID.value = billytree[billytree.length-2];\n                    document.realForm.CategoryName.value = billytreeName[billytreeName.length-2];\n                    \n                    document.realForm.hiotoryTree.value = billytree.slice(0,billytree.length-1);\n                    document.realForm.hiotoryTreeName.value = billytreeName.slice(0,billytreeName.length-1);\n                }\n                \n                //document.realForm.SearchKeyword.value = oTarget.innerHTML;\n                //alert(document.realForm.SearchKeyword.value);\n                //document.realForm.OnlineDateStart.value = \'\';\n                //document.realForm.OnlineDateEnd.value = \'\';\n                //document.realForm.ProductMoneyStart.value = \'\';\n                //document.realForm.ProductMoneyEnd.value = \'\';\n                //document.realForm.Video.value = \'\';\n                //document.realForm.OrderBy.value = \'\';\n                //document.realForm.QueryCmd.value = \'\';\n                document.realForm.PageIndex.value = \'0\';\n                document.realForm.PageSize.value = \'20\';\n                //document.realForm.CombinedCode.value = \'\';\n                //alert(\'document.realForm.hiotoryTree.value = \' + document.realForm.hiotoryTree.value);\n                //alert(\'document.realForm.hiotoryTreeName.value = \' + document.realForm.hiotoryTreeName.value);\n                document.realForm.submit();\n        }\n        \n        var hasOpenX18Fun = function()\n        {\n            hidePopWin(false);\n            getCookieObj.setCookie("hasOpenX18",\'Y\'); //設定cookie\n        }\n    </script>\n</div>\n<script>\n    //判斷模式決定用哪種畫面 IMG:圖片模式 TEXT:圖文並列模式\n    var ListViewMode;\n    var ListViewDivisor;\n    var nowModeLIst;\n    var toggleObj;\n    \n    if(!getCookieObj.ModeList  || getCookieObj.ModeList == \'PHOTOMODE\')\n    {\n        nowModeLIst = \'PHOTOMODE\';\n        ListViewMode = \'width187-vertical\';\n    }\n    else\n    {\n        nowModeLIst = \'PHOTOTEXT\';\n        ListViewMode = \'width187-horizontal\';\n    }\n    \n\n    var buildCategoryThreeProducts = function(nowModeLIst)\n    {\n    \n        //alert(\'in buildCategoryThreeProducts function\');\n        \n        if(nowModeLIst == \'PHOTOMODE\')\n        {\n            ListViewMode = \'width187-vertical\';\n            getCookieObj.setCookie(\'ModeList\',\'PHOTOMODE\');\n            \n            jQuery(\'#toolbar .view a\').removeClass(\'on\');\n            jQuery(\'#toolbar .gallery a\').addClass(\'on\');\n            \n            jQuery(\'.searchResultContent .SingleProductItem\').each(function () {\n                jQuery(this).removeClass(\'width187-horizontal\');\n                jQuery(this).addClass(\'width187-vertical\');\n            });\n            \n        }\n        else\n        {\n            ListViewMode = \'width187-horizontal\';\n            getCookieObj.setCookie(\'ModeList\',\'PHOTOTEXT\');\n            \n            jQuery(\'#toolbar .view a\').removeClass(\'on\');\n            jQuery(\'#toolbar .list a\').addClass(\'on\');\n            \n            jQuery(\'.searchResultContent .SingleProductItem\').each(function () {\n                jQuery(this).removeClass(\'width187-vertical\');\n                jQuery(this).addClass(\'width187-horizontal\');\n            });\n        }\n        \n    };\n    \n    var buildBuyNowLink = function(Good_ID, isKit, isPontaVoucher, ONLINE, BUNDLE_CD, PRC)\n    {\n        var linkURL = \'\';\n        \n        if(isKit == \'Y\')\n        {\n            if(ONLINE == \'Y\')\n            {\n                linkURL = \'<a href="ProductDetail.aspx?ProductSKU=\'+ Good_ID +\'" class="btn_GdKit_BuyNow">立即結帳</a>\';\n            }\n            else\n            {\n                //linkURL = \'<a href="javascript:;">銷售完畢</a>\';\n                linkURL = \'<a class="btn_Gd_soldOut" onclick="GoColorStyle(\'+ Good_ID +\')" href="javascript:;" GOODID="\'+ Good_ID +\'">貨到通知</a>\';\n            }\n        }\n        else if(isPontaVoucher == \'Y\')\n        {\n            if(ONLINE == \'Y\')\n            {\n                linkURL = \'<a href="ProductDetail.aspx?ProductSKU=\'+ Good_ID +\'" class="btn_GdTicket_BuyNow">立即結帳</a>\';\n            }\n            else\n            {\n                //linkURL = \'<a href="javascript:;">銷售完畢</a>\';\n                linkURL = \'<a class="btn_Gd_soldOut" onclick="GoColorStyle(\'+ Good_ID +\')" href="javascript:;" GOODID="\'+ Good_ID +\'">貨到通知</a>\';\n            }\n        }\n        else\n        {\n            if(ONLINE == \'Y\')\n            {\n                linkURL = \'<a href="javascript:;" onclickFun="GoColorStyle(\\\'\'+ Good_ID +\'\\\')" class="btn_Gd_BuyNow" isKit="\'+ isKit +\'" isPontaVoucher="\'+ isPontaVoucher + \'" ONLINE="\'+ ONLINE +\'" BUNDLECD="\'+ BUNDLE_CD +\'" GOODPRC="\'+ PRC +\'" GOODID="\'+ Good_ID +\'">立即結帳</a>\';\n            }\n            else\n            {\n                linkURL = \'<a class="btn_Gd_soldOut" onclick="GoColorStyle(\'+ Good_ID +\')" href="javascript:;" GOODID="\'+ Good_ID +\'">貨到通知</a>\';\n            }\n        }\n        \n        return linkURL;\n    };\n    \n    var buildAddtoCartLink = function(Good_ID, isKit, isPontaVoucher, ONLINE, BUNDLE_CD, PRC)\n    {\n        var linkURL = \'\';\n        \n        if(isKit == \'Y\')\n        {\n            linkURL = \'<a href="ProductDetail.aspx?ProductSKU=\'+ Good_ID +\'" class="btn_GdKit_compare">加入購物車</a>\';\n        }\n        else if(isPontaVoucher == \'Y\')\n        {\n            linkURL = \'<a class="btn_GdTicket_compare" onclick="sys_AddToShoppingCar(\'+ Good_ID +\')" href="javascript:;" GOODID="\'+ Good_ID +\'">加入購物車</a>\';\n        }\n        else\n        {\n            linkURL = \'<a class="btn_Gd_compare" onclick="sys_AddToShoppingCar(\'+ Good_ID +\')" href="javascript:;" GOODID="\'+ Good_ID +\'">加入購物車</a>\';\n        }\n        \n        return linkURL;\n    };\n    var buildGooDPrC = function (Good_ID, DISCOUNT_VALUE, isPontaVoucher, PRC)\n    {\n        var PRC_Content =\'\';\n        if(isPontaVoucher == \'Y\'){\n            if(pointType == \'1\'){\n                PRC_Content = \'<span class="GOOD-PRCText"><ins class="Exchange_icon"></span></ins><b>\' + Sys_FormatNumber(pointNum1) + \'</b>點<div style="text-align:right;"></div></div>\'\n            }\n            else{\n                PRC_Content = \'<span class="GOOD-PRCText"><ins class="Exchange_icon"></span></ins><b>\' + Sys_FormatNumber(pointNum2) + \'</b>點 + \' + Sys_FormatNumber(pointPlusMoney) +\'元<div style="text-align:right;"></div></div>\'\n            }\n        }\n        else{\n            PRC_Content = \'<span class="GOOD-PRCText">\'+Sys_showSearchPRCText(DISCOUNT_VALUE) +\'</span> $<b>\'+Sys_showSearchPRCValue(DISCOUNT_VALUE,PRC) +\'</b><div style="text-align:right;"></div></div>\'\n        }\n\n        return PRC_Content;\n    };\n</script>\n<div class="div998 searchContent clearfix">\n<div class="leftOptions">\n<h2>進階搜尋</h2>\n<!--進階搜尋:區塊:依價格 + 其他條件-->\n<div class="advancedSearch">\n<h4>‧商品來源<img src="../R6Images/searchicon/new.png" style="vertical-align: middle;"/></h4>\n<input checked="checked" id="s01" name="soucreFrom" type="radio" value="Normal"/><label for="s01" style="padding-right:15px;">一般</label>\n<input id="s02" name="soucreFrom" type="radio" value="Travel"/><label for="s02" style="padding-right:15px;">旅遊</label>\n<input id="s03" name="soucreFrom" type="radio" value="Adult"/><label for="s03">成人</label>\n<input class="searchKWInput condense" onblur="if(this.value==\'\'){this.value=\'在結果中搜尋\';}" onfocus="if(this.value==\'在結果中搜尋\'){this.value=\'\';};jQuery(\'&lt;selector&gt;\').attr(\'checked\', false);" type="text" value="在結果中搜尋"/>\n<h4>‧依價格</h4>\n<input class="searchKWInput lowPRC" onblur="if(this.value==\'\'){this.value=\'最低\';}" onfocus="if(this.value==\'最低\'){this.value=\'\';};jQuery(\'input[type=radio][name=\\\'pricerange\\\']\').attr(\'checked\', false);" type="text" value="最低"/> ~ <input class="searchKWInput highPRC" onblur="if(this.value==\'\'){this.value=\'最高\';}" onfocus="if(this.value==\'最高\'){this.value=\'\';};jQuery(\'input[type=radio][name=\\\'pricerange\\\']\').attr(\'checked\', false);" type="text" value="最高"/><br/>\n<input highprc="2000" id="p01" lowprc="0" name="pricerange" type="radio"/> <label for="p01">0-2000元</label><br/>\n<input highprc="3000" id="p02" lowprc="2001" name="pricerange" type="radio"/> <label for="p02">2001-3000元</label><br/>\n<input highprc="4000" id="p03" lowprc="3001" name="pricerange" type="radio"/> <label for="p03">3001-4000元</label><br/>\n<input highprc="" id="p04" lowprc="4001" name="pricerange" type="radio"/> <label for="p04">4001元以上</label>\n<script language="javascript">\n                    if(\'\' != \'\')\n                    {\n                        jQuery(\'.lowPRC\').val(\'\');\n                    }\n                    if(\'\' != \'\')\n                    {\n                        jQuery(\'.highPRC\').val(\'\');\n                    }\n                </script>\n<h4>‧其他條件</h4>\n<input class="otherFilters" id="express" name="type_24" type="checkbox" value="24H"/><label for="express">快速到貨</label><br/>\n<input class="otherFilters" id="store" name="type_Store" type="checkbox" value="Store"/><label for="store">超商取貨</label><br/>\n<!--<input id="TVProduct" type="checkbox" name="type_TVProduct" class="otherFilters" value="TVProduct" style="display:none;"><label for="TVProduct" style="display:none;">電視商品</label><br>-->\n<input class="otherFilters" id="onlystock" name="type_Coupon" type="checkbox" value="Coupon"/><label for="onlystock">可使用折價券</label><br/>\n<input class="otherFilters" id="OnSale" name="type_OnSale" type="checkbox" value="OnSale"/><label for="OnSale">促銷商品</label><br/>\n<input class="searchKWInput searchBtn" name="Submit" type="button" value="搜尋"/>\n<script language="javascript">\n                \n                    //這是根據下方各QueryCommand 取出來的\n                    var chkCMD = new Array();\n                    chkCMD[0] = \'{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"}\';\n                    chkCMD[1] = \'{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"}\';\n                    chkCMD[2] = \'{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"}\';\n                    chkCMD[3] = \'{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}\';\n                    chkCMD[4] = \'{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"}\';\n                    chkCMD[5] = \'{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}\';\n                    chkCMD[6] = \'{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"}\';\n                    chkCMD[7] = \'{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}\';\n                \n                    var chkCMD_Name = new Array();\n                    chkCMD_Name = ["Travel","Adult","Normal","OnSale","24H","Store","Coupon","TVProduct"];\n\n                    var chkCMD_Result = new Array();\n\n                    var type_24 = \'{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_Store = \'{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    \n                    var type_TVProduct = \'{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_Coupon = \'{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_OnSale = \'{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n        \n                    var type_Normal = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \n                    //var type_Adult = \'{"QCompC1"{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_Adult  = \'{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_Travel = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    \n                    var type_24H_Normal = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_24H_Travel = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_24H_Adult = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_24H_Store = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n\n                    var type_24H_Store_Normal = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_Store_Travel = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_Store_Adult = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n\n                    var type_24H_Coupon                 = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_24H_Coupon_Normal          = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_Coupon_Travel          = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_Coupon_Adult           = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    \n                    var type_24H_OnSale                 = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_24H_OnSale_Normal          = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_OnSale_Travel          = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_OnSale_Adult           = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    \n                    var type_24H_TVProduct              = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_24H_TVProduct_Normal       = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_TVProduct_Travel       = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_TVProduct_Adult        = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    \n                    var type_24H_Store_Coupon           = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_24H_Store_Coupon_Normal    = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"}}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_24H_Store_Coupon_Travel    = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"}}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_24H_Store_Coupon_Adult     = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"}}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    \n                    var type_24H_Store_OnSale           = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_24H_Store_OnSale_Normal    = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}}},"QCOP":3,"QCompC2":{"QC1":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_Store_OnSale_Adult     = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}}},"QCOP":3,"QCompC2":{"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_Store_OnSale_Travel    = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}}},"QCOP":3,"QCompC2":{"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    \n                    var type_24H_Store_TVProduct          = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_24H_Store_TVProduct_Normal   = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":3,"QCompC2":{"QC1":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_Store_TVProduct_Travel   = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":3,"QCompC2":{"QC1":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_Store_TVProduct_Adult    = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":3,"QCompC2":{"QC1":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\'; \n                    \n                    var type_24H_Coupon_OnSale          = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_24H_Coupon_OnSale_Normal   = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}}},"QCOP":3,"QCompC2":{"QC1":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_Coupon_OnSale_Travel   = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}}},"QCOP":3,"QCompC2":{"QC1":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_Coupon_OnSale_Adult    = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}}},"QCOP":3,"QCompC2":{"QC1":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                \n                    var type_24H_TVProduct_Coupon          = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_24H_TVProduct_Coupon_Normal   = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":3,"QCompC2":{"QC1":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_TVProduct_Coupon_Travel   = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":3,"QCompC2":{"QC1":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_TVProduct_Coupon_Adult    = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":3,"QCompC2":{"QC1":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\'; \n                \n                    var type_24H_TVProduct_OnSale          = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_24H_TVProduct_OnSale_Normal   = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":3,"QCompC2":{"QC1":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_TVProduct_OnSale_Travel   = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":3,"QCompC2":{"QC1":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_TVProduct_OnSale_Adult    = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":3,"QCompC2":{"QC1":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\'; \n                \n                    var type_24H_Store_Coupon_OnSale    = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}}},"QCOP":3,"QCompC2":{"QC1":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_Store_Coupon_OnSale_Normal     = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"}}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_Store_Coupon_OnSale_Adult      = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"}}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_Store_Coupon_OnSale_Travel     = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n            \n                    var type_24H_Store_TVProduct_Coupon    = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":3,"QCompC2":{"QC1":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_Store_TVProduct_Coupon_Normal     = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"}}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_Store_TVProduct_Coupon_Adult      = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"}}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_Store_TVProduct_Coupon_Travel     = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n            \n                    var type_24H_Store_TVProduct_OnSale    = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":3,"QCompC2":{"QC1":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_Store_TVProduct_OnSale_Normal     = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"}}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_Store_TVProduct_OnSale_Adult      = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"}}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_Store_TVProduct_OnSale_Travel     = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                                              \n                    var type_24H_TVProduct_Coupon_OnSale    = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":3,"QCompC2":{"QC1":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_TVProduct_Coupon_OnSale_Normal     = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"}}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_TVProduct_Coupon_OnSale_Adult      = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"}}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_TVProduct_Coupon_OnSale_Travel     = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    \n                    var type_Store_Normal           = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_Store_Travel           = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_Store_Adult            = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';      \n                    \n                    var type_Store_Coupon           = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';                        \n                    var type_Store_Coupon_Normal    = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_Store_Coupon_Travel    = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_Store_Coupon_Adult     = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    \n                    var type_Store_OnSale           = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_Store_OnSale_Normal    = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_Store_OnSale_Travel    = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_Store_OnSale_Adult     = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n    \n                    var type_Store_TVProduct            = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_Store_TVProduct_Normal     = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_Store_TVProduct_Travel     = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_Store_TVProduct_Adult      = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    \n                    var type_Store_Coupon_OnSale    = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_Store_Coupon_OnSale_Normal = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_Store_Coupon_OnSale_Travel = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_Store_Coupon_OnSale_Adult  = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n        \n                    var type_Store_TVProduct_Coupon     = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_Store_TVProduct_Coupon_Normal  = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_Store_TVProduct_Coupon_Travel  = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_Store_TVProduct_Coupon_Adult   = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    \n                    var type_Store_TVProduct_OnSale     = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_Store_TVProduct_OnSale_Normal  = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_Store_TVProduct_OnSale_Travel  = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_Store_TVProduct_OnSale_Adult   = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    \n                    var type_Store_TVProduct_Coupon_OnSale    = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":3,"QCompC2":{"QC1":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_Store_TVProduct_Coupon_OnSale_Normal     = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"}}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_Store_TVProduct_Coupon_OnSale_Adult      = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"}}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_Store_TVProduct_Coupon_OnSale_Travel     = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    \n                    var type_Coupon_Normal          = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_Coupon_Travel          = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_Coupon_Adult           = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    \n                    var type_Coupon_OnSale          = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';                              \n                    var type_Coupon_OnSale_Normal   = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_Coupon_OnSale_Travel   = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_Coupon_OnSale_Adult    = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"}},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QCompC":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                       \n                    var type_OnSale_Normal          = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_OnSale_Travel          = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_OnSale_Adult           = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';                \n                                      \n                    var type_TVProduct_Normal           = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_TVProduct_Travel           = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_TVProduct_Adult            = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';        \n                    \n                    var type_TVProduct_Coupon           = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';                              \n                    var type_TVProduct_Coupon_Normal    = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_TVProduct_Coupon_Travel    = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_TVProduct_Coupon_Adult     = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    \n                    var type_TVProduct_OnSale           = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';                              \n                    var type_TVProduct_OnSale_Normal    = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_TVProduct_OnSale_Travel    = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_TVProduct_OnSale_Adult     = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';    \n                    \n                    var type_TVProduct_Coupon_OnSale    = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_TVProduct_Coupon_OnSale_Normal = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_TVProduct_Coupon_OnSale_Travel = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    var type_TVProduct_Coupon_OnSale_Adult  = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}}},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}\';\n                    \n                    var type_24H_Store_TVProduct_Coupon_OnSale = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"}}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_Store_TVProduct_Coupon_OnSale_Normal = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"0","BOP":2,"MetaField":"AdultProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_Store_TVProduct_Coupon_OnSale_Travel = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"TravelProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    var type_24H_Store_TVProduct_Coupon_OnSale_Adult = \'{"QCompC1":{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"},"QCOP":1,"QC2":{"QT":2,"Operand1":"30","BOP":2,"MetaField":"PRODUCTSOURCE"}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}}},"QCOP":1,"QCompC2":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"},"QCOP":3,"QC2":{"QT":2,"Operand1":"555","BOP":2,"MetaField":"BUNDLE_CD"}}}\';\n                    \n                    \n                    var nowQueryCmdType = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"0","BOP":2,"Operand2":"","MetaField":"AdultProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":1,"Operand2":"554","MetaField":"BUNDLE_CD"}},"QCOP":2,"QC2":{"QT":2,"Operand1":"666","BOP":2,"Operand2":"","MetaField":"BUNDLE_CD"}}\';\n                    //alert(nowQueryCmdType); \n                    //var nowQueryCmdType = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"StoreService"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"MetaField":"AdultProduct"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}}}\';\n                    \n                    for(var i=0, j=chkCMD.length; i<j; i++)\n                    {\n                        if(nowQueryCmdType.indexOf(chkCMD[i]) != -1)\n                        {\n                            chkCMD_Result[chkCMD_Result.length] = i;\n                        }\n                    }\n                    \n                    //alert(\'chkCMD_Result = \' + chkCMD_Result);\n                    \n                    if(chkCMD_Result.length > 0)\n                    {\n                        jQuery(\'.otherFilters\').each(function (m) {\n                            for(var m=0, n=chkCMD_Result.length; m<n; m++)\n                            {\n                                if( jQuery(this).attr(\'value\') == chkCMD_Name[chkCMD_Result[m]] )\n                                {\n                                    jQuery(this).attr("checked", "checked");\n                                }\n                            }\n                        });\n                        \n                        jQuery("input[name=\'soucreFrom\']").each(function (m) {\n                            for(var m=0, n=chkCMD_Result.length; m<n; m++)\n                            {\n                                if( jQuery(this).attr(\'value\') == chkCMD_Name[chkCMD_Result[m]] )\n                                {\n                                    jQuery(this).attr("checked", "checked");\n                                }\n                            }\n                        });\n                    }\n                    \n                    \n                    for(var m=0, n=chkCMD_Result.length; m<n; m++)\n                    {\n                        //alert( typeof(chkCMD_Result[m]) )\n                        \n                        if(chkCMD_Result[m] == 1)\n                        {\n                            if(!getCookieObj.hasOpenX18)\n                            {\n                                document.getElementById(\'popupTitleBar\').style.display=\'none\';\n                                document.getElementById(\'popupInner\').style.border=\'0px\';\n                                document.getElementById(\'popupInner\').style.background=\'rgba(100, 100, 100, 0)\';\n                                showPopWin("../R6Images/X18/index.html", 940, 400,"",false,false); \n                            }\n                        }\n                    }\n                    \n                    \n                </script>\n</div>\n<!--進階搜尋:區塊:分類選擇-->\n<div class="categorySearch">\n<h3>分類選擇</h3>\n<!--ol>\n                    <li><a href="#">3C(319)</a>\n                        <ol>\n                            <li><a href="#">SONY(153)</a></li>\n                            <li><a href="#">三星(38)</a></li>\n                            <li><a href="#">HTC(110)</a></li>\n                            <li><a href="#">Apple(18)</a></li>\n                        </ol>\n                    </li>\n                </ol-->\n<script type="text/javascript">\n                    var newSR_LimitCategory = \'{ "Data": {"Count": "1", "Repeater": {"Content": {"CategoryID": "4", "Count": "2", "Name": "3C資訊", "Source": "Category" } } }}\';\n                    newSR_LimitCategory = newSR_LimitCategory.parseJSON();\n                    \n                    var LimitCategory_aHTML = new Array;\n                    LimitCategory_aHTML[LimitCategory_aHTML.length] = \'<ol>\';\n                    \n                    //以下範例ex：全站 > 3C資訊 > 資訊周邊\n            \n                    //這是組出最後一層分類之母分類，已範例為例就是組出"全站 > 3C資訊 > 資訊周邊"\n                    var squery_hiotoryTree_spilt = squery_hiotoryTree.split(\',\');\n                    var squery_hiotoryTreeName_spilt = squery_hiotoryTreeName.split(\',\');\n                    var index;\n                    \n                    for(var i=0, j=squery_hiotoryTree_spilt.length; i<j; i++)\n                    {\n                        index = i;\n                        if(squery_hiotoryTreeName_spilt[i] != "")\n                        {\n                            LimitCategory_aHTML[LimitCategory_aHTML.length] = \'<li>\';\n                            LimitCategory_aHTML[LimitCategory_aHTML.length] = \'    <a href="#" class="hasCategoryID" CategoryID="\'+ squery_hiotoryTree_spilt[i] +\'" level="\'+ (index+1) +\'">\'+ squery_hiotoryTreeName_spilt[i] +\'</a>\';\n                            LimitCategory_aHTML[LimitCategory_aHTML.length] = \'    <ol>\';\n                        }\n                    }\n            \n                    //這是組出該分類下面所有的子分類 ex：全站 > 3C資訊 > 資訊周邊  以下是"資訊周邊" 下的所有子分類\n                    if(newSR_LimitCategory.Data.Count != \'0\')\n                    {\n                        newSR_LimitCategory.Data.Repeater.Content = ConverCont(newSR_LimitCategory.Data.Repeater.Content); \n                        for(var i=0, j=newSR_LimitCategory.Data.Repeater.Content.length; i<j; i++)\n                        {\n                            LimitCategory_aHTML[LimitCategory_aHTML.length] = \'<li><a href="#" class="hasCategoryID" CategoryID="\'+ newSR_LimitCategory.Data.Repeater.Content[i].CategoryID +\'" level="\'+ (index+2) +\'">\'+ newSR_LimitCategory.Data.Repeater.Content[i].Name +\' ( \'+ newSR_LimitCategory.Data.Repeater.Content[i].Count +\' )</a></li>\'\n                        }\n                    }\n                    \n                    for(var i=0, j=squery_hiotoryTree_spilt.length; i<j; i++)\n                    {\n                        if(squery_hiotoryTreeName_spilt[i] != "")\n                        {\n                            LimitCategory_aHTML[LimitCategory_aHTML.length] = \'    </ol>\';\n                            LimitCategory_aHTML[LimitCategory_aHTML.length] = \'</li>\';\n                        }\n                    }\n                    \n                    \n                    LimitCategory_aHTML[LimitCategory_aHTML.length] = \'</ol>\';\n                    document.write(LimitCategory_aHTML.join(\'\'));\n                </script>\n</div>\n<!--進階搜尋:區塊:你最近找過(原:你最近搜尋過的關鍵字)-->\n<div class="recentSearch">\n<h3>你最近找過</h3>\n<script>\n                    var E68_SearchResultMyRecentKeyWord_array = E68_SearchResultMyRecentKeyWord.split(\',\');\n                    \n                    var E68_SRMyRecentKeyWord_html = new Array();\n                    E68_SRMyRecentKeyWord_html[E68_SRMyRecentKeyWord_html.length] = \'<ol>\';\n                    \n                    if(E68_SearchResultMyRecentKeyWord == \'\')\n                    {\n                        E68_SRMyRecentKeyWord_html[E68_SRMyRecentKeyWord_html.length] = \'<li>無</li>\';\n                    }\n                    else\n                    {\n                        for(var i=0, j=E68_SearchResultMyRecentKeyWord_array.length; i<j; i++)\n                        {\n                            E68_SRMyRecentKeyWord_html[E68_SRMyRecentKeyWord_html.length] = \'<li><a href="#" class="GAEventTracking PHType-AD singleKWSearch" ga_eventtype="search"ga_eventname="selfSearchKeyWord" ga_eventpictxt="text">\'+ E68_SearchResultMyRecentKeyWord_array[i] +\'</a></li>\';\n                        }\n                    }\n                    \n                    E68_SRMyRecentKeyWord_html[E68_SRMyRecentKeyWord_html.length] = \'</ol>\';\n                    \n                    document.write(E68_SRMyRecentKeyWord_html.join(\'\'));\n                </script>\n<!--ol>\n                    <li><a href="#">一般數位</a></li>\n                    <li><a href="#">防水數位相機</a></li>\n                    <li><a href="#">底片相機</a></li>\n                    <li><a href="#">拍立得</a></li>\n                    <li><a href="#">高階數位／類單眼</a></li>\n                    <li><a href="#">數位單眼</a></li>\n                </ol-->\n</div>\n<!--進階搜尋:區塊:熱門搜尋排行榜(原:7天熱門關鍵字)-->\n<div class="rankingSearch">\n<h3>熱門搜尋排行榜</h3>\n<script>\n                    var HotKeyWord_topRank_array = HotKeyWord_topRank.split(\',\');\n                    \n                    var HotKeyWord_topRank_html = new Array();\n                    HotKeyWord_topRank_html[HotKeyWord_topRank_html.length] = \'<ol>\';\n                    \n                    if(HotKeyWord_topRank == \'\')\n                    {\n                        HotKeyWord_topRank_html[HotKeyWord_topRank_html.length] = \'<li>無</li>\';\n                    }\n                    else\n                    {\n                        for(var i=0, j=HotKeyWord_topRank_array.length; i<j; i++)\n                        {\n                            HotKeyWord_topRank_html[HotKeyWord_topRank_html.length] = \'<li><a href="#" class="GAEventTracking PHType-AD singleKWSearch" ga_eventtype="search" ga_eventname="HotKeyWordByWeek" ga_eventpictxt="text">\'+ HotKeyWord_topRank_array[i] +\'</a></li>\';\n                        }\n                    }\n                    \n                    HotKeyWord_topRank_html[HotKeyWord_topRank_html.length] = \'</ol>\';\n                    \n                    document.write(HotKeyWord_topRank_html.join(\'\'));\n                </script>\n<!--ol>\n                    <li><a href="#">一般數位</a></li>\n                    <li><a href="#">防水數位相機</a></li>\n                    <li><a href="#">底片相機</a></li>\n                    <li><a href="#">拍立得</a></li>\n                    <li><a href="#">高階數位／類單眼</a></li>\n                    <li><a href="#">數位單眼</a></li>\n                    <li><a href="#">單眼相機機身</a></li>\n                    <li><a href="#">單眼相機鏡頭／濾鏡</a></li>\n                    <li><a href="#">單眼鏡頭蓋</a></li>\n                    <li><a href="#">辦公設備</a></li>\n                </ol-->\n</div>\n</div>\n<div class="rightResult clearfix">\n<!--進階結果:區塊:搜尋關鍵字 + 搜尋限縮關鍵字 + 分類搜尋 + 搜尋總筆數-->\n<h2 class="resultInfo">\n<span class="searchKeyWord">\n                    搜尋：<!--b><a href="#" class="showKeyWordStep">3C</a></b> > <b><a href="#" class="showKeyWordStep">Nikon</a></b> > <b><a href="#" class="showKeyWordStep lastnode">D5300</a></b-->\n<script language="javascript">\n                        var showKeyWord_arry = new Array();\n                        var showAdvKeyWord_arry = new Array();\n                        \n                        if( setSearchKeywordvalue != \'\')\n                        {\n                            \n                            if( document.realForm.AdvancedKeyword.value != \'\')\n                            {\n                                showKeyWord_arry[showKeyWord_arry.length] = \'<b><a href="#" class="showKeyWordStep">\'+ setSearchKeywordvalue +\'</a></b>\';\n                            }\n                            else\n                            {\n                                showKeyWord_arry[showKeyWord_arry.length] = \'<b>\'+ setSearchKeywordvalue +\'</b>\';\n                            }\n                        }\n                        \n                        if( document.realForm.AdvancedKeyword.value != \'\')\n                        {\n                            showAdvKeyWord_arry = document.realForm.AdvancedKeyword.value.split(\'╪\');\n                            \n                            for(var i=0, j=showAdvKeyWord_arry.length; i<j; i++)\n                            {\n                                if( i == (showAdvKeyWord_arry.length - 1) )\n                                {\n                                    showKeyWord_arry[showKeyWord_arry.length] = \'<b> > <a href="#" class="showKeyWordStep lastnode">\'+ showAdvKeyWord_arry[i] +\'</a></b>\';\n                                }\n                                else\n                                {\n                                    showKeyWord_arry[showKeyWord_arry.length] = \'<b> > <a href="#" class="showKeyWordStep">\'+ showAdvKeyWord_arry[i] +\'</a></b>\';\n                                }\n                            }\n                        }\n                        \n                        document.write( showKeyWord_arry.join(\'\') );\n                    </script>\n</span>\n<div class="clearfix">\n<span class="searchResultCrumbs">\n                        目前搜尋條件：<!--a href="#">全站</a> / <a href="#">3C</a> / <a href="#">Nikon</a> / <a href="#" class="lastnode">Nikon</a-->\n<script language="javascript">\n                            var categoryName_arry = new Array();\n                            for(var i=0, j=squery_hiotoryTree_spilt.length; i<j; i++)\n                            {\n                                if(squery_hiotoryTreeName_spilt[i] == \'\')\n                                {\n                                    categoryName_arry[categoryName_arry.length] = \'<a href="#" class="hasCategoryID" level="\'+ (i+1) +\'" CategoryID="\'+ squery_hiotoryTree_spilt[i] +\'">全站</a>\';\n                                }\n                                else\n                                {\n                                    categoryName_arry[categoryName_arry.length] = \' / <a href="#" class="hasCategoryID" level="\'+ (i+1) +\'" CategoryID="\'+ squery_hiotoryTree_spilt[i] +\'">\'+ squery_hiotoryTreeName_spilt[i].split(\' ( \')[0] +\'</a>\';\n                                }\n                            }\n                            document.write( categoryName_arry.join(\'\') );\n                        </script>\n</span>\n<span class="searchResultTotal">共2筆結果</span>\n</div>\n</h2>\n<div class="advSearchNote" style="display:none;"><span>貼心提醒：</span>您搜尋的商品結果超過100筆，為了讓您更精準找到您想要的，可於左側使用【進階搜尋】功能，縮小範圍搜尋！</div>\n<script>\n                var mTotalCount = 2;\n                \n                if(mTotalCount > 100)\n                {\n                    jQuery(\'.advSearchNote\').show();\n                    jQuery(\'.advancedSearch\').addClass(\'on\');\n                }\n            </script>\n<!--進階結果:區塊:排序方式 + 顯示模式-->\n<div class="clearfix" id="toolbar">\n<div class="sortBy">\n<h4>‧排序方式：</h4>\n<ol>\n<li class="on"><a href="#" queryparmorderby="_weight_,DESC">高相關</a><div class="arrow-down"></div></li>\n<li id="PrcSort">\n<a href="#" queryparmorderby="">價格排序</a>\n<ol>\n<li><a href="#" queryparmorderby="PRC,ASC">由低到高</a></li>\n<li><a href="#" queryparmorderby="PRC,DESC">由高到低</a></li>\n</ol>\n</li>\n<li><a href="#" queryparmorderby="OnlineDateTime,DESC">最新</a></li>\n<li><a href="#" queryparmorderby="HotView,DESC">最熱門</a></li>\n<li><a href="#" queryparmorderby="HotSale,DESC">最熱銷</a></li>\n</ol>\n<script language="javascript">\n                        if(\'_weight_,DESC\' != \'\')\n                        {\n                            jQuery(\'#toolbar .sortBy li\').removeClass(\'on\');\n                            jQuery(\'#toolbar .sortBy li\').each(function () \n                            {\n                                jQuery(this).find(\'.arrow-down\').remove();\n                            });\n                            \n                            if (\'_weight_,DESC\' == \'PRC,ASC\' || \'_weight_,DESC\' == \'PRC,DESC\')\n                            {\n                                jQuery("#PrcSort").addClass(\'on\');\n                                jQuery("#PrcSort").append(\'<div class="arrow-down"></div>\');\n                                \n                                jQuery(\'#PrcSort ol a\').each(function (){\n                                    if( jQuery(this).attr(\'QueryParmOrderBy\') == \'_weight_,DESC\' )\n                                    {\n                                        jQuery(this).css(\'color\',\'#990000\');\n                                        jQuery(this).css(\'font-weight\', \'bold\');\n                                    }\n                                });\n                            }\n                            else\n                            {\n                                jQuery(\'#toolbar .sortBy a\').each(function (){\n                                    if( jQuery(this).attr(\'QueryParmOrderBy\') == \'_weight_,DESC\' )\n                                    {\n                                        jQuery(this).parent().addClass(\'on\');\n                                        jQuery(this).parent().append(\'<div class="arrow-down"></div>\');\n                                    }\n                                });\n                            }\n                        }\n                    </script>\n</div>\n<div class="view">\n<h4>‧顯示模式：</h4>\n<ol>\n<li class="gallery"><a href="javascript:;" onclick="buildCategoryThreeProducts(\'PHOTOMODE\');" title="顯示圖片"></a></li>\n<li style="border-right:1px solid #999999; width:1px; margin:0 5px; padding:0; height:22px;"></li>\n<li class="list"><a href="javascript:;" onclick="buildCategoryThreeProducts(\'PHOTOTEXT\');" title="顯示圖文並列"></a></li>\n</ol>\n</div>\n</div>\n<!--進階結果:區塊:列出所有搜尋的商品-->\n<div class="searchResultContent clearfix">\n<!-- Product List START-->\n<script language="javascript">\n                    \n                    var srHTML = new Array();\n                    var aPL_GOODID = new Array();\n                    var aPL_GOODNM = new Array();\n                    var aPL_PRC = new Array();\n                    var aPL_DISCOUNT_VALUE = new Array();\n                    var aPL_BUNDLECD = new Array();\n                    var aPL_MAPTYPE = new Array();\n                    var aPL_STOREID = new Array();\n                    var aPL_CATEGORYID = new Array();\n                    var aPL_SMS = new Array();\n                    var aPL_SMS1 = new Array();\n                    var aPL_SMS2 = new Array();\n                    var aPL_SMS3 = new Array();\n                    var aPL_ONLINE = new Array();\n                    var aPL_OneDayShip = new Array();\n                    var aPL_StoreService = new Array();\n                    var aPL_AdultProduct = new Array();\n                    var aPL_Hiwey = new Array();\n                    var aPL_PageIndex = \'0\';\n\n                    //Vizury 追蹤碼\n                    var Vizury_GOODID = \'\';\n                    var Vizury_COUNT = 1;\n\n                    var compareWord = squery_SearchKeyword.replace(/\\&/g, \'＆\');\n                    //fish 20150721 ETMall 搜尋結果頁無法呈現商品列表資訊 DF-6118 \n                    compareWord = compareWord.replace(/\\//g,\'\\\\\\/\');\n                    var compareResult;\n                    \n                    var goCompare = (compareWord.indexOf(\'++\') != -1)? false : true;\n\n                    var goodsNameTag = \'\';\n                    var goodsNameTmp = changecar(\'MeFOTO 美孚 MK10 自拍腳架 自拍器 自拍棒 附藍芽 遙控器 藍\\/紅 (公司貨)\');\n                    var pointType = \'\';\n                    var pointNum1 = \'\';\n                    var pointNum2 = \'\';\n                    var pointPlusMoney = \'\';\n                    //compareWord = compareWord.replace(/\\//g,\'\\\\\\/\');\n                    goodsNameTag = goodsNameTmp;\n                    //fish 20150721 ETMall 搜尋結果頁無法呈現商品列表資訊 DF-6118 \n                    goodsNameTmp = goodsNameTmp.replace(/\\／/g, \'\\/\')\n                    \n                    if(goCompare)\n                    {\n                        eval("var compareStatement = /(.*)(" + compareWord + ")(.*)/i");\n                        if (compareResult = goodsNameTmp.match(compareStatement))\n                        {\n                            goodsNameTag = compareResult[1] + "<span class=\'marked\'>" + compareResult[2] + "</span>" + compareResult[3];\n                        }\n                    }\n                    \n                    \n                    /*\n                    if (compareResult = goodsNameTmp.match(compareStatement))\n                    {\n                        goodsNameTag = compareResult[1] + "<span class=\'marked\'>" + compareResult[2] + "</span>" + compareResult[3];\n                    }\n                    else\n                    {\n                        goodsNameTag = goodsNameTmp;\n                    }\n                    */\n                    goodsNameTag = DoubleToSingle(goodsNameTag);\n                    aPL_GOODID[0] = \'6011539\';\n                    aPL_SMS[0] = changecar(\'收合19.5CM/展開85CM/重量250g##適手機/相機及GOPRO 使用##相容IOS5.0與Android4.2以上照相功能\');\n                    aPL_SMS1[0] = aPL_SMS[0].split(\'##\')[0];\n                    aPL_SMS2[0] = aPL_SMS[0].split(\'##\')[1];\n                    aPL_SMS3[0] = aPL_SMS[0].split(\'##\')[2];\n                    if(aPL_SMS[0].split(\'##\').length==2)\n                    {\n                        aPL_SMS3[0] = \'\';\n                    }\n                    else if(aPL_SMS[0].split(\'##\').length==1)\n                    {\n                        aPL_SMS2[0] = \'\';\n                        aPL_SMS3[0] = \'\';\n                    }\n                    srHTML[srHTML.length] = [\n                    \'<div class="SingleProductItem \'+ ListViewMode +\' clearfix  GOODIDStr6011539">\',\n                    \'    <div class="GOOD-img">\',\n                    \'        <a class="GAEventTracking PHType-AD" href="ProductDetail.aspx?ProductSKU=6011539&kw=\'+ squery_SearchKeyword +\'&pi=\'+ aPL_PageIndex +\'" GA_EventType="search" GA_EventName="resulePRod_Img" GA_EventPicTxt="pro">\',\n                    \'            <div class="imgSrc">\',\n                    //\'                <img class="Gd-pic main-img" src="http://media.etmall.com.tw/ProductImage/6011539/6011539_LM.jpg" style="opacity: 1;">\',\n                    \'                <img class="Gd-pic main-img" src="\'+ getPdImg(\'6011539\', \'LM\') +\'" style="opacity: 1;">\',\n                    //\'                <img class="Gd-pic next-img" onerror="this.src=\\\'http://media.etmall.com.tw/ProductImage/6011539/6011539_LM.jpg\\\';" src="http://media.etmall.com.tw/ProductImage/6011539/6011539-2_LM.jpg">\',\n                    \'                <img class="Gd-pic next-img" onerror="this.src=\\\'\'+ getPdImg(\'6011539\', \'LM\') +\'\\\';" src="\'+ getPdImg(\'6011539\', \'LM\', \'-2\') +\'">\',\n                    \'            </div>\',\n                    \'            <div class="sms" style="bottom: -80px;">\',\n                    \'                <div class="animation-hidden">\',\n                    \'                    <div class="black-overlay"></div>\',\n                    \'                        <ul class="clearfix">\',\n                    \'                            <li>\'+ aPL_SMS1[0] +\'</li>\',\n                    \'                            <li>\'+ aPL_SMS2[0] +\'</li>\',\n                    \'                            <li>\'+ aPL_SMS3[0] +\'</li>\',\n                    \'                        </ul>\',\n                    \'                </div>\',\n                    \'                <span class="Gd-name" style="display:none;">\'+ goodsNameTag +\'</span>\',\n                    \'            </div>\',\n                    \'        </a>\',\n                    \'    </div>\',\n                    \'    <div class="GOOD-InfoBox">\',\n                    \'        <div class="GOOD-NM">\',\n                    //\'            <a href="ProductDetail.aspx?ProductSKU=6011539">\'+ changecar(\'MeFOTO 美孚 MK10 自拍腳架 自拍器 自拍棒 附藍芽 遙控器 藍\\/紅 (公司貨)\') +\'</a>\',\n                    \'            <a href="ProductDetail.aspx?ProductSKU=6011539&kw=\'+ squery_SearchKeyword +\'&pi=\'+ aPL_PageIndex +\'" class="GAEventTracking PHType-AD" GA_EventType="search" GA_EventName="resulePRod_Name" GA_EventPicTxt="text">\'+ goodsNameTag +\'</a>\',\n                    \'        </div>\',\n                    \'        <div class="GOOD-SMS">\',\n                    \'            <ul class="clearfix">\',\n                    \'                <li>\'+ aPL_SMS1[0] +\'</li>\',\n                    \'                <li>\'+ aPL_SMS2[0] +\'</li>\',\n                    \'                <li>\'+ aPL_SMS3[0] +\'</li>\',\n                    \'            </ul>\',\n                    \'        </div>\',\n                    \'    </div>\',\n                    \'    <div class="GOOD-BuyBox">\',\n                    //\'         <div class="GOOD-PRC" GOODPRC=""990"><span class="GOOD-PRCText">\'+Sys_showSearchPRCText(\'\')+\'</span> $<b>\'+Sys_showSearchPRCValue(\'\',\'990\') +\'</b><div style="text-align:right;"></div></div>\',\n\n\n                    \'         <div class="GOOD-PRC" GOODPRC=\' + "990" + \'>\',\n                    \'            \' + buildGooDPrC(\'6011539\', \'\', \'N\', \'990\'),\n\n\n                    \'        <div class="GOOD-Btns">\',\n                    \'            \' + buildBuyNowLink(\'6011539\', \'N\', \'N\', \'Y\', \'10\', \'990\'),\n                    /* 加入購物車資料先不進ETU，因為商品資料沒有StoreID&CategoryID */\n                    //\'            <a href="javascript:;" onclick="sys_AddToShoppingCar(\\\'6011539\\\')" class="btn_Gd_compare">加入購物車</a>\',\n                    \'            \' + buildAddtoCartLink(\'6011539\', \'N\', \'N\', \'Y\', \'10\', \'990\'),\n                    \'        </div>\',\n                    \'    </div>\',\n                    \'</div>\'\n                    ].join(\'\');\n                    /*\n                    aPL_GOODID[0] = \'6011539\';\n                    aPL_GOODNM[0] = changecar(\'MeFOTO 美孚 MK10 自拍腳架 自拍器 自拍棒 附藍芽 遙控器 藍\\/紅 (公司貨)\');\n                    aPL_PRC[0] = \'990\';\n                    aPL_DISCOUNT_VALUE[0] = \'\';\n                    aPL_BUNDLECD[0] = \'10\';\n                    aPL_MAPTYPE[0] = \'\';\n                    aPL_STOREID[0] = \'\';\n                    aPL_CATEGORYID[0] = \'\';\n                    aPL_SMS[0] = changecar(\'收合19.5CM/展開85CM/重量250g##適手機/相機及GOPRO 使用##相容IOS5.0與Android4.2以上照相功能\');\n                    aPL_SMS1[0] = aPL_SMS[0].split(\'##\')[0];\n                    aPL_SMS2[0] = aPL_SMS[0].split(\'##\')[1];\n                    aPL_SMS3[0] = aPL_SMS[0].split(\'##\')[2];\n                    aPL_ONLINE[0] = \'Y\';\n                    aPL_OneDayShip[0] = \'false\';\n                    aPL_StoreService[0] = \'false\';\n                    aPL_AdultProduct[0] = \'0\';\n                    aPL_Hiwey[0] = \'0\';\n                    aPL_isKit[0] = \'N\';\n                    aPL_isPontaVoucher[0] = \'N\';\n                    GOODCOUNT = GOODCOUNT + 1;\n                    */\n\n                    if (Vizury_COUNT < 5)\n                    {\n                    \tVizury_GOODID += \'6011539\' + \',\';\n                    }\n                    else if (Vizury_COUNT == 5)\n                    {\n                    \tVizury_GOODID = Vizury_GOODID + \'6011539\';\n                    }\n                    Vizury_COUNT++\n\n\n                    var goodsNameTag = \'\';\n                    var goodsNameTmp = changecar(\'MEFOTO美孚 藍牙自拍迷你腳架組MK10 (勝興公司貨)\');\n                    var pointType = \'\';\n                    var pointNum1 = \'\';\n                    var pointNum2 = \'\';\n                    var pointPlusMoney = \'\';\n                    //compareWord = compareWord.replace(/\\//g,\'\\\\\\/\');\n                    goodsNameTag = goodsNameTmp;\n                    //fish 20150721 ETMall 搜尋結果頁無法呈現商品列表資訊 DF-6118 \n                    goodsNameTmp = goodsNameTmp.replace(/\\／/g, \'\\/\')\n                    \n                    if(goCompare)\n                    {\n                        eval("var compareStatement = /(.*)(" + compareWord + ")(.*)/i");\n                        if (compareResult = goodsNameTmp.match(compareStatement))\n                        {\n                            goodsNameTag = compareResult[1] + "<span class=\'marked\'>" + compareResult[2] + "</span>" + compareResult[3];\n                        }\n                    }\n                    \n                    \n                    /*\n                    if (compareResult = goodsNameTmp.match(compareStatement))\n                    {\n                        goodsNameTag = compareResult[1] + "<span class=\'marked\'>" + compareResult[2] + "</span>" + compareResult[3];\n                    }\n                    else\n                    {\n                        goodsNameTag = goodsNameTmp;\n                    }\n                    */\n                    goodsNameTag = DoubleToSingle(goodsNameTag);\n                    aPL_GOODID[1] = \'6179229\';\n                    aPL_SMS[1] = changecar(\'手機免安裝APP/藍牙連線即可使用##內附GoPro轉接座與手機轉接座##使用通用型螺絲4分之1牙口\');\n                    aPL_SMS1[1] = aPL_SMS[1].split(\'##\')[0];\n                    aPL_SMS2[1] = aPL_SMS[1].split(\'##\')[1];\n                    aPL_SMS3[1] = aPL_SMS[1].split(\'##\')[2];\n                    if(aPL_SMS[1].split(\'##\').length==2)\n                    {\n                        aPL_SMS3[1] = \'\';\n                    }\n                    else if(aPL_SMS[1].split(\'##\').length==1)\n                    {\n                        aPL_SMS2[1] = \'\';\n                        aPL_SMS3[1] = \'\';\n                    }\n                    srHTML[srHTML.length] = [\n                    \'<div class="SingleProductItem \'+ ListViewMode +\' clearfix  GOODIDStr6179229">\',\n                    \'    <div class="GOOD-img">\',\n                    \'        <a class="GAEventTracking PHType-AD" href="ProductDetail.aspx?ProductSKU=6179229&kw=\'+ squery_SearchKeyword +\'&pi=\'+ aPL_PageIndex +\'" GA_EventType="search" GA_EventName="resulePRod_Img" GA_EventPicTxt="pro">\',\n                    \'            <div class="imgSrc">\',\n                    //\'                <img class="Gd-pic main-img" src="http://media.etmall.com.tw/ProductImage/6179229/6179229_LM.jpg" style="opacity: 1;">\',\n                    \'                <img class="Gd-pic main-img" src="\'+ getPdImg(\'6179229\', \'LM\') +\'" style="opacity: 1;">\',\n                    //\'                <img class="Gd-pic next-img" onerror="this.src=\\\'http://media.etmall.com.tw/ProductImage/6179229/6179229_LM.jpg\\\';" src="http://media.etmall.com.tw/ProductImage/6179229/6179229-2_LM.jpg">\',\n                    \'                <img class="Gd-pic next-img" onerror="this.src=\\\'\'+ getPdImg(\'6179229\', \'LM\') +\'\\\';" src="\'+ getPdImg(\'6179229\', \'LM\', \'-2\') +\'">\',\n                    \'            </div>\',\n                    \'            <div class="sms" style="bottom: -80px;">\',\n                    \'                <div class="animation-hidden">\',\n                    \'                    <div class="black-overlay"></div>\',\n                    \'                        <ul class="clearfix">\',\n                    \'                            <li>\'+ aPL_SMS1[1] +\'</li>\',\n                    \'                            <li>\'+ aPL_SMS2[1] +\'</li>\',\n                    \'                            <li>\'+ aPL_SMS3[1] +\'</li>\',\n                    \'                        </ul>\',\n                    \'                </div>\',\n                    \'                <span class="Gd-name" style="display:none;">\'+ goodsNameTag +\'</span>\',\n                    \'            </div>\',\n                    \'        </a>\',\n                    \'    </div>\',\n                    \'    <div class="GOOD-InfoBox">\',\n                    \'        <div class="GOOD-NM">\',\n                    //\'            <a href="ProductDetail.aspx?ProductSKU=6179229">\'+ changecar(\'MEFOTO美孚 藍牙自拍迷你腳架組MK10 (勝興公司貨)\') +\'</a>\',\n                    \'            <a href="ProductDetail.aspx?ProductSKU=6179229&kw=\'+ squery_SearchKeyword +\'&pi=\'+ aPL_PageIndex +\'" class="GAEventTracking PHType-AD" GA_EventType="search" GA_EventName="resulePRod_Name" GA_EventPicTxt="text">\'+ goodsNameTag +\'</a>\',\n                    \'        </div>\',\n                    \'        <div class="GOOD-SMS">\',\n                    \'            <ul class="clearfix">\',\n                    \'                <li>\'+ aPL_SMS1[1] +\'</li>\',\n                    \'                <li>\'+ aPL_SMS2[1] +\'</li>\',\n                    \'                <li>\'+ aPL_SMS3[1] +\'</li>\',\n                    \'            </ul>\',\n                    \'        </div>\',\n                    \'    </div>\',\n                    \'    <div class="GOOD-BuyBox">\',\n                    //\'         <div class="GOOD-PRC" GOODPRC=""990"><span class="GOOD-PRCText">\'+Sys_showSearchPRCText(\'750\')+\'</span> $<b>\'+Sys_showSearchPRCValue(\'750\',\'990\') +\'</b><div style="text-align:right;"></div></div>\',\n\n\n                    \'         <div class="GOOD-PRC" GOODPRC=\' + "990" + \'>\',\n                    \'            \' + buildGooDPrC(\'6179229\', \'750\', \'N\', \'990\'),\n\n\n                    \'        <div class="GOOD-Btns">\',\n                    \'            \' + buildBuyNowLink(\'6179229\', \'N\', \'N\', \'N\', \'10\', \'990\'),\n                    /* 加入購物車資料先不進ETU，因為商品資料沒有StoreID&CategoryID */\n                    //\'            <a href="javascript:;" onclick="sys_AddToShoppingCar(\\\'6179229\\\')" class="btn_Gd_compare">加入購物車</a>\',\n                    \'            \' + buildAddtoCartLink(\'6179229\', \'N\', \'N\', \'N\', \'10\', \'990\'),\n                    \'        </div>\',\n                    \'    </div>\',\n                    \'</div>\'\n                    ].join(\'\');\n                    /*\n                    aPL_GOODID[1] = \'6179229\';\n                    aPL_GOODNM[1] = changecar(\'MEFOTO美孚 藍牙自拍迷你腳架組MK10 (勝興公司貨)\');\n                    aPL_PRC[1] = \'990\';\n                    aPL_DISCOUNT_VALUE[1] = \'750\';\n                    aPL_BUNDLECD[1] = \'10\';\n                    aPL_MAPTYPE[1] = \'\';\n                    aPL_STOREID[1] = \'\';\n                    aPL_CATEGORYID[1] = \'\';\n                    aPL_SMS[1] = changecar(\'手機免安裝APP/藍牙連線即可使用##內附GoPro轉接座與手機轉接座##使用通用型螺絲4分之1牙口\');\n                    aPL_SMS1[1] = aPL_SMS[1].split(\'##\')[0];\n                    aPL_SMS2[1] = aPL_SMS[1].split(\'##\')[1];\n                    aPL_SMS3[1] = aPL_SMS[1].split(\'##\')[2];\n                    aPL_ONLINE[1] = \'N\';\n                    aPL_OneDayShip[1] = \'false\';\n                    aPL_StoreService[1] = \'false\';\n                    aPL_AdultProduct[1] = \'0\';\n                    aPL_Hiwey[1] = \'0\';\n                    aPL_isKit[1] = \'N\';\n                    aPL_isPontaVoucher[1] = \'N\';\n                    GOODCOUNT = GOODCOUNT + 1;\n                    */\n\n                    if (Vizury_COUNT < 5)\n                    {\n                    \tVizury_GOODID += \'6179229\' + \',\';\n                    }\n                    else if (Vizury_COUNT == 5)\n                    {\n                    \tVizury_GOODID = Vizury_GOODID + \'6179229\';\n                    }\n                    Vizury_COUNT++\n\n\n                    \n                        document.write( srHTML.join(\'\') );\n                </script>\n<!--div class="SingleProductItem width187-vertical clearfix">\n                    <div class="GOOD-img">\n                        <a href="ProductDetail.aspx?StoreID=2&amp;CategoryID=28012&amp;ProductSKU=1362638" ga_eventpictxt="pic" ga_eventname="SProductLists" ga_eventtype="S2_28012" class="GAEventTracking PHType-AD">\n                            <div class="imgSrc">\n                                <img class="main-img" src="http://media.etmall.com.tw/ProductImage/1362638/1362638_XL.jpg" style="opacity: 1;">\n                                <img onerror="this.src=\'http://media.etmall.com.tw/ProductImage/1362638/1362638_XL.jpg\';" class="next-img" src="http://media.etmall.com.tw/ProductImage/1362638/1362638_XL.jpg">\n                            </div>\n                            <div class="sms" style="bottom: -80px;">\n                                <div class="animation-hidden">\n                                    <div class="black-overlay"></div>\n                                        <ul class="clearfix">\n                                            <li>罩衫毛衣給人一種清新的感覺，</li>\n                                            <li>長長的拼色格子毛衣十分保暖，</li>\n                                            <li>整個給人一種大氣而又清爽的感覺整個給人一</li>\n                                        </ul>\n                                </div>\n                            </div>\n                        </a>\n                    </div>\n                    <div class="GOOD-InfoBox">\n                        <div class="GOOD-NM">\n                            <a href="ProductDetail.aspx?StoreID=2&amp;CategoryID=28012&amp;ProductSKU=862696" ga_eventpictxt="text" ga_eventname="SProductLists" ga_eventtype="S2_28012" class="GAEventTracking PHType-AD">《KIWI》美式幸運23刷毛外套..</a>\n                        </div>\n                        <div class="GOOD-SMS">\n                            <ul class="clearfix">\n                                <li>面料柔軟舒適 連帽設計</li>\n                                <li>表現一點俏皮可愛</li>\n                                <li>休閒必備!早春最優惠~</li>\n                            </ul>\n                        </div>\n                    </div>\n                    <div class="GOOD-BuyBox">\n                        <div class="GOOD-PRC">$<b>599</b><div style="text-align:right;"></div></div>\n                        <div class="GOOD-Btns">\n                            <a href="javascript:;" onclick="GoColorStyle(862696)" class="btn_Gd_BuyNow">立即結帳</a>\n                            <a href="javascript:;" onclick="sys_goCompareList(\'862696\')" class="btn_Gd_compare">比較清單</a>\n                        </div>\n                    </div>\n                </div-->\n</div>\n<div id="EHSN-asr">\n<div class="listpaging-wrap"><!-- 分頁 -->\n<div class="listpaging">\n<script>\n                            var NowPageIndexNum = 0;\n                            var NowPageSizeNum = 40;\n                            var ProductTotalNum = 2;\n                            var ProductStartNum = (NowPageIndexNum*NowPageSizeNum)+1;\n                            var ProductEndNum = (NowPageIndexNum+1)*NowPageSizeNum;\n                            \n                            if(ProductEndNum > ProductTotalNum)\n                            {\n                                ProductEndNum = ProductTotalNum;\n                            }\n                         </script>\n<div class="totalConutDiv">第<b><script>document.write(ProductStartNum)</script></b>件 ～ 第<b><script>document.write(ProductEndNum)</script></b>件（共<b>2</b>件商品）|\u3000</div><div class="paging" id="EHSN-pageNaviTop"></div>\n</div>\n</div>\n</div>\n<!--進階結果:區塊:宇匯推薦商品-->\n<div class="scupioRecommand clearfix">\n<h2>根據您的搜尋，您或許對這些商品也有興趣</h2>\n<div class="scupio-show-five clearfix">\n<div class="right">\n<div class="scupioPromoPro">\n<ul class="jcarousel-skin-HomeBridge" id="bridgewellCarouselList"></ul>\n</div>\n</div>\n</div>\n</div>\n<!--  Product page tag ---->\n<script async="true" src="//static.criteo.net/js/ld/ld.js" type="text/javascript"></script>\n<script type="text/javascript">\n            window.criteo_q = window.criteo_q || [];\n            window.criteo_q.push(  \n                    { event: "setAccount", account: 27373 },\n                    { event: "setSiteType", type: "d" },\n                    { event: "viewList", item: aPL_GOODID }\n            );\n            </script>\n<!--宇匯大中小分類推薦商品-->\n<script type="text/javascript">\n                var getMsize = function(imgURL)\n                {\n                    var MSize = \'\'\n                \n                    if(imgURL.indexOf(\'NXimg\') == -1)\n                    {\n                        var getGOOD_ID = imgURL.split(\'ProductImage/\')[1].split(\'/\')[0];\n                        //var MSize = checkHTTPSSL() +\'media.etmall.com.tw/ProductImage/\'+ getGOOD_ID +\'/\'+ getGOOD_ID +\'_ML.jpg\';\n                        MSize = getPdImg(getGOOD_ID, \'ML\');\n                    }\n                    else\n                    {\n                        MSize = imgURL;\n                    }\n                    return MSize;\n                };\n                \n                (function()\n                    {\n                        var showLayout = \'jsarray\';\n                        \n                        var e={\n                                "mid"   : "64",\n                                "pid"   : "search",\n                                "kw"    : setSearchKeywordvalue,\n                                "pi"    : aPL_PageIndex,\n                                "sitem" : aPL_GOODID.join(\',\'),\n                                "uid"   : ga_CUST_ACCT_ID,\n                                "layout": \'jsarray\',  // 表示傳回的資料不是 html 版型, 而是推薦商品資料.\n                                "count":"20",  //表示總共需要傳回十九筆推薦資料\n                                "success" : function(s) {\n                                                eval("var products="+s); // 回傳一個二維陣列, 第一個有四個推薦商品, 第二個有十五個推薦商品\n                                                var result = new Array();\n                                                var result1 = new Array();\n                                                \n                                                \n                                                if (products.length == 0)\n                                                {\n                                                    return;\n                                                }\n                                                \n                                                //result.push(\'<ul>\');\n                                                for (var i = 0 ; i < products[0].length ; i ++)\n                                                {\n                                                    var item = products[0][i];\n                                                    result.push(\'<li>\');\n                                                    result.push(\'    <a class="GAEventTracking PHType-AD" GA_EventType="search" GA_EventName="ScupioPromoProduct" GA_EventPicTxt="pro" href="\'+ item.clickurl +\'">\');\n                                                    result.push(\'       <img src="\'+ getMsize(item.imgurl) +\'" class="Gd-pic">\');\n                                                    result.push(\'       <span class="Gd-name">\'+ item.title +\'</span>\');\n                                                    result.push(\'       <span class="Gd-prc">$<span>\'+ Sys_FormatNumber(item.price.toString()) +\'</span></span>\');\n                                                    result.push(\'    </a>\');\n                                                    result.push(\'</li>\');\n                                                }\n                                                //result.push(\'</ul>\');\n                                                \n\n                                                jQuery("#bridgewellCarouselList").html(result.join(""));\n                                                jQuery(\'#bridgewellCarouselList\').jcarousel({\n                                                    size: products[0].length,\n                                                    scroll:5,\n                                                    auto: 6000,\n                                                    wrap: \'circular\'\n                                                });\n                                                \n                                                /* scrollLoading圖片動態加載 */\n                                                /*\n                                                jQuery(\'img.lazy\').lazyload({ \n                                                    effect: showeffect,\n                                                    threshold : 50,\n                                                    failure_limit : 10\n                                                })\n                                                */\n                                            }\n                        };\n                        var f=\'undefined\';var g="http://";var h="https://";var i="//";var j=g;if(document.location.href.indexOf(g)!=-1){j=i}else if(document.location.href.indexOf(h)!=-1){j=i}function l(v){if(v=="")return false;return(eval("typeof "+v)!=f)}function m(a){var s=document.createElement(\'script\');s.setAttribute(\'type\',\'text/javascript\');s.setAttribute(\'src\',a);return s}function n(a){var b=document.getElementsByTagName(\'head\')[0];if(b)b.appendChild(m(a));else document.body.appendChild(m(a))}function o(a,b){var c=setInterval(function(){if(l(a)){clearInterval(c);b()}},50)}function p(a,b,c,d){if(l(b)==false){n(a);o(b,function(){if(c)c();if(d)d()})}else{if(d)d()}}var k=j+"www.etmall.com.tw/E68Includes_Src/rec_ehs.js";p(k,"scupioec",null,function(){self.scupioec.call(e)})\n                    }\n                )();\n            </script>\n<!--宇匯大中小分類推薦商品-->\n</div>\n</div>\n<script>\n    var ua = window.navigator.userAgent;\n    var msie = ua.indexOf("MSIE ");//IE10\n    var trident = ua.indexOf(\'Trident/\');//IE11 IE edge\n    var edge = ua.indexOf(\'Edge/\');//IE12\n    \n    jQuery(document).ready(function()\n    {\n        //page load 時就要綁上mouse over顯示SMS\n        jQuery(\'.SingleProductItem .GOOD-img\').hover(function(e){\n        \n            if (e.stopPropagation) { e.stopPropagation(); }\n            e.preventDefault();\n            \n            jQuery(this).find(\'.sms\').stop().animate({\n                bottom: \'0px\'\n            }, 300);\n            \n            jQuery(this).find(\'.main-img\').stop().animate({\n                opacity: \'0\'\n            }, 500);\n\n        }, function(e){\n        \n            if (e.stopPropagation) { e.stopPropagation(); }\n            e.preventDefault();\n            \n            jQuery(this).find(\'.sms\').stop().animate({\n                bottom: \'-80px\'\n            }, 500);\n            \n            jQuery(this).find(\'.main-img\').stop().animate({\n                opacity: \'1\'\n            }, 500);\n            \n        });\n        \n        //page load 時就要判斷"顯示圖片"、"顯示圖文並列" 要加上class="on"\n        if(nowModeLIst == \'PHOTOMODE\')\n        {\n            jQuery(\'#toolbar .view a\').removeClass(\'on\');\n            jQuery(\'#toolbar .gallery a\').addClass(\'on\');\n        }\n        else\n        {\n            jQuery(\'#toolbar .view a\').removeClass(\'on\');\n            jQuery(\'#toolbar .list a\').addClass(\'on\');\n        }\n        \n        //page load 時就要綁上"最精準"、"最便宜"、"最新"、"最熱門"、"最熱銷" onclick 事件 || 2014.04.22 修正\n        jQuery(\'#PrcSort\').hover(function(e){\n   \n            jQuery(\'#PrcSort ol\').css(\'display\', \'block\');\n\n        }, function(e){\n        \n            jQuery(\'#PrcSort ol\').css(\'display\', \'\');\n            \n        });\n        \n        jQuery(\'#toolbar .sortBy a\').live(\'click\', function (e) \n        {\n            if (e.stopPropagation) { e.stopPropagation(); }\n            e.preventDefault();\n            \n            var QueryParmOrderBy_attr = jQuery(this).attr(\'QueryParmOrderBy\');\n            if (QueryParmOrderBy_attr != \'\')\n            {\n                document.realForm.SearchKeyword.value = setSearchKeywordvalue;\n                document.realForm.QueryCmd.value = squery_QueryCmdHistory;\n                document.realForm.OrderBy.value = QueryParmOrderBy_attr;\n                //document.realForm.action = \'AllSearchFormResult.aspx?SearchKeyword=\' + setSearchKeywordvalue + \'&OrderBy=\' + QueryParmOrderBy_attr;\n                \n                \n                if ( msie > 0 ){\n                    // If Internet Explorer, return version number\n                    document.realForm.action = \'AllSearchFormResult.aspx?SearchKeyword=\' + encodeURIComponent(setSearchKeywordvalue) + \'&SearchKey=\'+ encodeURIComponent(setSearchKeywordvalue) +\'&CategoryID=\'+ document.realForm.CategoryID.value +\'&ProductPage=0&RecordsPerPage=20&OrderBy=\'+ QueryParmOrderBy_attr;\n                }\n                else\n                {\n                    // If another browser, return 0\n                    document.realForm.action = \'AllSearchFormResult.aspx?SearchKeyword=\' + setSearchKeywordvalue + \'&SearchKey=\'+ setSearchKeywordvalue +\'&CategoryID=\'+ document.realForm.CategoryID.value +\'&ProductPage=0&RecordsPerPage=20&OrderBy=\'+ QueryParmOrderBy_attr;\n                }\n                \n                document.realForm.submit();\n            }\n        });\n        \n        //page load 時就要綁上"分類選擇" onclick 事件 || 2014.04.22 修正\n        jQuery(\'.hasCategoryID\').live(\'click\', function (e) {\n            if (e.stopPropagation) { e.stopPropagation(); }\n            e.preventDefault();\n            \n            var LevelNum = parseInt(jQuery(this).attr(\'level\'));\n            var groupCategoryID_array = new Array();\n            var groupCategoryName_array = new Array();\n            \n            if( LevelNum > squery_hiotoryTree_spilt.length)\n            {\n                groupCategoryID_array[groupCategoryID_array.length] = squery_hiotoryTree;\n                groupCategoryID_array[groupCategoryID_array.length] = jQuery(this).attr(\'CategoryID\');\n                \n                groupCategoryName_array[groupCategoryName_array.length] = squery_hiotoryTreeName;\n                groupCategoryName_array[groupCategoryName_array.length] = jQuery(this).text();\n            }\n            else\n            {\n                for(var i=0, j=(LevelNum-1); i<=j; i++)\n                {\n                    groupCategoryID_array[groupCategoryID_array.length] = squery_hiotoryTree_spilt[i];\n                    groupCategoryName_array[groupCategoryName_array.length] = squery_hiotoryTreeName_spilt[i];\n                }\n            }\n            \n\n            //alert(\'groupCategoryID_array = \' + groupCategoryID_array)\n            //alert(\'groupCategoryName_array = \' + groupCategoryName_array)\n\n            \n            //document.realForm.ProductSource.value = \'\';\n            document.realForm.CategoryID.value = jQuery(this).attr(\'CategoryID\');\n            document.realForm.CategoryName.value = jQuery(this).text();\n            //document.realForm.hiotoryTree.value = squery_hiotoryTree + \',\' + jQuery(this).attr(\'CategoryID\');\n            //document.realForm.hiotoryTreeName.value = squery_hiotoryTreeName + \',\' + jQuery(this).text();\n            //document.realForm.hiotoryTreeName.value = squery_hiotoryTreeName + \',\' + oTarget.innerHTML;\n            \n            document.realForm.hiotoryTree.value = groupCategoryID_array.join(\',\');\n            document.realForm.hiotoryTreeName.value = groupCategoryName_array.join(\',\');\n            \n            //alert(\'click \' + document.realForm.hiotoryTreeName.value)\n            //document.realForm.SearchKeyword.value = oTarget.getAttribute(\'hkw\');\n            document.realForm.SearchKeyword.value = setSearchKeywordvalue;\n            //document.realForm.OnlineDateStart.value = \'\';\n            //document.realForm.OnlineDateEnd.value = \'\';\n            //document.realForm.ProductMoneyStart.value = \'\';\n            //document.realForm.ProductMoneyEnd.value = \'\';\n            //document.realForm.Video.value = \'\';\n            //document.realForm.OrderBy.value = \'\';\n            //document.realForm.QueryCmd.value = \'\';\n            document.realForm.QueryCmd.value = squery_QueryCmdHistory;\n            //document.realForm.QueryCmdName.value = \'\';\n            document.realForm.PageIndex.value = \'0\';\n            document.realForm.PageSize.value = \'20\';\n            //document.realForm.CombinedCode.value = \'\';\n            \n            \n            if ( msie > 0 ){\n                // If Internet Explorer, return version number\n                document.realForm.action = \'AllSearchFormResult.aspx?SearchKeyword=\' + encodeURIComponent(setSearchKeywordvalue) + \'&SearchKey=\'+ encodeURIComponent(setSearchKeywordvalue) +\'&CategoryID=\'+ jQuery(this).attr(\'CategoryID\') +\'&ProductPage=0&RecordsPerPage=20&OrderBy=\'+ document.realForm.OrderBy.value;\n            }\n            else\n            {\n                // If another browser, return 0\n                document.realForm.action = \'AllSearchFormResult.aspx?SearchKeyword=\' + setSearchKeywordvalue + \'&SearchKey=\'+ setSearchKeywordvalue +\'&CategoryID=\'+ jQuery(this).attr(\'CategoryID\') +\'&ProductPage=0&RecordsPerPage=20&OrderBy=\'+ document.realForm.OrderBy.value;\n            }\n            \n            document.realForm.submit();\n        });\n        \n        //page load 時就要綁上"在結果中搜尋" 限縮搜尋 || 2014.04.22 修正\n        jQuery(\'.searchBtn\').live(\'click\', function (e) {\n            if (e.stopPropagation) { e.stopPropagation(); }\n            e.preventDefault();\n            \n            var goSubmit = true;\n            \n            var addType_Array            = new Array();\n            addType_Array[addType_Array.length] = \'type\';\n            \n            /*\n            var addType_OnSale                  = \'{"DisplayName":"DISCOUNT_VALUE","QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}}\';\n            var addType_24H                     = \'{"DisplayName":"OneDayShip","QC1":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"OneDayShip"}}\';\n            var addType_Store                   = \'{"DisplayName":"StoreService","QC1":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"StoreService"}}\';\n            var addType_Coupon                  = \'{"DisplayName":"COUPON","QC1":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"COUPON"}}\';\n                    \n            var addType_24H_Store               = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"StoreService"}}}\';\n            var addType_24H_Coupon              = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"COUPON"}}}\';\n            var addType_Store_Coupon            = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"StoreService"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"COUPON"}}}\';         \n            var addType_24H_OnSale              = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}}}\';\n            var addType_Coupon_OnSale           = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}}}\';\n            var addType_Store_OnSale            = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"StoreService"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}}}\';\n                \n            var addType_24H_Store_Coupon        = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"StoreService"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"COUPON"}}}\';\n            var addType_24H_Store_OnSale        = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"StoreService"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"Operand2":"","MetaField":"DISCOUNT_VALUE"}}}\';\n            var addType_24H_OnSale_Coupon       = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"COUPON"}}}\';\n            var addType_OnSale_Store_Coupon     = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"StoreService"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"COUPON"}}}\';\n            \n            var addType_24H_Store_Coupon_OnSale = \'{"QCompC1":{"QC1":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"OneDayShip"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"StoreService"},"QCOP":1,"QC2":{"QT":2,"Operand1":"1","BOP":2,"Operand2":"","MetaField":"COUPON"},"QCOP":1,"QC2":{"QT":2,"Operand1":"0","BOP":3,"MetaField":"DISCOUNT_VALUE"}}}\';\n            */\n            \n            \n            //"在結果中搜尋" 欄位的判別\n            if( jQuery(\'.condense\').val() != \'\' && jQuery(\'.condense\').val() != \'在結果中搜尋\')\n            {\n                if( jQuery(\'.condense\').val().trim() == \'\')\n                {\n                    alert(\'查無相關資料請重新搜尋\');\n                    return false;\n                }\n                \n                if(document.realForm.AdvancedKeyword.value != \'\')\n                {\n                    //document.realForm.AdvancedKeyword.value = document.realForm.AdvancedKeyword.value + \'╪\' + jQuery(\'.condense\').val();\n                    document.realForm.AdvancedKeyword.value = jQuery(\'.condense\').val();\n                }\n                else\n                {\n                    document.realForm.AdvancedKeyword.value = jQuery(\'.condense\').val();\n                }\n                \n                goSubmit = true;\n            }\n            //alert(\'goSubmit-1 = \' + goSubmit);\n            \n            //依"價格"的判別 - 自填價格區間判斷\n            if (jQuery(\'.lowPRC\').val() != "" && jQuery(\'.lowPRC\').val() != \'最低\')\n            {\n                if (isNaN(jQuery(\'.lowPRC\').val()))\n                {\n                    alert("很抱歉!您輸入的價格有誤,請重新輸入");\n                    jQuery(\'.lowPRC\').val(\'\');\n                    jQuery(\'.lowPRC\').val(\'\').focus();\n                    return false;\n                }\n                else\n                {\n                    document.realForm.ProductMoneyStart.value = jQuery(\'.lowPRC\').val();\n                }\n            }\n            else\n            {\n                document.realForm.ProductMoneyEnd.value = \'\';\n            }\n            \n            if (jQuery(\'.highPRC\').val() != "" && jQuery(\'.highPRC\').val() != \'最高\')\n            {\n                if (isNaN(jQuery(\'.highPRC\').val()))\n                {\n                    alert("很抱歉!您輸入的價格有誤,請重新輸入");\n                    jQuery(\'.highPRC\').val(\'\');\n                    jQuery(\'.highPRC\').val(\'\').focus();\n                    return false;\n                }\n                else\n                {\n                    document.realForm.ProductMoneyEnd.value = jQuery(\'.highPRC\').val();\n                }\n            }\n            else\n            {\n                document.realForm.ProductMoneyEnd.value = \'\';\n            }\n            /*\n            if (jQuery(\'.lowPRC\').val() != "" && jQuery(\'.lowPRC\').val() != \'最低\')\n            {\n                if (jQuery(\'.highPRC\').val() == "" || jQuery(\'.highPRC\').val() == \'最高\')\n                {\n                    alert("很抱歉!您尚未填妥價格區間");\n                    jQuery(\'.highPRC\').val(\'\');\n                    jQuery(\'.highPRC\').val(\'\').focus();\n                    return false;\n                }\n            }\n            if (jQuery(\'.highPRC\').val() != "" && jQuery(\'.highPRC\').val() != \'最高\')\n            {\n                if (jQuery(\'.lowPRC\').val() == "" || jQuery(\'.lowPRC\').val() == \'最低\')\n                {\n                    alert("很抱歉!您尚未填妥價格區間");\n                    jQuery(\'.lowPRC\').val(\'\');\n                    jQuery(\'.lowPRC\').val(\'\').focus();\n                    return false;\n                }\n            }\n            */\n            /*\n            if (jQuery(\'.lowPRC\').val() != "" && jQuery(\'.lowPRC\').val() != \'最低\' && jQuery(\'.highPRC\').val() != "" && jQuery(\'.highPRC\').val() != \'最高\')\n            {\n                document.realForm.ProductMoneyStart.value = jQuery(\'.lowPRC\').val();\n                document.realForm.ProductMoneyEnd.value = jQuery(\'.highPRC\').val();\n                goSubmit = true;\n            }\n            */\n            //alert(\'goSubmit-2 = \' + goSubmit);\n            \n            //依"價格"的判別 - 固定價格Radio選擇\n            /*\n            if(  jQuery(\'input[type=radio][name="pricerange"]\').is(\':checked\')  )\n            {\n                queryLowPRC = jQuery(\'input:radio:checked[name="pricerange"]\').attr(\'lowPRC\');\n                queryHighPRC = jQuery(\'input:radio:checked[name="pricerange"]\').attr(\'highPRC\');\n                \n                alert(\'queryLowPRC = \' + queryLowPRC);\n                alert(\'queryHighPRC = \' + queryHighPRC);\n                \n                document.realForm.ProductMoneyStart.value = queryLowPRC;\n                document.realForm.ProductMoneyEnd.value = queryHighPRC;\n                goSubmit = true;\n            }\n            */\n            \n            \n            //其他條件"快速到貨"、"超商取貨"、"可使用折價券" 的判別\n            jQuery(\'.otherFilters:checked\').each(function () {\n                addType_Array[addType_Array.length] = jQuery(this).val();\n            });\n            \n            jQuery("input[name=\'soucreFrom\']").each(function (m) {\n                if( jQuery(this).is(":checked") )\n                {\n                    addType_Array[addType_Array.length] = jQuery(this).val();\n                }\n            });\n            \n            if(addType_Array != \'addType\')\n            {\n                document.realForm.QueryCmd.value = eval( addType_Array.join(\'_\') );\n                goSubmit = true;\n            }\n            else\n            {\n                document.realForm.QueryCmd.value = \'\';\n            }\n            //alert(\'goSubmit-3 = \' + goSubmit);\n            \n            if(goSubmit)\n            {\n                //document.realForm.action = \'AllSearchFormResult.aspx?SearchKeyword=\' + setSearchKeywordvalue;\n                document.realForm.action = \'AllSearchFormResult.aspx?SearchKeyword=\' + encodeURIComponent(setSearchKeywordvalue) + \'&SearchKey=\'+ encodeURIComponent(setSearchKeywordvalue) +\'&CategoryID=\'+ document.realForm.CategoryID.value +\'&ProductPage=0&RecordsPerPage=20&OrderBy=\'+ document.realForm.OrderBy.value;\n                document.realForm.submit();\n            }\n            else\n            {\n                alert("很抱歉!您尚未輸入任何進階搜尋條件");\n                return false;\n            }\n            \n        });\n        \n        //page load 時就要綁上 進階搜尋的價格區間radio 選擇\n        jQuery(\'input[type=radio][name="pricerange"]\').live(\'click\', function (e) {\n            \n            var queryLowPRC;\n            var queryHighPRC;\n            queryLowPRC = jQuery(\'input:radio:checked[name="pricerange"]\').attr(\'lowPRC\');\n            queryHighPRC = jQuery(\'input:radio:checked[name="pricerange"]\').attr(\'highPRC\');\n            \n            \n            jQuery(\'.lowPRC\').val(queryLowPRC);\n            jQuery(\'.highPRC\').val(queryHighPRC);\n        });\n        \n        //page load 時就要綁上底色黑色那條的搜尋關鍵字的 onclick 事件（可以刪除，也可以直接按任何階層的搜尋關鍵字）\n        jQuery(\'.resultInfo .showKeyWordStep\').live(\'click\', function (e) {\n            if (e.stopPropagation) { e.stopPropagation(); }\n            e.preventDefault();\n            \n            var searchKeyWordLinkSize = jQuery(\'.resultInfo .showKeyWordStep\').size();\n            //alert(\'searchKeyWordLinkSize = \' + searchKeyWordLinkSize);\n            //alert( jQuery(this).text() );\n            //alert( jQuery(this).parent().index() );\n            var AdvancedKeywordCount = jQuery(this).parent().index();\n            var showAdvKeyWord_arry = document.realForm.AdvancedKeyword.value.split(\'╪\');\n            showAdvKeyWord_arry.unshift("");\n            var newAdvKeyWord = new Array();\n            \n            if( AdvancedKeywordCount == 1 )\n            {\n                document.realForm.SearchKeyword.value = setSearchKeywordvalue;\n                document.realForm.AdvancedKeyword.value = \'\';\n                \n                if ( msie > 0 ){\n                    // If Internet Explorer, return version number\n                    document.realForm.action = \'AllSearchFormResult.aspx?SearchKeyword=\' + encodeURIComponent(setSearchKeywordvalue) + \'&SearchKey=\'+ encodeURIComponent(setSearchKeywordvalue) +\'&CategoryID=\'+ document.realForm.CategoryID.value +\'&ProductPage=0&RecordsPerPage=20&OrderBy=\'+ document.realForm.OrderBy.value;\n                }\n                else\n                {\n                    // If another browser, return 0\n                    document.realForm.action = \'AllSearchFormResult.aspx?SearchKeyword=\' + setSearchKeywordvalue + \'&SearchKey=\'+ setSearchKeywordvalue +\'&CategoryID=\'+ document.realForm.CategoryID.value +\'&ProductPage=0&RecordsPerPage=20&OrderBy=\'+ document.realForm.OrderBy.value;\n                }\n                document.realForm.submit();\n            }\n            else\n            {\n                if( jQuery(this).parent().index() == searchKeyWordLinkSize )\n                {\n                    jQuery(this).parent().remove();\n                    AdvancedKeywordCount = AdvancedKeywordCount-1;\n                }\n                for(var i=0, j=(AdvancedKeywordCount); i<j; i++)\n                {\n                    newAdvKeyWord[newAdvKeyWord.length] = showAdvKeyWord_arry[i];\n                }\n                document.realForm.SearchKeyword.value = setSearchKeywordvalue;\n                document.realForm.AdvancedKeyword.value = newAdvKeyWord.join(\'╪\').replace(\'╪\', \'\');\n                \n                \n                if ( msie > 0 ){\n                    // If Internet Explorer, return version number\n                    document.realForm.action = \'AllSearchFormResult.aspx?SearchKeyword=\' + encodeURIComponent(setSearchKeywordvalue) + \'&SearchKey=\'+ encodeURIComponent(setSearchKeywordvalue) +\'&CategoryID=\'+ document.realForm.CategoryID.value +\'&ProductPage=0&RecordsPerPage=20&OrderBy=\'+ document.realForm.OrderBy.value;\n                }\n                else\n                {\n                    // If another browser, return 0\n                    document.realForm.action = \'AllSearchFormResult.aspx?SearchKeyword=\' + setSearchKeywordvalue + \'&SearchKey=\'+ setSearchKeywordvalue +\'&CategoryID=\'+ document.realForm.CategoryID.value +\'&ProductPage=0&RecordsPerPage=20&OrderBy=\'+ document.realForm.OrderBy.value;\n                }\n                document.realForm.submit();\n            }\n            \n        });\n                \n        //page load 時就要綁上 "你是不是要找"、"大家正在找"、"你最近找過"、"熱門搜尋排行榜" || 2014.04.22 修正\n        jQuery(\'.singleKWSearch\').live(\'click\', function (e) {\n            if (e.stopPropagation) { e.stopPropagation(); }\n            e.preventDefault();\n            \n            var itemNO = 1;\n            jQuery(\'[class ~= GAEventTracking PHType-AD]\').removeClass(\'GAETClick\');\n            jQuery(this).addClass(\'GAETClick\');\n            \n            jQuery(\'[GA_EventName="\' + jQuery(this).attr(\'GA_EventName\') + \'"]\').each(function (i) {\n                if( jQuery(this).hasClass(\'GAETClick\') )\n                {\n                    itemNO = (i + 1);\n                }\n            });\n            \n            var PicOrText;\n            if(jQuery(this).attr(\'GA_EventPicTxt\') == \'pro\')\n            {\n                PicOrText = (targetTagName == \'img\')? \'pic\' : \'text\';\n            }\n            else\n            {\n                PicOrText = jQuery(this).attr(\'GA_EventPicTxt\');\n            }\n            \n            var eventCategory;\n            if( jQuery(\'[GA_EventName="\' + jQuery(this).attr(\'GA_EventName\') + \'"]\').size() == 1 )\n            {\n                eventCategory = jQuery(this).attr(\'GA_EventType\') + \'_\' + jQuery(this).attr(\'GA_EventName\') + \'_\' + PicOrText;\n            }\n            else\n            {\n                eventCategory = jQuery(this).attr(\'GA_EventType\') + \'_\' + jQuery(this).attr(\'GA_EventName\') + \'_\' + itemNO + \'_\' + PicOrText;\n            }\n            \n            document.realForm.ProductSource.value = \'\';\n            document.realForm.CategoryID.value = \'\';\n            document.realForm.SearchKeyword.value = jQuery(this).text();\n            document.realForm.OnlineDateStart.value = \'\';\n            document.realForm.OnlineDateEnd.value = \'\';\n            document.realForm.ProductMoneyStart.value = \'\';\n            document.realForm.ProductMoneyEnd.value = \'\';\n            document.realForm.Video.value = \'\';\n            document.realForm.OrderBy.value = \'\';\n            document.realForm.QueryCmd.value = \'\';\n            document.realForm.PageIndex.value = \'0\';\n            document.realForm.PageSize.value = \'20\';\n            document.realForm.CombinedCode.value = \'\';\n            document.realForm.CategoryName.value = \'\';\n            document.realForm.QueryCmdName.value = \'\';\n            document.realForm.hiotoryTree.value = \'\';\n            document.realForm.hiotoryTreeName.value = \'\';\n            document.realForm.Color.value = \'\';\n            document.realForm.Style.value = \'\';\n            document.realForm.ColorValue.value = \'\';\n            document.realForm.StyleValue.value = \'\';\n            //alert(document.realForm.SearchKeyword.value);\n            if (  msie > 0 || trident >0 || edge >0 ){\n                document.realForm.action = \'AllSearchFormResult.aspx?SearchKeyword=\' + encodeURIComponent(jQuery(this).text()) + \'&SearchKey=\'+ encodeURIComponent(jQuery(this).text()) +\'&CategoryID=&ProductPage=0&RecordsPerPage=20&OrderBy=&PHRef=\' + eventCategory;\n            }\n            else{           \n                document.realForm.action = \'AllSearchFormResult.aspx?SearchKeyword=\' + jQuery(this).text() + \'&SearchKey=\'+ jQuery(this).text() +\'&CategoryID=&ProductPage=0&RecordsPerPage=20&OrderBy=&PHRef=\' + eventCategory;\n            }\n            document.realForm.submit();\n        });\n        \n        jQuery(\'.btn_Gd_BuyNow\').live(\'click\', function (e) {\n                if (e.stopPropagation) { e.stopPropagation(); }\n                e.preventDefault();\n                \n                if( jQuery(this).attr(\'BUNDLECD\') == \'30\')\n                {\n                    //E68BuyNowPop(jQuery(this).attr(\'GOODID\') + \'╪\' + PHRef, jQuery(this).attr(\'GOODID\'));\n                    location.href = \'ProductDetail.aspx?ProductSKU=\' + jQuery(this).attr(\'GOODID\');\n                }\n                else\n                {\n\t\t\t\t\t//強制帶入search_resuleBuyNow\n                    PHRef = \'search_resuleBuyNow\';\n                    E68BuyNowPop(jQuery(this).attr(\'GOODID\') + \'╪\' + PHRef, jQuery(this).attr(\'GOODID\'));\n                }\n                \n                fbq(\'track\', \'AddToCart\');\n        });\n        \n        \n        \n        //page load 時就要綁上"分類頁碼" onclick 事件 || 2014.04.22 新增\n        jQuery(\'.pagelist a\').live(\'click\', function (e) {\n            if (e.stopPropagation) { e.stopPropagation(); }\n            e.preventDefault();\n            \n            var ProductPage_attr = jQuery(this).attr(\'ProductPage\');\n            var RecordsPerPage_attr = jQuery(this).attr(\'RecordsPerPage\');\n            \n            document.realForm.PageIndex.value = ProductPage_attr;\n            document.realForm.PageSize.value = RecordsPerPage_attr;\n            \n            \n            if ( msie > 0 ){\n                // If Internet Explorer, return version number\n                document.realForm.action = \'AllSearchFormResult.aspx?SearchKeyword=\' + encodeURIComponent(setSearchKeywordvalue) + \'&SearchKey=\'+ encodeURIComponent(setSearchKeywordvalue) +\'&CategoryID=\'+ document.realForm.CategoryID.value +\'&ProductPage=\'+ ProductPage_attr +\'&RecordsPerPage=\'+ RecordsPerPage_attr +\'&OrderBy=\'+ document.realForm.OrderBy.value;\n            }\n            else\n            {\n                // If another browser, return 0\n                document.realForm.action = \'AllSearchFormResult.aspx?SearchKeyword=\' + setSearchKeywordvalue + \'&SearchKey=\'+ setSearchKeywordvalue +\'&CategoryID=\'+ document.realForm.CategoryID.value +\'&ProductPage=\'+ ProductPage_attr +\'&RecordsPerPage=\'+ RecordsPerPage_attr +\'&OrderBy=\'+ document.realForm.OrderBy.value;\n            }\n            document.realForm.submit();\n        });\n        \n    });\n</script>\n<!-- Vizury 追蹤碼 -->\n<script type="text/javascript">\n(function(){ var x = document.createElement(\'script\'); x.async = true;\nx.src = "//asia.creativecdn.com/tags?type=script&id=pr_YoiaNzLySvYFl9SSIeeZ_listing_" + Vizury_GOODID; document.getElementsByTagName(\'head\')[0].appendChild(x); }());\n</script><script>ShowPageControl("EHSN-pageNaviTop", 0, 1,40);</script>\n<!--PlaceHolder：E68_SearchResult：搜尋結果end-->\n<!--20151007 第四季Yahoo原生廣告 CR-14852-->\n<script type="application/javascript">(function(w,d,t,r,u){w[u]=w[u]||[];w[u].push({\'projectId\':\'10001506899115\',\'properties\':{\'pixelId\':\'32132\'}});var s=d.createElement(t);s.src=r;s.async=true;s.onload=s.onreadystatechange=function(){var y,rs=this.readyState,c=w[u];if(rs&&rs!="complete"&&rs!="loaded"){return}try{y=YAHOO.ywa.I13N.fireBeacon;w[u]=[];w[u].push=function(p){y([p])};y(c)}catch(e){}};var scr=d.getElementsByTagName(t)[0],par=scr.parentNode;par.insertBefore(s,scr)})(window,document,"script","https://s.yimg.com/wi/ytc.js","dotq");</script>\n</div>\n</div>\n<!-- (end) content_body -->\n<!--在form_R65TopNavi.xml中使用 因為要提升頁面速度-->\n<!--script src="GetPersonal_CustNM.aspx"></script-->\n<script src="GetLoginInfo.aspx?v=20170207160415"></script>\n</div>\n<script>\r\n                    var overHeight = jQuery(\'#R65-b-newuh\').outerHeight();\r\n        \r\n                    if(!(jQuery.browser.msie && jQuery.browser.version=="6.0"))\r\n                    {\r\n                        jQuery(window).scroll(function () { \r\n                               //You\'ve scrolled this much:\r\n                               //jQuery(\'.textHRER\').html("You\'ve scrolled " + jQuery(window).scrollTop() + " pixels");\r\n                               \r\n                                if(  jQuery(\'.member-navi-links ul a\').hasClass(\'on\')  )\r\n                                {\r\n                                    if( parseInt(jQuery(window).scrollTop()) >= 503 )\r\n                                    {\r\n                                        jQuery(\'.E68_floatBanner\').css(\'position\', \'fixed\');\r\n                                        jQuery(\'.E68_floatBanner\').css(\'top\', \'0px\');\r\n                                    }\r\n                                    else\r\n                                    {\r\n                                        jQuery(\'.E68_floatBanner\').css(\'position\', \'absolute\');\r\n                                        jQuery(\'.E68_floatBanner\').css(\'top\', \'135px\');\r\n                                    }\r\n                                }\r\n                                else\r\n                                {\r\n                                    if( parseInt(jQuery(window).scrollTop()) >= 190 )\r\n                                    {\r\n                                        jQuery(\'.E68_floatBanner\').css(\'position\', \'fixed\');\r\n                                        jQuery(\'.E68_floatBanner\').css(\'top\', \'0px\');\r\n                                    }\r\n                                    else\r\n                                    {\r\n                                        jQuery(\'.E68_floatBanner\').css(\'position\', \'absolute\');\r\n                                        jQuery(\'.E68_floatBanner\').css(\'top\', \'135px\');\r\n                                    }\r\n                                }\r\n                               \r\n                                /*\r\n                                if(jQuery(window).scrollTop() >= overHeight)\r\n                                {\r\n                                    jQuery(\'body\').addClass(\'fixedTop\',1000);\r\n                                    if(isfromBenefit == \'Y\')\r\n                                    {\r\n                                        jQuery(\'#R65-b-tm\').addClass(\'addMarginTop\');\r\n                                        jQuery(\'.uhSearch\').addClass(\'addMarginTop\');\r\n                                    }\r\n                                }\r\n                                else\r\n                                {\r\n                                    jQuery(\'body\').removeClass(\'fixedTop\');;\r\n                                    if(isfromBenefit == \'Y\')\r\n                                    {\r\n                                        jQuery(\'#R65-b-tm\').removeClass(\'addMarginTop\');\r\n                                        jQuery(\'.uhSearch\').removeClass(\'addMarginTop\')\r\n                                    }\r\n                                }\r\n                                */\r\n                        });\r\n                    }\r\n                    \r\n            var resizeWindow = function()\r\n            {\r\n                if( jQuery( window ).width() <= 1030)\r\n                {\r\n                    jQuery(\'.E68_floatBanner\').css(\'left\', \'40%\');\r\n                }\r\n                else\r\n                {\r\n                    jQuery(\'.E68_floatBanner\').css(\'left\', \'50%\');\r\n                }\r\n            };\r\n            \r\n            jQuery( window ).resize(function() {\r\n                resizeWindow();\r\n            });\r\n            \r\n            resizeWindow();\r\n                \r\n            jQuery(document).ready(function(){\r\n\r\n\t\t\t\tjQuery(\'a[class ~= "gaTrackEventshoppintcart"]\').live("click", function(e){\r\n                    //e.preventDefault();\r\n                    \r\n\t\t\t\t\t//console.log(  typeof(jQuery(this).attr(\'PHD\') )   ); \r\n\t\t\t\t\t//console.log("_trackEvent{ PHD = " + jQuery(this).attr(\'PHD\') + " , Href =  " + jQuery(this).attr(\'Href\') + " }"); \r\n\t\t\t\t\t\r\n\t\t\t\t\t//if (typeof (_gaq) != "undefined") \r\n\t\t\t\t\t//{   \r\n\t\t\t\t\t\tif(jQuery(this).attr(\'PHD\')==\'black_account\')gahref=\'account.aspx\';\r\n\t\t\t\t\t\telse if(jQuery(this).attr(\'PHD\')==\'black_shoppinglist\')gahref=\'shoppinglist.aspx\';\r\n\t\t\t\t\t\telse if(jQuery(this).attr(\'PHD\')==\'black_list\')gahref=\'comparelist.aspx\';\r\n\t\t\t\t\t\telse if(jQuery(this).attr(\'PHD\')==\'black_view\')gahref=\'viewshistory.aspx\';\r\n\t\t\t\t\t\telse if(jQuery(this).attr(\'PHD\')==\'black_pay\')gahref=\'pay.aspx\';\r\n\t\t\t\t\t\telse gahref=jQuery(this).attr(\'Href\');\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t//_gaq.push([\'_trackEvent\', \'click_shopping\', jQuery(this).attr(\'PHD\'), gahref]);\r\n                        ga(\'send\', \'event\', \'click_shopping\', jQuery(this).attr(\'PHD\'), gahref);\r\n                        \r\n                        \r\n                        if (typeof (dataLayer) != "undefined") \r\n                        {\r\n                            dataLayer.push({\'event\': \'trackEvent\',\'event_category\': \'click_shopping\',\'event_action\': jQuery(this).attr(\'PHD\'),\'event_label\': gahref});\r\n                        }\r\n                    //}\r\n                });\r\n                \r\n                \r\n                // 新版吃的GA\r\n                    /* Google _trackEvent() 2013.12.24 更新*/\r\n                    jQuery(\'[class ~= GAEventTracking]\').live(\'click\', function (e) {\r\n                    \r\n                        //alert(e.target.tagName);\r\n                        var targetTagName = e.target.tagName.toLowerCase();\r\n                        //e.preventDefault();\r\n                        //alert(\'new PHD = \' + jQuery(this).attr(\'PHD\'))\r\n                        //alert(\'new Href = \' + jQuery(this).attr(\'Href\'))\r\n                        \r\n                        var itemNO = 1;\r\n                        jQuery(\'[class ~= GAEventTracking]\').removeClass(\'GAETClick\');\r\n                        jQuery(this).addClass(\'GAETClick\');\r\n                        \r\n                        jQuery(\'[GA_EventName="\' + jQuery(this).attr(\'GA_EventName\') + \'"]\').each(function (i) {\r\n                            if( jQuery(this).hasClass(\'GAETClick\') )\r\n                            {\r\n                                itemNO = (i + 1);\r\n                            }\r\n                        });\r\n                        \r\n                        /*\r\n                        if(  (jQuery(this).hasAttr(\'rel\'))  )\r\n                        {\r\n                            alert(\'hasAttr\');\r\n                        }\r\n                        else\r\n                        {\r\n                            alert(\'noAttr\');\r\n                        }\r\n                        */\r\n                        \r\n                        var PicOrText;\r\n                        if(jQuery(this).attr(\'GA_EventPicTxt\') == \'pro\')\r\n                        {\r\n                            PicOrText = (targetTagName == \'img\')? \'pic\' : \'text\';\r\n                        }\r\n                        else if(jQuery(this).attr(\'GA_EventPicTxt\') == \'fakepic\')\r\n                        {\r\n                            PicOrText = \'pic\';\r\n                        }\r\n                        else\r\n                        {\r\n                            PicOrText = jQuery(this).attr(\'GA_EventPicTxt\');\r\n                        }\r\n                        \r\n                        \r\n                        var eventCategory;\r\n                        if( jQuery(\'[GA_EventName="\' + jQuery(this).attr(\'GA_EventName\') + \'"]\').size() == 1 )\r\n                        {\r\n                            if(jQuery(this).attr(\'GA_EventCount\') && jQuery(this).attr(\'GA_EventCount\') == \'NoNum\')\r\n                            {\r\n                                eventCategory = jQuery(this).attr(\'GA_EventType\') + \'_\' + jQuery(this).attr(\'GA_EventName\');\r\n                            }\r\n                            else\r\n                            {\r\n                                eventCategory = jQuery(this).attr(\'GA_EventType\') + \'_\' + jQuery(this).attr(\'GA_EventName\') + \'_\' + PicOrText;\r\n                            }\r\n                        }\r\n                        else\r\n                        {\r\n                            if(jQuery(this).attr(\'GA_EventCount\') && jQuery(this).attr(\'GA_EventCount\') == \'NoNum\')\r\n                            {\r\n                                eventCategory = jQuery(this).attr(\'GA_EventType\') + \'_\' + jQuery(this).attr(\'GA_EventName\');\r\n                            }\r\n                            else\r\n                            {\r\n                                eventCategory = jQuery(this).attr(\'GA_EventType\') + \'_\' + jQuery(this).attr(\'GA_EventName\') + \'_\' + itemNO + \'_\' + PicOrText;\r\n                            }\r\n                            \r\n                        }\r\n                        var eventAction   = jQuery(this).attr(\'Href\');\r\n                        var eventActionOri = jQuery(this).attr(\'Href\');\r\n                        \r\n                        \r\n                        if(jQuery(this).attr(\'GA_EventRule\') && jQuery(this).attr(\'GA_EventRule\') == \'Y\')\r\n                        {\r\n                            eventAction = jQuery(this).attr(\'GA_EventAction\');\r\n                        }\r\n                        \r\n                        var eventLabel;\r\n                        \r\n                        switch(jQuery(this).attr(\'GA_EventPicTxt\'))\r\n                        {\r\n                            case (\'fakepic\'):{\r\n                                eventLabel = getMediaImgStr(jQuery(this).attr(\'VirtualImg\'));\r\n                                break;\r\n                            };\r\n                            case (\'pic\'):{\r\n                                eventLabel = getMediaImgStr(jQuery(this).find(\'img\').attr(\'src\'));\r\n                                break;\r\n                            };\r\n                            case (\'text\'):{\r\n                                eventLabel = jQuery(this).text().replace(/^\\s+|\\s+$/gm,\'\').replace(\'\\t\',\'\');\r\n                                break;\r\n                            };\r\n                            case (\'pro\'):{\r\n                                \r\n                                if(targetTagName == \'img\')\r\n                                {\r\n                                    eventLabel = getMediaImgStr( jQuery(this).find(\'.Gd-pic\').attr(\'src\') );\r\n                                }\r\n                                else\r\n                                {\r\n                                    eventLabel = jQuery(this).find(\'.Gd-name\').text().replace(/^\\s+|\\s+$/gm,\'\').replace(\'\\t\',\'\');\r\n                                }\r\n                                \r\n                                break;\r\n                            };\r\n                        };\r\n                        \r\n                        \r\n                        //alert(\'eventCategory = \' + eventCategory);\r\n                        //alert(\'eventAction = \' + eventAction);\r\n                        //alert(\'eventLabel = \' + eventLabel);\r\n                        //return;\r\n                        \r\n                        \r\n                        //PHRef\r\n                        if( jQuery(this).hasClass(\'PHType-AD\') )\r\n                        {\r\n\t\t\t\t\t\t\tif(!jQuery(this).hasClass(\'PHType-Click\'))\r\n\t\t\t\t\t\t\t{\r\n\t\t\t\t\t\t\t\tif(jQuery(this).attr(\'Href\').toLowerCase().indexOf(\'aspx\') != -1)\r\n\t\t\t\t\t\t\t\t{\r\n\t\t\t\t\t\t\t\t\tif(jQuery(this).attr(\'Href\').toLowerCase().indexOf(\'scupio\') != -1)\r\n\t\t\t\t\t\t\t\t\t{\r\n\t\t\t\t\t\t\t\t\t\t(jQuery(this).attr(\'Href\').indexOf(\'%3f\') == -1)? jQuery(this).attr(\'Href\', eventActionOri + \'%3fPHRef=\' + eventCategory): jQuery(this).attr(\'Href\', eventActionOri + \'%26PHRef=\' + eventCategory)\r\n\t\t\t\t\t\t\t\t\t}\r\n\t\t\t\t\t\t\t\t\telse\r\n\t\t\t\t\t\t\t\t\t{\r\n\t\t\t\t\t\t\t\t\t\t(jQuery(this).attr(\'Href\').indexOf(\'?\') == -1)? jQuery(this).attr(\'Href\', eventActionOri + \'?PHRef=\' + eventCategory): jQuery(this).attr(\'Href\', eventActionOri + \'&PHRef=\' + eventCategory)\r\n\t\t\t\t\t\t\t\t\t}\r\n\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t}\r\n\t\t\t\t\t\t\t\tjQuery(this).addClass(\'PHType-Click\');\r\n\t\t\t\t\t\t\t}\r\n                        }\r\n                        else\r\n                        {\r\n\t\t\t\t\t\t\tif(!jQuery(this).hasClass(\'PHType-Click\'))\r\n\t\t\t\t\t\t\t{\r\n\t\t\t\t\t\t\t\tif(PHRef != \'\' && jQuery(this).attr(\'Href\').toLowerCase().indexOf(\'aspx\') != -1)\r\n\t\t\t\t\t\t\t\t{\r\n\t\t\t\t\t\t\t\t\tif(jQuery(this).attr(\'Href\').toLowerCase().indexOf(\'scupio\') != -1)\r\n\t\t\t\t\t\t\t\t\t{\r\n\t\t\t\t\t\t\t\t\t\t(jQuery(this).attr(\'Href\').indexOf(\'%3f\') == -1)? jQuery(this).attr(\'Href\', eventActionOri + \'%3fPHRef=\' + PHRef): jQuery(this).attr(\'Href\', eventActionOri + \'%26PHRef=\' + PHRef)\r\n\t\t\t\t\t\t\t\t\t}\r\n\t\t\t\t\t\t\t\t\telse\r\n\t\t\t\t\t\t\t\t\t{\r\n\t\t\t\t\t\t\t\t\t\t(jQuery(this).attr(\'Href\').indexOf(\'?\') == -1)? jQuery(this).attr(\'Href\', eventActionOri + \'?PHRef=\' + PHRef): jQuery(this).attr(\'Href\', eventActionOri + \'&PHRef=\' + PHRef)\r\n\t\t\t\t\t\t\t\t\t}\r\n\t\t\t\t\t\t\t\t}\r\n\r\n\t\t\t\t\t\t\t\tjQuery(this).addClass(\'PHType-Click\');\r\n\t\t\t\t\t\t\t}\r\n                        }\r\n                        \r\n                        if (typeof (_gaq) != "undefined") \r\n                        {\r\n                            //_gaq.push([\'_trackEvent\', eventCategory, eventAction, eventLabel]);\r\n                        }\r\n                        \r\n                        ga(\'send\', \'event\', eventCategory, eventAction, eventLabel);\r\n                        \r\n                        if (typeof (dataLayer) != "undefined") \r\n                        {\r\n                            dataLayer.push({\'event\': \'trackEvent\',\'event_category\': eventCategory,\'event_action\': eventAction,\'event_label\': eventLabel});\r\n                        }\r\n                        \r\n                        fbq(\'track\', \'ViewContent\');\r\n                    });\r\n            });\r\n        </script>\n<a class="n-cd-top" href="#0">TOP</a>\n<footer class="n-footer">\n<form method="post" name="goFooterSearch">\n<input name="CategoryID" type="hidden"/>\n<input name="CategoryName" type="hidden"/>\n<input name="Color" type="hidden"/>\n<input name="ColorValue" type="hidden"/>\n<input name="CombinedCode" type="hidden"/>\n<input name="hiotoryTree" type="hidden"/>\n<input name="hiotoryTreeName" type="hidden"/>\n<input name="noResultUse" type="hidden"/>\n<input name="OnlineDateEnd" type="hidden"/>\n<input name="OnlineDateStart" type="hidden"/>\n<input name="OrderBy" type="hidden"/>\n<input name="PageIndex" type="hidden" value="0"/>\n<input name="PageSize" type="hidden" value="20"/>\n<input name="ProductMoneyEnd" type="hidden"/>\n<input name="ProductMoneyStart" type="hidden"/>\n<input name="ProductSource" type="hidden"/>\n<input name="query_advance" type="hidden" value="Y"/>\n<input name="query_categoryid" type="hidden"/>\n<input name="query_searchType" type="hidden"/>\n<input name="query_storeid" type="hidden"/>\n<input name="QueryCmd" type="hidden"/>\n<input name="QueryCmdName" type="hidden"/>\n<input name="SearchKeyword" type="hidden"/>\n<input name="Style" type="hidden"/>\n<input name="StyleValue" type="hidden"/>\n<input name="Video" type="hidden"/>\n</form>\n<div class="n-content-s">\n<a class="n-gotop" href="#">TOP</a>\n<div class="clearfix">\n<div class="n-footer__service"></div>\n<!--iframe 非首頁使用-->\n<!--iframe id="FaceError" src="https://www.facebook.com/plugins/like.php?href=https%3A%2F%2Fwww.facebook.com%2FETMall&amp;send=false&amp;layout=standard&amp;width=100&amp;show_faces=true&amp;font&amp;colorscheme=light&amp;action=like&amp;height=40" scrolling="no" frameborder="0" class="n-footer__fb"></iframe-->\n<div class="n-footer__fb">\n<div id="fb-root"></div>\n<script>(function(d, s, id) {\r\n                            var js, fjs = d.getElementsByTagName(s)[0];\r\n                            if (d.getElementById(id)) return;\r\n                            js = d.createElement(s); js.id = id;\r\n                            js.src = "//connect.facebook.net/zh_TW/sdk.js#xfbml=1&version=v2.7&appId=289388427741701";\r\n                            fjs.parentNode.insertBefore(js, fjs);\r\n                        }(document, \'script\', \'facebook-jssdk\'));</script>\n<div class="fb-like" data-action="like" data-href="https://www.facebook.com/ETMall" data-layout="standard" data-share="true" data-show-faces="true" data-size="small" data-width="260"></div>\n</div>\n</div>\n<div class="hr--lv2"></div>\n<div class="clearfix">\n<div class="n-icon-footer__logo"><a class="sendGA" gaaction="" galabel="Foot_EHSLOGO" ganame="EHSLOGO" gapictext="pic" gatype="Foot" href="Home.aspx" title="返回首頁"><img height="73" src="../img201607/1x1_transparent.gif" width="56"/></a></div>\n<div class="n-footer__copy">\r\n                        本網站所有內容及圖片均不得以任何型式，予以重製或傳送 <a class="underline--link" href="R6MemCenterNoticec_sub.aspx?Page=7_1_notice_security">安全機制</a> 與 <a class="underline--link" href="R6MemCenterNoticec_sub.aspx?Page=7_2_notice_private">隱私聲明</a> \u3000<a href="http://www.etmall.com.tw/XML/content/PCITLS/index.html" target="_blank">(即日起停用支援TLS 1.0 加密協定)</a><br/>\r\n                        東森得易購股份有限公司版權所有<span class="n-icon-ip">\u3000<span>台灣 新北市中和區景平路258號1樓 <br/>\r\n                        代表人：陳世志 <br/>\r\n                        24H 免費服務專線：0800-013-058 <br/>\r\n                        電子信箱：ehs_service@ehsn.com.tw<br/>\r\n                        2016 EASTERN HOME SHOPPING &amp; LEISURE CO., LTD. All Rights Reserved.\r\n                    </span></span></div>\n<div class="n-footer__security">\n<!--div class="items"><a href="https://trustsealinfo.verisign.com/splash?form_file=fdf%2Fsplash.fdf&amp;sap=&amp;dn=www.etmall.com.tw&amp;zoneoff=&amp;lang=zh_TW" class="n-icon-hitrust" target="_blank" title="全球安全認證網站"></a></div-->\n<!--div class="items"><a href="https://www.scanalert.com/RatingVerify?ref=www.etmall.com.tw&amp;lang=TW" class="n-icon-scanalert"><img border="0" src="https://images.scanalert.com/meter/www.etmall.com.tw/23.gif" width="94px" height="54px" alt="HACKER SAFE認證的網站足以預防99%以上的駭客犯罪" oncontextmenu="alert(\'翻印必究 - HACKER SAFE是ScanAlert公司的註冊商標\'); return false;" target="_blank"></a></div-->\n<div class="items"><a class="n-icon-bsi" href="http://www.etmall.com.tw/XML/Content/BSI/index.html" target="_blank"></a></div>\n<div class="items"><a class="n-icon-pcidss" href="http://www.etmall.com.tw/XML/Content/PCIDSS/index.html" target="_blank"></a></div>\n</div>\n</div>\n</div>\n</footer>\n<script charset="UTF-8" language="Javascript" src="../js201607/E68pageJS.js"></script>\n<!--ponta登入辦綁卡-->\n<a class="pontaFancy" href="#PontaFancyRule" style="display:none;">d78798797987987987987979889798ddd</a>\n<script>\r\n            jQuery(\'.pontaFancy\').fancybox({\r\n                    \'href\' : \'#PontaFancyRule\',\r\n                    \'overlayOpacity\'\t:0.2,\r\n                    \'overlayShow\':false\r\n            });\r\n\r\n            jQuery(document).ready(function(){\r\n                //var LoginPonta_Web_Switch = getCookieObj.LoginPonta_Web_Switch;\r\n                  \r\n                if("N" == "Y" && location.href.toLowerCase().indexOf(\'basket.aspx\') == -1)\r\n                {\r\n                    jQuery(\'#PontaFancyRule\').append(\'<iframe src="LoginOneCard_Apply.aspx" frameborder="0" scrolling="no" width="690" height="485"></iframe>\');\r\n                  \r\n                    jQuery(\'.pontaFancy\').trigger(\'click\');\r\n                    //getCookieObj.setCookie("LoginPonta_Web_Switch", "N");\r\n                    \r\n                    jQuery(\'#fancybox-wrap\').css(\'position\', \'fixed\');\r\n                    \r\n                    jQuery(\'#fancybox-content\').css(\'border-color\', \'#333\');\r\n                    jQuery(\'#fancybox-content\').css(\'border-width\', \'6px\');\r\n                    \r\n                    jQuery(\'#fancybox-close\').css(\'background-image\', \'url("../R6Images/ponta/images/fancybox/fancybox_sprite.png")\');\r\n                    jQuery(\'#fancybox-close\').css(\'background-position\', \'-4px -2px\');\r\n                    jQuery(\'#fancybox-close\').css(\'top\', \'-13px\');\r\n                    jQuery(\'#fancybox-close\').css(\'right\', \'-4px\');\r\n                }\r\n            });\r\n        </script>\n<div style="display:none;">\n<div id="PontaFancyRule" style="width:680px;height:480px;padding:20px;background-coloe:#fff;">\n</div>\n</div>\n<!-- Google 在營銷代碼 -->\n<script type="text/javascript">\n/* <![CDATA[ */\nvar google_conversion_id = 977282151;\nvar google_custom_params = window.google_tag_params;\nvar google_remarketing_only = true;\n/* ]]> */\n</script>\n<script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript">\n</script>\n<noscript>\n<div style="display:inline;">\n<img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/977282151/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/>\n</div>\n</noscript>\n</body>\n</html>\n'

# %%
b
# Out:
# '<!DOCTYPE HTML>\n<html prefix="og: http://ogp.me/ns#"><head><meta content="TEXT/HTML; CHARSET=UTF-8" http-equiv="Content-Type"/>\n<title>搜尋結果｜ETMall東森購物網</title>\n<meta content="no-cache" http-equiv="Pragma"/>\n<meta content="Yes" http-equiv="MSThemeCompatible"/>\n<meta content="1 days" name="revisit-after"/>\n<meta content="no-cache" http-equiv="Pragma"/>\n<meta content="no-store" http-equiv="Cache-Control"/>\n<meta content="0" http-equiv="expires"/>\n<meta content="IE=9; IE=8; IE=7" http-equiv="X-UA-Compatible"/>\n<script>\n\tvar ETU_opener = \'Y\';\n</script>\n<script>var FBrecord_opener = \'Y\';</script>\n<meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>\n<script>\r\nvar isUseNewImgPath = \'Y\';\r\nvar IsUseNewImageIP = \'media.etmall.com.tw/NXimg\';\r\n</script>\n<script type="text/javascript">\r\n(function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElemen
# ...
