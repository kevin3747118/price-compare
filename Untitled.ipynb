# %%
from bs4 import BeautifulSoup
import pymssql
import urllib.request
import random
import time

from bs4 import BeautifulSoup
# def get_page(url):
#     time.sleep(0.37)
#     request = urllib.request.Request(url)
#
#     ####randon header here####
#     foo = [
# ##       'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2227.1 Safari/537.36',
# ##       'Mozilla/5.0 (compatible, MSIE 11, Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko',
# ##       'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:40.0) Gecko/20100101 Firefox/40.1'
# ##       'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_6_7; da-dk) AppleWebKit/533.21.1 (KHTML, like Gecko) Version/5.0.5 Safari/533.21.1'
#          'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246'
#          'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2722.0 Safari/537.36'
#          'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.116 Safari/537.36'
#     ]
#     headers = str(random.choice(foo))
#     ####randon header here####
#
#     request.add_header('User-Agent', headers)
#     time.sleep(0.45)
#     response = urllib.request.urlopen(request, timeout=180)
#     html = response.read().decode('utf-8')
#     response.close()
#     return html
def get_page(url):

    time.sleep(0.45)
    from bs4 import BeautifulSoup
    import urllib.request
    import random

    request = urllib.request.Request(url)

    ####隨機header挑選####
    foo = [
        # 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2227.1 Safari/537.36',
        'Mozilla/5.0 (compatible, MSIE 11, Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko',
        'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:40.0) Gecko/20100101 Firefox/40.1'
        'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_6_7; da-dk) AppleWebKit/533.21.1 (KHTML, like Gecko) Version/5.0.5 Safari/533.21.1'
        # 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246'
        # 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2722.0 Safari/537.36'
        # 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.116 Safari/537.36'
    ]
    headers = str(random.choice(foo))
    ####隨機header挑選####

    request.add_header('User-Agent', headers)
    time.sleep(0.37)
    response = urllib.request.urlopen(request, timeout=180)
    html = BeautifulSoup(response.read().decode('utf-8'), 'lxml')
    return html


# cnxn = pymssql.connect(server='payeasy.database.windows.net', user='payeasydb@payeasy', password='ar2vmee.',database='PAYEASY_DATA', as_dict=False)
# cnxn = pymssql.connect(server='payeasy.database.windows.net', user='bi_agent@payeasy', password='abcd-1234',database='PAYEASY_DATA', as_dict=False)
cnxn = pymssql.connect(server='10.10.20.5', user='bi_agent', password='abcd-1234', database='MIS_OPEN', as_dict=False)
cursor = cnxn.cursor()
#################################################################################################
####單一店面####
# sql_null_area = ("select distinct 區 from [dbo].[store_information_2017] where google電話 is null")
sql_null_area = ("select distinct([地區名稱]) from dbo.STORE_INFORMATION_MAINTENANCE where 地區名稱 = '三灣鄉'")
cursor.execute(sql_null_area)
null_area = cursor.fetchall()


for i in range(len(null_area)):
    # sql_google_null_tel = ("SELECT SID, 店名, [地址(不含市區)], 市 "
    #                        "FROM [dbo].[store_information_2017] "
    #                    # "where SID = 10 ")
    #                        " where 店名 in (select 店名 FROM [dbo].[store_information_2017]"
    #                        " group by 店名 having count(*) <= 1 ) "
    #                        "and 區 = '" + str(null_area[i][0]) + "' and 分店 = '' and google電話 is null ")
    sql_google_null_tel = ("SELECT [PSD_NUM], [特約商店名稱], [地址], [地區名稱] "
                           "FROM [dbo].[STORE_INFORMATION_MAINTENANCE] "
                       # "where SID = 10 ")
                           "where [特約商店名稱] in (select [特約商店名稱] FROM [dbo].[STORE_INFORMATION_MAINTENANCE]"
                           "group by [特約商店名稱] having count(*) <= 1 ) "
                           "and [地區名稱] = '" + str(null_area[i][0]) + "' and [分店名稱] = '' and [google電話] is null ")
    cursor.execute(sql_google_null_tel)
    google_null_tel = cursor.fetchall()
####單一店面####
################################################################################################
    ###變數宣告區###
    weeks = ['星期一', '星期二', '星期三', '星期四', '星期五', '星期六', '星期日']
    remove_string = ['(春節)', '']
    len_google_null_tel = [x for x in range(len(google_null_tel))]
    ###變數宣告區###
    try:
        print('processing single store data !')
        for i in len_google_null_tel:
            #         print(google_null_tel[i][1])
            ####店名####
            terms = urllib.parse.quote(google_null_tel[i][1] + ' ' + google_null_tel[i][3])
            #         print('https://www.google.com.tw/search?&q=' + terms + '%20%E5%8F%B0%E5%8C%97&oq=' + terms + '%20%E5%8F%B0%E5%8C%97')
            soup = get_page('https://www.google.com.tw/search?&q=' + terms + '%20%E5%8F%B0%E5%8C%97&oq=' + terms + '%20%E5%8F%B0%E5%8C%97')
            #         result = get_page('https://www.google.com.tw/search?&q=' + terms + '&oq=' + terms)
            #         soup = BeautifulSoup(result, "lxml")
            #         ####店名####

            #         ####店名+部份地址####
            address_remove = ''.join([i for i in google_null_tel[i][2] if not i.isdigit() and i not in '巷號弄樓之-ABC與()'])
            terms2 = urllib.parse.quote(google_null_tel[i][1] + ' ' + address_remove + ' ' + google_null_tel[i][3])
            soup2 = get_page('https://www.google.com.tw/search?&q=' + terms2 + '&oq=' + terms2)
    except:
        print('oh~')
# Out:
# processing single store data !

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup2
# Out:
# <!DOCTYPE html>
# ...
